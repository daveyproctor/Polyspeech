# %%
len(usernames)
# Out:
# 464

# %%
len(set(usernames))
# Out:
# 237

# %%
from collections import OrderedDict
remdups = list(OrderedDict.fromkeys(usernames))
remdups
# Out:
# ['@RepConorLamb',
#  '@SenHydeSmith',
#  '@SenDougJones',
#  '@SenTinaSmith',
#  '@RepKHandel',
#  '@RepRalphNorman',
#  '@RepRonEstes',
#  '@RepClayHiggins',
#  '@HouseHomeland',
#  '@RepScottTaylor',
#  '@RepRutherfordFL',
#  '@HouseJudiciary',
#  '@RepMikeJohnson',
#  '@RepJenniffer',
#  '@NatResources',
#  '@HouseSmallBiz',
#  '@RepDonBacon',
#  '@RepMattGaetz',
#  '@RepDarrenSoto',
#  '@RepJackyRosen',
#  '@RepGonzalez',
#  '@RepAlLawsonJr',
#  '@RepTomGarrett',
#  '@EdWorkforce',
#  '@RepTedBudd',
#  '@RepEspaillat',
#  '@RepBRochester',
#  '@RepBarragan',
#  '@HispanicCaucus',
#  '@USProgressives',
#  '@RepLizCheney',
#  '@RepTomSuozzi',
#  '@SenJohnKennedy',
#  '@RepAndyBiggsAZ',
#  '@RepBrianFitz',
#  '@RepRoKhanna',
#  '@RepArrington',
#  '@RepKihuen',
#  '@RepMcEachin',
#  '@HASCDemocrats',
#  '@RepCarbajal',
#  '@RepJimBanks',
#  '@RepRooney',
#  '@RepJasonLewis',
#  '@RepCharlieCrist',
#  '@RepDavidKustoff',
#  '@RepLouCorrea',
#  '@VetAffairsDems',
#  '@RepGallagher',
# ...

# %%
women_old = [
('lisamurkowski', 'D', '?', 'Sen'),
('SenatorBoxer', 'D', '?', 'Sen'),
('maziehirono', 'D', '?', 'Sen'),
('SenLandrieu', 'D', '?', 'Sen'),
('SenatorBarb', 'D', '?', 'Sen'),
('stabenow', 'D', '?', 'Sen'),
('amyklobuchar', 'D', '?', 'Sen'),
('clairecmc', 'D', '?', 'Sen'),
('SenatorShaheen', 'D', '?', 'Sen'),
('SenGillibrand', 'D', '?', 'Sen'),
('SenatorHagan', 'D', '?', 'Sen'),
('SenatorHeitkamp', 'D', '?', 'Sen'),
('SenFeinstein', 'R', '?', 'Sen'),
('SenatorFischer', 'R', '?', 'Sen'),
('kellyayotte', 'R', '?', 'Sen')]

# %%
women_new = [('SenHydeSmith', 'R', 'Cindy Hyde-Smith', 'Sen'),
('SenTinaSmith', 'D', 'Tina Smith', 'Sen'),
('RepKHandel', 'R', 'Karen Handel', 'Rep'),
('RepJenniffer', 'R', 'Jenniffer Gonzalez', 'Rep'),
('RepJackyRosen', 'R', 'Jacky Rosen', 'Rep'),
('RepBRochester', 'D', 'Blunt Rochester', 'Rep'),
('RepBarragan', 'D', 'Nanette D. Barragan', 'Rep'),
('RepLizCheney', 'R', 'Liz Cheney', 'Rep'),
('RepJayapal', 'D', 'Pramila Jayapal', 'Rep'),
('SenKamalaHarris', 'D', 'Kamala Harris', 'Sen'),
('RepValDemings', 'D', 'Val Demings', 'Rep'),
('RepTenney', 'R', 'Tenney', 'Rep'),
('RepStephMurphy', 'D', 'Stephanie Murphy', 'Rep'),
('RepAmata', 'R', 'Aumua Amata', 'Rep'),
('RepMiaLove', '?', 'Mia Love', 'Rep'),
('RepKathleenRice', '?', 'Kathleen Rice', 'Rep'),
('RepDebDingell', '?', 'Debbie Dingell', 'Rep'),
('RepBonnie', 'D', 'Bonnie WatsonColeman', 'Rep'),
('RepMcSally', '?', 'Martha McSally', 'Rep'),
('RepStefanik', '?', 'Elise Stefanik', 'Rep'),
('RepComstock', '?', 'Barbara Comstock', 'Rep'),
('RepAdams', '?', 'Alma S. Adams', 'Rep'),
('RepLawrence', '?', 'Brenda Lawrence', 'Rep'),
('StaceyPlaskett', '?', 'Stacey Plaskett', 'Rep'),
('RepKClark', '?', 'Katherine Clark', 'Rep'),
('USRepKCastor', '?', 'Kathy Castor', 'Rep'),
('RepBeatty', '?', 'Joyce Beatty', 'Rep'),
('RepRobinKelly', '?', 'Robin Kelly', 'Rep'),
('RepDWStweets', '?', 'Wasserman Schultz', 'Rep'),
('RepCheri', '?', 'Cheri Bustos', 'Rep'),
('RepSinema', '?', 'Kyrsten Sinema', 'Rep'),
('RepLoisFrankel', '?', 'Lois Frankel', 'Rep'),
('SenatorBaldwin', '?', 'Tammy Baldwin', 'Sen'),
('SusanWBrooks', '?', 'Susan W. Brooks', 'Rep'),
('RepWalorski', '?', 'Jackie Walorski', 'Rep'),
('RepEsty', '?', 'Elizabeth Esty', 'Rep')]

# %%
len(women_new), len(women_old)
# Out:
# (36, 15)

# %%
OrderedDict.fromkeys(women_old + women_new) - OrderedDict.fromkeys(women_new)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2a89f80a2a4a> in <module>()
# ----> 1 OrderedDict.fromkeys(women_old + women_new) - OrderedDict.fromkeys(women_new)
#
# TypeError: unsupported operand type(s) for -: 'collections.OrderedDict' and 'collections.OrderedDict'

# %%
women = list(OrderedDict.fromkeys(women_old + women_new))
women
# Out:
# [('lisamurkowski', 'D', '?', 'Sen'),
#  ('SenatorBoxer', 'D', '?', 'Sen'),
#  ('maziehirono', 'D', '?', 'Sen'),
#  ('SenLandrieu', 'D', '?', 'Sen'),
#  ('SenatorBarb', 'D', '?', 'Sen'),
#  ('stabenow', 'D', '?', 'Sen'),
#  ('amyklobuchar', 'D', '?', 'Sen'),
#  ('clairecmc', 'D', '?', 'Sen'),
#  ('SenatorShaheen', 'D', '?', 'Sen'),
#  ('SenGillibrand', 'D', '?', 'Sen'),
#  ('SenatorHagan', 'D', '?', 'Sen'),
#  ('SenatorHeitkamp', 'D', '?', 'Sen'),
#  ('SenFeinstein', 'R', '?', 'Sen'),
#  ('SenatorFischer', 'R', '?', 'Sen'),
#  ('kellyayotte', 'R', '?', 'Sen'),
#  ('SenHydeSmith', 'R', 'Cindy Hyde-Smith', 'Sen'),
#  ('SenTinaSmith', 'D', 'Tina Smith', 'Sen'),
#  ('RepKHandel', 'R', 'Karen Handel', 'Rep'),
#  ('RepJenniffer', 'R', 'Jenniffer Gonzalez', 'Rep'),
#  ('RepJackyRosen', 'R', 'Jacky Rosen', 'Rep'),
#  ('RepBRochester', 'D', 'Blunt Rochester', 'Rep'),
#  ('RepBarragan', 'D', 'Nanette D. Barragan', 'Rep'),
#  ('RepLizCheney', 'R', 'Liz Cheney', 'Rep'),
# ...

# %%
len(women)
# there are 19 women senators, 32 women reps
# Out:
# 51

# %%
# take all twitter handles on the page https://twitter.com/cspan/lists/members-of-congress/members?lang=en
mostly_humans = ['RepConorLamb', 'RepConorLamb', 'SenHydeSmith', 'SenHydeSmith', 'SenDougJones', 'SenDougJones', 'SenTinaSmith', 'SenTinaSmith', 'RepConorLamb', 'RepConorLamb', 'SenHydeSmith', 'SenHydeSmith', 'SenDougJones', 'SenDougJones', 'SenTinaSmith', 'SenTinaSmith', 'RepKHandel', 'RepKHandel', 'RepRalphNorman', 'RepRalphNorman', 'RepRonEstes', 'RepRonEstes', 'RepClayHiggins', 'RepClayHiggins', 'HouseHomeland', 'RepScottTaylor', 'RepScottTaylor', 'RepRutherfordFL', 'RepRutherfordFL', 'HouseHomeland', 'HouseJudiciary', 'RepMikeJohnson', 'RepMikeJohnson', 'HouseJudiciary', 'RepJenniffer', 'RepJenniffer', 'NatResources', 'HouseSmallBiz', 'RepDonBacon', 'RepDonBacon', 'RepMattGaetz', 'RepMattGaetz', 'RepDarrenSoto', 'RepDarrenSoto', 'RepJackyRosen', 'RepJackyRosen', 'RepGonzalez', 'RepGonzalez', 'RepAlLawsonJr', 'RepAlLawsonJr', 'RepTomGarrett', 'RepTomGarrett', 'EdWorkforce', 'HouseHomeland', 'RepTedBudd', 'RepTedBudd', 'RepEspaillat', 'RepEspaillat', 'RepBRochester', 'RepBRochester', 'RepBarragan', 'RepBarragan', 'HispanicCaucus', 'USProgressives', 'RepLizCheney', 'RepLizCheney', 'RepTomSuozzi', 'RepTomSuozzi', 'SenJohnKennedy', 'SenJohnKennedy', 'RepAndyBiggsAZ', 'RepAndyBiggsAZ', 'RepBrianFitz', 'RepBrianFitz', 'RepRoKhanna', 'RepRoKhanna', 'RepArrington', 'RepArrington', 'RepKihuen', 'RepKihuen', 'RepMcEachin', 'RepMcEachin', 'HASCDemocrats', 'RepCarbajal', 'RepCarbajal', 'RepJimBanks', 'RepJimBanks', 'RepRooney', 'RepRooney', 'RepJasonLewis', 'RepJasonLewis', 'RepCharlieCrist', 'RepCharlieCrist', 'RepDavidKustoff', 'RepDavidKustoff', 'RepLouCorrea', 'RepLouCorrea', 'VetAffairsDems', 'RepGallagher', 'RepGallagher', 'DrNealDunnFL2', 'DrNealDunnFL2', 'RepJohnFaso', 'RepJohnFaso', 'RepJayapal', 'RepJayapal', 'USProgressives', 'RepJoshG', 'RepJoshG', 'CongressmanRaja', 'CongressmanRaja', 'RepBrianMast', 'RepBrianMast', 'RepTrey', 'RepTrey', 'RepPaulMitchell', 'RepPaulMitchell', 'SenCortezMasto', 'SenCortezMasto', 'RepOHalleran', 'RepOHalleran', 'RepRaskin', 'RepRaskin', 'RepDrewFerguson', 'RepDrewFerguson', 'SenKamalaHarris', 'SenKamalaHarris', 'RepValDemings', 'RepValDemings', 'RepTenney', 'RepTenney', 'RepJimmyPanetta', 'RepJimmyPanetta', 'RepStephMurphy', 'RepStephMurphy', 'RepMarshall', 'RepMarshall', 'RepMikeCapuano', 'RepMikeCapuano', 'WarrenDavidson', 'WarrenDavidson', 'CongBoyle', 'CongBoyle', 'BlueCollarDems', 'RepLaHood', 'RepLaHood', 'RepTrentKelly', 'RepTrentKelly', 'DonaldNorcross', 'DonaldNorcross', 'RepTedLieu', 'RepTedLieu', 'TedLieu', 'dandonovan_ny', 'dandonovan_ny', 'RepAmata', 'RepAmata', 'NatResources', 'RepPeteAguilar', 'RepPeteAguilar', 'RepGrothman', 'RepGrothman', 'RepMiaLove', 'RepMiaLove', 'CongressmanHice', 'CongressmanHice', 'SteveKnight25', 'SteveKnight25', 'RepBuddyCarter', 'RepBuddyCarter', 'RepKathleenRice', 'RepKathleenRice', 'RepDebDingell', 'RepDebDingell', 'RepBonnie', 'RepBonnie', 'CBWGCaucus', 'RepDeSaulnier', 'RepDeSaulnier', 'transportdems', 'RepJohnKatko', 'RepJohnKatko', 'RepRussell', 'RepRussell', 'RepRubenGallego', 'RepRubenGallego', 'RepMarkWalker', 'RepMarkWalker', 'RepublicanStudy', 'RepRodBlum', 'RepRodBlum', 'GOPoversight', 'RepMcSally', 'RepMcSally', 'RepBost', 'RepBost', 'transport', 'RepAlexMooney', 'RepAlexMooney', 'financialcmte', 'RepRickAllen', 'RepRickAllen', 'SenThomTillis', 'SenThomTillis', 'HurdOnTheHill', 'HurdOnTheHill', 'TAMU', 'HouseHomeland', 'RepTomMacArthur', 'RepTomMacArthur', 'SenSasse', 'SenSasse', ' BenSasse', 'RepAbraham', 'RepAbraham', 'RepDonBeyer', 'RepDonBeyer', 'SciCmteDems', 'RepStefanik', 'RepStefanik', 'SenatorRounds', 'SenatorRounds', 'RepFrenchHill', 'RepFrenchHill', 'RepRyanCostello', 'RepRyanCostello', 'HouseCommerce', 'RepEvanJenkins', 'RepEvanJenkins', 'RepGarretGraves', 'RepGarretGraves', 'RepComstock', 'RepComstock', 'RepPoliquin', 'RepPoliquin', 'RepNewhouse', 'RepNewhouse', 'RepBrianBabin', 'RepBrianBabin', 'HouseScience', 'RepAdams', 'RepAdams', 'RepMikeBishop', 'RepMikeBishop', 'WaysandMeansGOP', 'RepTomEmmer', 'RepTomEmmer', 'RepLoudermilk', 'RepLoudermilk', 'SenDanSullivan', 'SenDanSullivan', 'repdavetrott', 'repdavetrott', 'sendavidperdue', 'sendavidperdue', 'RepLawrence', 'RepLawrence', 'RepKenBuck', 'RepKenBuck', 'USRepGaryPalmer', 'USRepGaryPalmer', 'SenJoniErnst', 'SenJoniErnst', 'RepCurbelo', 'RepCurbelo', 'RepWesterman', 'RepWesterman', 'RepRatcliffe', 'RepRatcliffe', 'HouseHomeland', 'RepLeeZeldin', 'RepLeeZeldin', 'StaceyPlaskett', 'StaceyPlaskett', 'RepMoolenaar', 'RepMoolenaar', 'RepDaveBrat', 'RepDaveBrat', 'HouseBudgetGOP', 'HouseSmallBiz', 'RepHastingsFL', 'RepHastingsFL', 'RepRobWoodall', 'RepRobWoodall', 'RepJimmyGomez', 'RepJimmyGomez', 'RepKClark', 'RepKClark', 'RepByrne', 'RepByrne', 'RepGuthrie', 'RepGuthrie', 'RepJohnDuncanJr', 'RepJohnDuncanJr', 'Transport', 'GOPoversight', 'USRepKCastor', 'USRepKCastor', 'RepBlainePress', 'RepBlainePress', 'RepJasonSmith', 'RepJasonSmith', 'RepBeatty', 'RepBeatty', 'RepSanfordSC', 'RepSanfordSC', 'USRepLong', 'USRepLong', 'PeterWelch', 'PeterWelch', 'USRepRodney', 'USRepRodney', 'HouseAppropsGOP', 'RepRobinKelly', 'RepRobinKelly', 'Rep_Hunter', 'Rep_Hunter', 'RepChrisSmith', 'RepChrisSmith', 'RepTimWalz', 'RepTimWalz', 'VetAffairsDems', 'RepJuanVargas', 'RepJuanVargas', 'SenateMajLdr', 'SenateMajLdr', 'JuliaBrownley26', 'JuliaBrownley26', 'VetAffairsDems', 'TransportDems', 'RepCardenas', 'RepCardenas', 'HouseCommerce', 'SteveScalise', 'SteveScalise', 'repmarkpocan', 'repmarkpocan', 'USProgressives', 'RepDonaldPayne', 'RepDonaldPayne', 'KeithRothfus', 'KeithRothfus', 'RepDWStweets', 'RepDWStweets', 'RepScottPeters', 'RepScottPeters', 'EnergyCommerce', 'RepBetoORourke', 'RepBetoORourke', 'RepDavidValadao', 'RepDavidValadao', 'MartinHeinrich', 'MartinHeinrich', 'SenatorRisch', 'SenatorRisch', 'RepCheri', 'RepCheri', 'RepJBridenstine', 'RepJBridenstine', 'CongressmanRuiz', 'CongressmanRuiz', 'RepAndyBarr', 'RepAndyBarr', 'RepFilemonVela', 'RepFilemonVela', 'RepSinema', 'RepSinema', 'RepBillFoster', 'RepBillFoster', 'RepRWilliams', 'RepRWilliams', 'FinancialCmte', 'RepLoisFrankel', 'RepLoisFrankel', 'HouseDemWomen', 'SenatorBaldwin', 'SenatorBaldwin', 'SenTedCruz', 'SenTedCruz', 'RepPaulCook', 'RepPaulCook', 'USMC', 'RepVeasey', 'RepVeasey', 'dallascowboys', 'SusanWBrooks', 'SusanWBrooks', 'susanwbrooks', 'RepSeanMaloney', 'RepSeanMaloney', 'RepChrisStewart', 'RepChrisStewart', 'RepTedYoho', 'RepTedYoho', 'HouseForeign', 'HouseAgNews', 'RepSchneider', 'RepSchneider', 'SenatorFischer', 'SenatorFischer', 'RepHuffman', 'RepHuffman', 'RepHuffman', 'RepLaMalfa', 'RepLaMalfa', 'RepDennyHeck', 'RepDennyHeck', 'GonzagaBulldogs', 'FSCDems', 'SenAngusKing', 'SenAngusKing', 'RepWalorski', 'RepWalorski', 'TulsiPress', 'TulsiPress', 'RepLujanGrisham', 'RepLujanGrisham', 'SenatorHeitkamp', 'SenatorHeitkamp', 'RepEsty', 'RepEsty', 'RepDougCollins', 'RepDougCollins', 'HouseJudiciary', 'RepMullin', 'RepMullin', 'RepDerekKilmer', 'RepDerekKilmer', 'RepDeSantis', 'RepDeSantis', 'RepAnnieKuster', 'RepAnnieKuster', 'SenDuckworth', 'SenDuckworth', 'RepHolding', 'RepHolding', 'RepTomRice', 'RepTomRice', 'RepChrisCollins', 'RepChrisCollins', 'HouseCommerce', 'TXRandy14', 'TXRandy14', 'RepJoeKennedy', 'RepJoeKennedy', 'RepLowenthal', 'RepLowenthal', 'USRepRickNolan', 'USRepRickNolan', 'RepAnnWagner', 'RepAnnWagner', 'RepGraceMeng', 'RepGraceMeng', 'RepKevinCramer', 'RepKevinCramer', 'HouseCommerce', 'RepLukeMesser', 'RepLukeMesser', 'RepDanKildee', 'RepDanKildee', 'FSCDems', 'RepMarkTakano', 'RepMarkTakano', 'VetAffairsDems']
#mostly_humans = list(enumerate(mostly_humans))
#mostly_humans

# %%
women_usernames = [woman[0] for woman in women]
women_usernames
# Out:
# ['lisamurkowski',
#  'SenatorBoxer',
#  'maziehirono',
#  'SenLandrieu',
#  'SenatorBarb',
#  'stabenow',
#  'amyklobuchar',
#  'clairecmc',
#  'SenatorShaheen',
#  'SenGillibrand',
#  'SenatorHagan',
#  'SenatorHeitkamp',
#  'SenFeinstein',
#  'SenatorFischer',
#  'kellyayotte',
#  'SenHydeSmith',
#  'SenTinaSmith',
#  'RepKHandel',
#  'RepJenniffer',
#  'RepJackyRosen',
#  'RepBRochester',
#  'RepBarragan',
#  'RepLizCheney',
#  'RepJayapal',
#  'SenKamalaHarris',
#  'RepValDemings',
#  'RepTenney',
#  'RepStephMurphy',
#  'RepAmata',
#  'RepMiaLove',
#  'RepKathleenRice',
#  'RepDebDingell',
#  'RepBonnie',
#  'RepMcSally',
#  'RepStefanik',
#  'RepComstock',
#  'RepAdams',
#  'RepLawrence',
#  'StaceyPlaskett',
#  'RepKClark',
#  'USRepKCastor',
#  'RepBeatty',
#  'RepRobinKelly',
#  'RepDWStweets',
#  'RepCheri',
#  'RepSinema',
#  'RepLoisFrankel',
#  'SenatorBaldwin',
#  'SusanWBrooks',
#  'RepWalorski',
#  'RepEsty']

# %%
# subtract women
mostly_men = [hum for hum in mostly_humans if hum not in women_usernames]
# remove duplicates
mostly_men = list(OrderedDict.fromkeys(mostly_men))
mostly_men
# Out:
# ['RepConorLamb',
#  'SenDougJones',
#  'RepRalphNorman',
#  'RepRonEstes',
#  'RepClayHiggins',
#  'HouseHomeland',
#  'RepScottTaylor',
#  'RepRutherfordFL',
#  'HouseJudiciary',
#  'RepMikeJohnson',
#  'NatResources',
#  'HouseSmallBiz',
#  'RepDonBacon',
#  'RepMattGaetz',
#  'RepDarrenSoto',
#  'RepGonzalez',
#  'RepAlLawsonJr',
#  'RepTomGarrett',
#  'EdWorkforce',
#  'RepTedBudd',
#  'RepEspaillat',
#  'HispanicCaucus',
#  'USProgressives',
#  'RepTomSuozzi',
#  'SenJohnKennedy',
#  'RepAndyBiggsAZ',
#  'RepBrianFitz',
#  'RepRoKhanna',
#  'RepArrington',
#  'RepKihuen',
#  'RepMcEachin',
#  'HASCDemocrats',
#  'RepCarbajal',
#  'RepJimBanks',
#  'RepRooney',
#  'RepJasonLewis',
#  'RepCharlieCrist',
#  'RepDavidKustoff',
#  'RepLouCorrea',
#  'VetAffairsDems',
#  'RepGallagher',
#  'DrNealDunnFL2',
#  'RepJohnFaso',
#  'RepJoshG',
#  'CongressmanRaja',
#  'RepBrianMast',
#  'RepTrey',
#  'RepPaulMitchell',
#  'SenCortezMasto',
#  'RepOHalleran',
#  'RepRaskin',
# ...

# %%
men_old = [('MarkUdall', 'D', '?', 'Sen'),
('SenBennetCO', 'D', '?', 'Sen'),
('ChrisMurphyCT', 'D', '?', 'Sen'),
('SenBlumenthal', 'D', '?', 'Sen'),
('SenatorCarper', 'D', '?', 'Sen'),
('ChrisCoons', 'D', '?', 'Sen'),
('SenatorDurbin', 'D', '?', 'Sen'),
('SenDonnelly', 'D', '?', 'Sen'),
('SenatorHarkin', 'D', '?', 'Sen'),
('jontester', 'D', '?', 'Sen'),
('SenatorReid', 'D', '?', 'Sen'),
('CoryBooker', 'D', '?', 'Sen'),
('SenatorMenendez', 'D', '?', 'Sen'),
('MartinHeinrich', 'D', '?', 'Sen'),
('SenatorTomUdall', 'D', '?', 'Sen'),
('SenSchumer', 'D', '?', 'Sen'),
('SenJohnMcCain', 'R', '?', 'Sen'),
('JeffFlake', 'R', '?', 'Sen'),
('JohnBoozman', 'R', '?', 'Sen'),
('marcorubio', 'R', '?', 'Sen'),
('SaxbyChambliss', 'R', '?', 'Sen'),
('brianschatz', 'R', '?', 'Sen'),
('MikeCrapo', 'R', '?', 'Sen'),
('SenatorRisch', 'R', '?', 'Sen'),
('SenDanCoats', 'R', '?', 'Sen'),
('ChuckGrassley', 'R', '?', 'Sen'),
('SenPatRoberts', 'R', '?', 'Sen'),
('JerryMoran', 'R', '?', 'Sen'),
('SenRandPaul', 'R', '?', 'Sen'),
('DavidVitter', 'R', '?', 'Sen'),
('SenatorWicker', 'R', '?', 'Sen'),
('RoyBlunt', 'R', '?', 'Sen'),
('SenDeanHeller', 'R', '?', 'Sen'),
('SenatorBurr', 'R', '?', 'Sen')]

# %%
men_new_reps = [
('RepConorLamb', '?', '?', 'Rep'),
('RepRalphNorman', '?', '?', 'Rep'),
('RepRonEstes', '?', '?', 'Rep'),
('RepClayHiggins', '?', '?', 'Rep'),
('RepScottTaylor', '?', '?', 'Rep'),
('RepRutherfordFL', '?', '?', 'Rep'),
('RepMikeJohnson', '?', '?', 'Rep'),
('RepDonBacon', '?', '?', 'Rep'),
('RepMattGaetz', '?', '?', 'Rep'),
('RepDarrenSoto', '?', '?', 'Rep'),
('RepGonzalez', '?', '?', 'Rep'),
('RepAlLawsonJr', '?', '?', 'Rep'),
('RepTomGarrett', '?', '?', 'Rep'),
('RepTedBudd', '?', '?', 'Rep'),
('RepEspaillat', '?', '?', 'Rep'),
('RepTomSuozzi', '?', '?', 'Rep'),
('RepAndyBiggsAZ', '?', '?', 'Rep'),
('RepBrianFitz', '?', '?', 'Rep'),
('RepRoKhanna', '?', '?', 'Rep'),
('RepArrington', '?', '?', 'Rep'),
('RepKihuen', '?', '?', 'Rep'),
('RepMcEachin', '?', '?', 'Rep'),
('RepChrisSmith', '?', '?', 'Rep'),
('RepTimWalz', '?', '?', 'Rep'),
('RepJuanVargas', '?', '?', 'Rep'),
('RepCardenas', '?', '?', 'Rep'),
('repmarkpocan', '?', '?', 'Rep'),
('RepDonaldPayne', '?', '?', 'Rep'),
('RepScottPeters', '?', '?', 'Rep'),
('RepBetoORourke', '?', '?', 'Rep'),
('RepDavidValadao', '?', '?', 'Rep'),
('RepJBridenstine', '?', '?', 'Rep'),
('RepAndyBarr', '?', '?', 'Rep'),
('RepFilemonVela', '?', '?', 'Rep'),
('RepBillFoster', '?', '?', 'Rep'),
('RepRWilliams', '?', '?', 'Rep'),
('RepPaulCook', '?', '?', 'Rep'),
('RepVeasey', '?', '?', 'Rep'),
('RepSeanMaloney', '?', '?', 'Rep'),
('RepChrisStewart', '?', '?', 'Rep'),
('RepTedYoho', '?', '?', 'Rep'),
('RepSchneider', '?', '?', 'Rep'),
('RepHuffman', '?', '?', 'Rep'),
('RepLaMalfa', '?', '?', 'Rep'),
('RepDennyHeck', '?', '?', 'Rep'),
('RepLujanGrisham', '?', '?', 'Rep'),
('RepDougCollins', '?', '?', 'Rep'),
('RepMullin', '?', '?', 'Rep'),
('RepDerekKilmer', '?', '?', 'Rep'),
('RepDeSantis', '?', '?', 'Rep'),
('RepAnnieKuster', '?', '?', 'Rep'),
('RepHolding', '?', '?', 'Rep'),
('RepTomRice', '?', '?', 'Rep'),
('RepChrisCollins', '?', '?', 'Rep'),
('RepJoeKennedy', '?', '?', 'Rep'),
('RepLowenthal', '?', '?', 'Rep'),
('RepAnnWagner', '?', '?', 'Rep'),
('RepGraceMeng', '?', '?', 'Rep'),
('RepKevinCramer', '?', '?', 'Rep'),
('RepLukeMesser', '?', '?', 'Rep'),
('RepDanKildee', '?', '?', 'Rep'),
('RepMarkTakano', '?', '?', 'Rep')]

# %%
import numpy as np
np.random.seed(10)

# %%
indices = np.random.choice(list(range(len(men_old))), 19, replace=False)

# %%
indices = sorted(indices)

# %%
men_old_min = [men_old[idx] for idx in indices]
men_old_min
# Out:
# [('SenBennetCO', 'D', '?', 'Sen'),
#  ('ChrisMurphyCT', 'D', '?', 'Sen'),
#  ('SenBlumenthal', 'D', '?', 'Sen'),
#  ('ChrisCoons', 'D', '?', 'Sen'),
#  ('SenatorDurbin', 'D', '?', 'Sen'),
#  ('SenDonnelly', 'D', '?', 'Sen'),
#  ('CoryBooker', 'D', '?', 'Sen'),
#  ('SenatorMenendez', 'D', '?', 'Sen'),
#  ('MartinHeinrich', 'D', '?', 'Sen'),
#  ('SenatorTomUdall', 'D', '?', 'Sen'),
#  ('JohnBoozman', 'R', '?', 'Sen'),
#  ('marcorubio', 'R', '?', 'Sen'),
#  ('SaxbyChambliss', 'R', '?', 'Sen'),
#  ('brianschatz', 'R', '?', 'Sen'),
#  ('MikeCrapo', 'R', '?', 'Sen'),
#  ('SenatorRisch', 'R', '?', 'Sen'),
#  ('SenPatRoberts', 'R', '?', 'Sen'),
#  ('DavidVitter', 'R', '?', 'Sen'),
#  ('SenDeanHeller', 'R', '?', 'Sen')]

# %%
indices = np.random.choice(list(range(len(men_new_reps))), 32, replace=False)

# %%
indices = sorted(indices)

# %%
men_new_reps_min = [men_new_reps[idx] for idx in indices]
men_new_reps_min
# Out:
# [('RepRalphNorman', '?', '?', 'Rep'),
#  ('RepRonEstes', '?', '?', 'Rep'),
#  ('RepMattGaetz', '?', '?', 'Rep'),
#  ('RepGonzalez', '?', '?', 'Rep'),
#  ('RepTedBudd', '?', '?', 'Rep'),
#  ('RepArrington', '?', '?', 'Rep'),
#  ('RepMcEachin', '?', '?', 'Rep'),
#  ('RepRooney', '?', '?', 'Rep'),
#  ('RepOHalleran', '?', '?', 'Rep'),
#  ('RepJimmyPanetta', '?', '?', 'Rep'),
#  ('RepMarshall', '?', '?', 'Rep'),
#  ('RepTedLieu', '?', '?', 'Rep'),
#  ('RepAlexMooney', '?', '?', 'Rep'),
#  ('RepAbraham', '?', '?', 'Rep'),
#  ('RepFrenchHill', '?', '?', 'Rep'),
#  ('RepGarretGraves', '?', '?', 'Rep'),
#  ('RepBrianBabin', '?', '?', 'Rep'),
#  ('RepMikeBishop', '?', '?', 'Rep'),
#  ('RepRobWoodall', '?', '?', 'Rep'),
#  ('RepByrne', '?', '?', 'Rep'),
#  ('RepJohnDuncanJr', '?', '?', 'Rep'),
#  ('RepJasonSmith', '?', '?', 'Rep'),
#  ('RepJuanVargas', '?', '?', 'Rep'),
#  ('RepCardenas', '?', '?', 'Rep'),
#  ('RepBetoORourke', '?', '?', 'Rep'),
#  ('RepJBridenstine', '?', '?', 'Rep'),
# ...

# %%
men_match_women = men_old_min + men_new_reps_min

# %%
len(men_match_women)
# Out:
# 51

# %%
men_match_women
# Out:
# [('SenBennetCO', 'D', '?', 'Sen'),
#  ('ChrisMurphyCT', 'D', '?', 'Sen'),
#  ('SenBlumenthal', 'D', '?', 'Sen'),
#  ('ChrisCoons', 'D', '?', 'Sen'),
#  ('SenatorDurbin', 'D', '?', 'Sen'),
#  ('SenDonnelly', 'D', '?', 'Sen'),
#  ('CoryBooker', 'D', '?', 'Sen'),
#  ('SenatorMenendez', 'D', '?', 'Sen'),
#  ('MartinHeinrich', 'D', '?', 'Sen'),
#  ('SenatorTomUdall', 'D', '?', 'Sen'),
#  ('JohnBoozman', 'R', '?', 'Sen'),
#  ('marcorubio', 'R', '?', 'Sen'),
#  ('SaxbyChambliss', 'R', '?', 'Sen'),
#  ('brianschatz', 'R', '?', 'Sen'),
#  ('MikeCrapo', 'R', '?', 'Sen'),
#  ('SenatorRisch', 'R', '?', 'Sen'),
#  ('SenPatRoberts', 'R', '?', 'Sen'),
#  ('DavidVitter', 'R', '?', 'Sen'),
#  ('SenDeanHeller', 'R', '?', 'Sen'),
#  ('RepRalphNorman', '?', '?', 'Rep'),
#  ('RepRonEstes', '?', '?', 'Rep'),
#  ('RepMattGaetz', '?', '?', 'Rep'),
#  ('RepGonzalez', '?', '?', 'Rep'),
#  ('RepTedBudd', '?', '?', 'Rep'),
#  ('RepArrington', '?', '?', 'Rep'),
#  ('RepMcEachin', '?', '?', 'Rep'),
# ...
