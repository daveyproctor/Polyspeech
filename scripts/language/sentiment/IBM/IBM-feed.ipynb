# %% [markdown]
# ## New analysis

# %% [markdown]
# Analyzes text, HTML, or a public webpage for the following features:
#         - Categories
#         - Concepts
#         - Emotion
#         - Entities
#         - Keywords
#         - Metadata
#         - Relations
#         - Semantic roles
#         - Sentiment.

# %%
import codecs
import json
import glob
import numpy as np
import pandas as pd
import sys; sys.path.append("/Users/daveyproctor/Documents/Polyspeech/"); from lib.progress import ProgressTracker
import pprint as pp

# %%
with open("IBM.key") as fp:
    key = json.load(fp)

# %%
from __future__ import print_function
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions, EmotionOptions
from watson_developer_cloud import natural_language_understanding_v1
service = NaturalLanguageUnderstandingV1(
    version='2018-03-16',
    ## url is optional, and defaults to the URL below. Use the correct URL for your region.
    # url='https://gateway.watsonplatform.net/natural-language-understanding/api',
    iam_apikey=key["apikey"],
)

# %%
KeywordsOptions?

# %%
# Test
response = service.analyze(
    text='Bruce Banner is the Hulk and Bruce Wayne is BATMAN! '
    'Superman fears not Banner, but Wayne.',
    features=Features(entities=EntitiesOptions(),
                      keywords=KeywordsOptions(emotion=True))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 89,
#     "features": 2
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "Bruce Banner",
#       "relevance": 0.999938,
#       "emotion": {
#         "sadness": 0.110184,
#         "joy": 0.279904,
#         "fear": 0.072589,
#         "disgust": 0.082855,
#         "anger": 0.123095
#       },
#       "count": 1
#     },
#     {
#       "text": "Bruce Wayne",
#       "relevance": 0.984803,
#       "emotion": {
#         "sadness": 0.110184,
#         "joy": 0.279904,
#         "fear": 0.072589,
#         "disgust": 0.082855,
#         "anger": 0.123095
#       },
#       "count": 1
#     },
#     {
#       "text": "Superman fears",
#       "relevance": 0.974561,
#       "emotion": {
#         "sadness": 0.141719,
#         "joy": 0.193744,
#         "fear": 0.077596,
#         "disgust": 0.07352,
#         "anger": 0.083215
#       },
#       "count": 1
#     },
#     {
#       "text": "Hulk",
#       "relevance": 0.691614,
#       "emotion": {
#         "sadness": 0.110184,
#         "joy": 0.279904,
#         "fear": 0.072589,
#         "disgust": 0.082855,
#         "anger": 0.123095
#       },
#       "count": 1
#     },
#     {
#       "text": "Banner",
#       "relevance": 0.644681,
#       "emotion": {
#         "sadness": 0.101967,
#         "joy": 0.304163,
#         "fear": 0.065787,
#         "disgust": 0.083401,
#         "anger": 0.121029
#       },
#       "count": 1
#     },
#     {
#       "text": "BATMAN",
#       "relevance": 0.568413,
#       "emotion": {
#         "sadness": 0.110184,
#         "joy": 0.279904,
#         "fear": 0.072589,
#         "disgust": 0.082855,
#         "anger": 0.123095
#       },
#       "count": 1
#     },
#     {
#       "text": "Wayne",
#       "relevance": 0.54164,
#       "emotion": {
#         "sadness": 0.101967,
#         "joy": 0.304163,
#         "fear": 0.065787,
#         "disgust": 0.083401,
#         "anger": 0.121029
#       },
#       "count": 1
#     }
#   ],
#   "entities": [
#     {
#       "type": "Person",
#       "text": "Bruce Banner",
#       "relevance": 0.931351,
#       "count": 3
#     },
#     {
#       "type": "Person",
#       "text": "Wayne",
#       "relevance": 0.288696,
#       "count": 1
#     }
#   ]
# }

# %%
response = service.analyze(
    text="#TrumpShutdown not just about federal workers, it‚Äôs about all of us.  If we fly, safety &amp; delays at airports; if we file tax return, no one to process &amp; delays in refund check; if a Senior or veteran applying for assistance,  no one to process &amp; delay in checks.  #EndShutdown https://t.co/g16aYNihPU",
    features=Features(entities=EntitiesOptions(emotion=True),
                      keywords=KeywordsOptions(emotion=True))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 314,
#     "features": 2
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "refund check",
#       "relevance": 0.799199,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 1
#     },
#     {
#       "text": "veteran applying",
#       "relevance": 0.76639,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 1
#     },
#     {
#       "text": "tax return",
#       "relevance": 0.753577,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 1
#     },
#     {
#       "text": "amp",
#       "relevance": 0.641856,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 3
#     },
#     {
#       "text": "delays",
#       "relevance": 0.63809,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 2
#     },
#     {
#       "text": "federal workers",
#       "relevance": 0.599981,
#       "emotion": {
#         "sadness": 0.366906,
#         "joy": 0.052989,
#         "fear": 0.036153,
#         "disgust": 0.071718,
#         "anger": 0.169086
#       },
#       "count": 1
#     },
#     {
#       "text": "process",
#       "relevance": 0.597316,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 2
#     },
#     {
#       "text": "airports",
#       "relevance": 0.574102,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 1
#     },
#     {
#       "text": "safety",
#       "relevance": 0.573192,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 1
#     },
#     {
#       "text": "assistance",
#       "relevance": 0.564854,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 1
#     },
#     {
#       "text": "delay",
#       "relevance": 0.547117,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 1
#     },
#     {
#       "text": "checks",
#       "relevance": 0.539272,
#       "emotion": {
#         "sadness": 0.366532,
#         "joy": 0.022868,
#         "fear": 0.051608,
#         "disgust": 0.143132,
#         "anger": 0.09215
#       },
#       "count": 1
#     },
#     {
#       "text": "\u00c4\u00f4s",
#       "relevance": 0.333999,
#       "emotion": {
#         "sadness": 0.366906,
#         "joy": 0.052989,
#         "fear": 0.036153,
#         "disgust": 0.071718,
#         "anger": 0.169086
#       },
#       "count": 1
#     }
#   ],
#   "entities": [
#     {
#       "type": "Hashtag",
#       "text": "#TrumpShutdown",
#       "relevance": 0.01,
#       "count": 1
#     },
#     {
#       "type": "Hashtag",
#       "text": "#EndShutdown",
#       "relevance": 0.01,
#       "count": 1
#     }
#   ]
# }

# %% [markdown]
# ## Picks up from extractTweets

# %%
dataDir="/Users/daveyproctor/Documents/Polyspeech/data/"

# %%
tweetsDF = pd.read_csv(f"{dataDir}tweets/RepAbrahamBefore2018.csv")

# %%
tweetsDF
# Out:
#          tweet_id         time_created  \
# 0    1.059478e+18  2018-11-05 16:09:51
# 1    1.058730e+18  2018-11-03 14:35:58
# 2    1.055481e+18  2018-10-25 15:28:13
# 3    1.055185e+18  2018-10-24 19:50:22
# 4    1.055185e+18  2018-10-24 19:49:51
# 5    1.053811e+18  2018-10-21 00:52:54
# 6    1.053341e+18  2018-10-19 17:42:10
# 7    1.052958e+18  2018-10-18 16:21:29
# 8    1.052600e+18  2018-10-17 16:40:05
# 9    1.050402e+18  2018-10-11 15:03:50
# 10   1.050048e+18  2018-10-10 15:39:53
# 11   1.049711e+18  2018-10-09 17:17:52
# 12   1.048631e+18  2018-10-06 17:47:43
# 13   1.048304e+18  2018-10-05 20:06:57
# 14   1.048297e+18  2018-10-05 19:40:00
# 15   1.047586e+18  2018-10-03 20:35:00
# 16   1.046833e+18  2018-10-01 18:43:42
# 17   1.046401e+18  2018-09-30 14:05:01
# 18   1.045687e+18  2018-09-28 14:51:42
# 19   1.045447e+18  2018-09-27 22:54:15
# 20   1.045345e+18  2018-09-27 16:12:09
# 21   1.045072e+18  2018-09-26 22:04:13
# 22   1.045072e+18  2018-09-26 22:04:12
# 23   1.045002e+18  2018-09-26 17:26:08
# 24   1.044972e+18  2018-09-26 15:28:24
# 25   1.044637e+18  2018-09-25 17:15:57
# 26   1.044256e+18  2018-09-24 16:01:56
# 27   1.043171e+18  2018-09-21 16:13:51
# 28   1.042448e+18  2018-09-19 16:19:17
# 29   1.042195e+18  2018-09-18 23:35:17
# ..            ...                  ...
# 235  9.794481e+17  2018-03-29 20:00:02
# 236  9.794179e+17  2018-03-29 18:00:01
# 237  9.794095e+17  2018-03-29 17:26:25
# 238  9.793877e+17  2018-03-29 16:00:01
# 239  9.790203e+17  2018-03-28 15:40:01
# 240  9.787101e+17  2018-03-27 19:07:31
# 241  9.786751e+17  2018-03-27 16:48:13
# 242  9.776038e+17  2018-03-24 17:51:35
# 243  9.771816e+17  2018-03-23 13:53:49
# 244  9.768709e+17  2018-03-22 17:19:11
# 245  9.768709e+17  2018-03-22 17:18:56
# 246  9.766304e+17  2018-03-22 01:23:38
# 247  9.761420e+17  2018-03-20 17:02:44
# 248  9.761210e+17  2018-03-20 15:39:26
# 249  9.757856e+17  2018-03-19 17:26:32
# 250  9.757613e+17  2018-03-19 15:50:03
# 251  9.757427e+17  2018-03-19 14:35:56
# 252  9.750271e+17  2018-03-17 15:12:31
# 253  9.743682e+17  2018-03-15 19:34:12
# 254  9.736067e+17  2018-03-13 17:08:25
# 255  9.735710e+17  2018-03-13 14:46:24
# 256  9.735708e+17  2018-03-13 14:45:47
# 257  9.735649e+17  2018-03-13 14:22:24
# 258  9.733587e+17  2018-03-13 00:42:58
# 259  9.732044e+17  2018-03-12 14:29:49
# 260  9.725860e+17  2018-03-10 21:32:17
# 261  9.717715e+17  2018-03-08 15:35:58
# 262  9.711157e+17  2018-03-06 20:10:08
# 263  9.711074e+17  2018-03-06 19:36:53
# 264  9.710777e+17  2018-03-06 17:39:07
#
#                                              full_text  is_retweet  \
# 0    Dianne and I were thrilled to join my granddau...       False
# 1    Today is the day! #GeauxTigers https://t.co/B8...       False
# 2    RT @tmcclelland: Incredibly grateful to give t...        True
# 3    RT @nfib_la: Thank you to our Guardians of Sma...        True
# 4    RT @ScottFranklinJr: Incredible tour of the Ir...        True
# 5    Great seeing my friends @RepMikeJohnson and hi...       False
# 6    Democrats want to abolish ICE, but I like that...       False
# 7    Thanks Gen. Frank for inviting me to participa...       False
# 8    #LA05 is the largest recipient ($1.12 million)...       False
# 9    .@4H Clubs help our kids grow as people and le...       False
# 10   Back on the ground after penetrating the eye o...       False
# 11   .@nikkihaley has been outstanding representing...       False
# 12   Huge congrats to @LaTech student Mason Andrews...       False
# 13   RT @usaricenews: US rice sale of 90k MT to Ira...        True
# 14   This weekend, we remember &amp; honor firefigh...       False
# 15   Tomorrow is Bring Your Bible to School Day and...       False
# 16   Throughout October, Americans will don the col...       False
# 17   Today we honor Gold Star Mothers across the na...       False
# 18   Senate Democrat - the only job in America wher...       False
# 19   I make decisions based on evidence &amp; data....       False
# 20   September is #NationalRiceMonth and very few p...       False
# 21   2) deficits grow, and the House goes along wit...       False
# 22   1) I voted NO on this latest spending bill. It...       False
# 23   RT @15thSMA: Thank you to @RepAbraham &amp; yo...        True
# 24   I called on the FDA to cancel a contract w/ a ...       False
# 25   Retired Marine Lt. Col. Robert Miller of Bogal...       False
# 26   Excited to announce that @ULM_Official receive...       False
# 27   Outside of my D.C. office, the POW-MIA flag st...       False
# 28   I spoke with @KALBtv5 about Kavanaugh, his acc...       False
# 29   RT @DeptofDefense: Today marks 71 years of #Ai...        True
# ..                                                 ...         ...
# 235  More from my interview with @KALBtv5. I'll nev...       False
# 236  More from my interview with @KALBtv5 - The VA ...       False
# 237  We can never say "Thank You!" enough to our na...       False
# 238  I spoke with @KALBtv5 about changes to #Census...       False
# 239  It is common sense that the Census should ask ...       False
# 240  Here's a great story about a CenLa resident, H...       False
# 241  I commend Attorney General @JeffLandry and his...       False
# 242  Today I spoke at the @LANationalGuard Youth Ch...       False
# 243  President Trump is considering a veto of the o...       False
# 244  (2/2) rather than focusing on the money our mi...       False
# 245  (1/2) This 2,200 page omnibus dropped less tha...       False
# 246  An honor to accept the @AOPA Hartranft Award w...       False
# 247  I stand w/ @NIFLA &amp; #ProLife pregnancy cen...       False
# 248  Thanks to @VP Mike Pence for speaking to young...       False
# 249  Enjoyed meeting with instructors from @LADelta...       False
# 250  CORRECTION: Congress shouldn't* be involved in...       False
# 251  Congress should be involved in attempting to o...       False
# 252  RT @realDonaldTrump: Andrew McCabe FIRED, a gr...        True
# 253  Great meeting today with @usairforce Secretary...       False
# 254  I spoke on the House floor to recognize the li...       False
# 255  Not only is she the most qualified, Ms. Haspel...       False
# 256  A very bold &amp; positive move by Pres. Trump...       False
# 257  RT @SecretaryPerry: The men and women of the C...        True
# 258  This is exactly what I’ve been saying since Da...       False
# 259  I signed onto this letter to have the #Conscie...       False
# 260  Enjoyed spending part of the day in Bogalusa a...       False
# 261  I spoke w/ @KTBS news about how the budget bil...       False
# 262  RT @woodcouncil: .@RepAbraham, TY for being an...        True
# 263  Great meeting today with the Ouachita River Va...       False
# 264  Congratulations to Terry Doughty, the new U.S....       False
#
#      retweet_count  favorite_count  hashtag_count  \
# 0              1.0            21.0              1
# 1              5.0            39.0              1
# 2              1.0             NaN              0
# 3             13.0             NaN              0
# 4              9.0             NaN              0
# 5              7.0            27.0              2
# 6              6.0            30.0              1
# 7              3.0            14.0              1
# 8              3.0            12.0              1
# 9              2.0            12.0              2
# 10             4.0            10.0              1
# 11             5.0            24.0              0
# 12            43.0           177.0              3
# 13            15.0             NaN              0
# 14             1.0             9.0              0
# 15            27.0            79.0              0
# 16             1.0             4.0              0
# 17             4.0            19.0              0
# 18            57.0           129.0              2
# 19            32.0           104.0              1
# 20             8.0            15.0              4
# 21             NaN             8.0              1
# 22             2.0            11.0              0
# 23            15.0             NaN              1
# 24             8.0            16.0              1
# 25             3.0            10.0              2
# 26             3.0            14.0              1
# 27             2.0             8.0              1
# 28             6.0            15.0              1
# 29          1646.0             NaN              3
# ..             ...             ...            ...
# 235            6.0            11.0              2
# 236            2.0             7.0              2
# 237           11.0            26.0              2
# 238            5.0            12.0              3
# 239           12.0            42.0              1
# 240            5.0             7.0              1
# 241            4.0            12.0              0
# 242            5.0            18.0              0
# 243            7.0            16.0              1
# 244            7.0             9.0              0
# 245           12.0            10.0              0
# 246            5.0            24.0              1
# 247            3.0             4.0              3
# 248           18.0            28.0              2
# 249            4.0            16.0              1
# 250            1.0             1.0              0
# 251            5.0             1.0              1
# 252        44012.0             NaN              0
# 253            5.0            14.0              1
# 254            6.0             8.0              1
# 255           13.0            17.0              0
# 256           11.0            14.0              0
# 257         1117.0             NaN              0
# 258            7.0            18.0              0
# 259            3.0            10.0              2
# 260            3.0            16.0              1
# 261            5.0             6.0              1
# 262            1.0             NaN              1
# 263            2.0             3.0              1
# 264           14.0            27.0              0
#
#                          hashtags0           hashtags1    hashtags2  ...  \
# 0                             LA05                 NaN          NaN  ...
# 1                      GeauxTigers                 NaN          NaN  ...
# 2                              NaN                 NaN          NaN  ...
# 3                              NaN                 NaN          NaN  ...
# 4                              NaN                 NaN          NaN  ...
# 5                             HBTD                LA05          NaN  ...
# 6                             LA05                 NaN          NaN  ...
# 7                             LA05                 NaN          NaN  ...
# 8                             LA05                 NaN          NaN  ...
# 9                   National4HWeek                LA05          NaN  ...
# 10                            LA05                 NaN          NaN  ...
# 11                             NaN                 NaN          NaN  ...
# 12                            la05                HBTD  EverLoyalBe  ...
# 13                             NaN                 NaN          NaN  ...
# 14                             NaN                 NaN          NaN  ...
# 15                             NaN                 NaN          NaN  ...
# 16                             NaN                 NaN          NaN  ...
# 17                             NaN                 NaN          NaN  ...
# 18                            LA05    ConfirmKavanaugh          NaN  ...
# 19                            LA05                 NaN          NaN  ...
# 20               NationalRiceMonth           Louisiana    ThinkRice  ...
# 21                            LA05                 NaN          NaN  ...
# 22                             NaN                 NaN          NaN  ...
# 23                        Soldiers                 NaN          NaN  ...
# 24                            LA05                 NaN          NaN  ...
# 25                       Louisiana                LA05          NaN  ...
# 26                            LA05                 NaN          NaN  ...
# 27            POWMIARecognitionDay                 NaN          NaN  ...
# 28                            LA05                 NaN          NaN  ...
# 29                        AirForce              AFBday         AF71  ...
# ..                             ...                 ...          ...  ...
# 235                             2A                LA05          NaN  ...
# 236                       Veterans                LA05          NaN  ...
# 237  NationalVietnamWarVeteransDay                LA05          NaN  ...
# 238                     Census2020              Census         LA05  ...
# 239                           LA05                 NaN          NaN  ...
# 240                           LA05                 NaN          NaN  ...
# 241                            NaN                 NaN          NaN  ...
# 242                            NaN                 NaN          NaN  ...
# 243                           la05                 NaN          NaN  ...
# 244                            NaN                 NaN          NaN  ...
# 245                            NaN                 NaN          NaN  ...
# 246                           la05                 NaN          NaN  ...
# 247                        ProLife  GiveFreeSpeechLife         LA05  ...
# 248                  NationalAgDay                LA05          NaN  ...
# 249                           la05                 NaN          NaN  ...
# 250                            NaN                 NaN          NaN  ...
# 251                           LA05                 NaN          NaN  ...
# 252                            NaN                 NaN          NaN  ...
# 253                           LA05                 NaN          NaN  ...
# 254                           LA05                 NaN          NaN  ...
# 255                            NaN                 NaN          NaN  ...
# 256                            NaN                 NaN          NaN  ...
# 257                            NaN                 NaN          NaN  ...
# 258                            NaN                 NaN          NaN  ...
# 259        ConscienceProtectionAct                LA05          NaN  ...
# 260                           LA05                 NaN          NaN  ...
# 261                           LA05                 NaN          NaN  ...
# 262               TimberInnovation                 NaN          NaN  ...
# 263                           LA05                 NaN          NaN  ...
# 264                            NaN                 NaN          NaN  ...
#
#     user_mentions2  user_mentions3   user_mentions4 in_reply_to_screen_name  \
# 0              NaN             NaN              NaN                     NaN
# 1              NaN             NaN              NaN                     NaN
# 2              NaN             NaN              NaN                     NaN
# 3    JohnKennedyLA    SteveScalise  RepGarretGraves                     NaN
# 4              NaN             NaN              NaN                     NaN
# 5              NaN             NaN              NaN                     NaN
# 6              NaN             NaN              NaN                     NaN
# 7              NaN             NaN              NaN                     NaN
# 8              NaN             NaN              NaN                     NaN
# 9              NaN             NaN              NaN                     NaN
# 10             NaN             NaN              NaN                     NaN
# 11             NaN             NaN              NaN                     NaN
# 12             NaN             NaN              NaN                     NaN
# 13       StateDept      RepAbraham  RepRickCrawford                     NaN
# 14             NaN             NaN              NaN                     NaN
# 15             NaN             NaN              NaN                     NaN
# 16             NaN             NaN              NaN                     NaN
# 17             NaN             NaN              NaN                     NaN
# 18             NaN             NaN              NaN                     NaN
# 19             NaN             NaN              NaN                     NaN
# 20             NaN             NaN              NaN                     NaN
# 21             NaN             NaN              NaN              RepAbraham
# 22             NaN             NaN              NaN                     NaN
# 23             NaN             NaN              NaN                     NaN
# 24             NaN             NaN              NaN                     NaN
# 25             NaN             NaN              NaN                     NaN
# 26             NaN             NaN              NaN                     NaN
# 27             NaN             NaN              NaN                     NaN
# 28             NaN             NaN              NaN                     NaN
# 29             NaN             NaN              NaN                     NaN
# ..             ...             ...              ...                     ...
# 235            NaN             NaN              NaN                     NaN
# 236            NaN             NaN              NaN                     NaN
# 237            NaN             NaN              NaN                     NaN
# 238            NaN             NaN              NaN                     NaN
# 239            NaN             NaN              NaN                     NaN
# 240            NaN             NaN              NaN                     NaN
# 241            NaN             NaN              NaN                     NaN
# 242            NaN             NaN              NaN                     NaN
# 243            NaN             NaN              NaN                     NaN
# 244            NaN             NaN              NaN              RepAbraham
# 245            NaN             NaN              NaN                     NaN
# 246            NaN             NaN              NaN                     NaN
# 247            NaN             NaN              NaN                     NaN
# 248            NaN             NaN              NaN                     NaN
# 249            NaN             NaN              NaN                     NaN
# 250            NaN             NaN              NaN              RepAbraham
# 251            NaN             NaN              NaN                     NaN
# 252            NaN             NaN              NaN                     NaN
# 253            NaN             NaN              NaN                     NaN
# 254            NaN             NaN              NaN                     NaN
# 255            NaN             NaN              NaN              RepAbraham
# 256            NaN             NaN              NaN                     NaN
# 257            NaN             NaN              NaN                     NaN
# 258            NaN             NaN              NaN                     NaN
# 259            NaN             NaN              NaN                     NaN
# 260            NaN             NaN              NaN                     NaN
# 261            NaN             NaN              NaN                     NaN
# 262    MyArkLaMiss             NaN              NaN                     NaN
# 263            NaN             NaN              NaN                     NaN
# 264            NaN             NaN              NaN                     NaN
#
#     in_reply_to_status_id vader_pos vader_neg vader_neu vader_compound  \
# 0                     NaN     0.159     0.000     0.841         0.6249
# 1                     NaN     0.000     0.000     1.000         0.0000
# 2                     NaN     0.130     0.000     0.870         0.5095
# 3                     NaN     0.143     0.000     0.857         0.3612
# 4                     NaN     0.127     0.000     0.873         0.4939
# 5                     NaN     0.298     0.000     0.702         0.8020
# 6                     NaN     0.166     0.156     0.678        -0.1901
# 7                     NaN     0.183     0.107     0.711         0.5423
# 8                     NaN     0.034     0.000     0.966         0.0772
# 9                     NaN     0.234     0.000     0.766         0.9057
# 10                    NaN     0.270     0.000     0.730         0.8750
# 11                    NaN     0.191     0.051     0.758         0.7787
# 12                    NaN     0.331     0.000     0.669         0.9078
# 13                    NaN     0.121     0.000     0.879         0.4404
# 14                    NaN     0.161     0.082     0.756         0.6908
# 15                    NaN     0.375     0.000     0.625         0.9595
# 16                    NaN     0.084     0.284     0.632        -0.9360
# 17                    NaN     0.294     0.086     0.619         0.8555
# 18                    NaN     0.138     0.201     0.662        -0.3971
# 19                    NaN     0.000     0.127     0.873        -0.7162
# 20                    NaN     0.085     0.038     0.876         0.2732
# 21           1.045072e+18     0.000     0.000     1.000         0.0000
# 22                    NaN     0.106     0.130     0.764        -0.0343
# 23                    NaN     0.299     0.000     0.701         0.8555
# 24                    NaN     0.057     0.210     0.733        -0.7717
# 25                    NaN     0.119     0.073     0.808         0.3164
# 26                    NaN     0.206     0.000     0.794         0.8555
# 27                    NaN     0.000     0.083     0.917        -0.4404
# 28                    NaN     0.190     0.102     0.708         0.6908
# 29                    NaN     0.277     0.000     0.723         0.7845
# ..                    ...       ...       ...       ...            ...
# 235                   NaN     0.090     0.094     0.816        -0.0572
# 236                   NaN     0.300     0.000     0.700         0.9432
# 237                   NaN     0.124     0.161     0.715        -0.3476
# 238                   NaN     0.057     0.000     0.943         0.3818
# 239                   NaN     0.000     0.000     1.000         0.0000
# 240                   NaN     0.307     0.000     0.693         0.9430
# 241                   NaN     0.100     0.000     0.900         0.4404
# 242                   NaN     0.254     0.000     0.746         0.9062
# 243                   NaN     0.062     0.060     0.878         0.0258
# 244          9.768709e+17     0.049     0.099     0.852        -0.3612
# 245                   NaN     0.000     0.077     0.923        -0.4939
# 246                   NaN     0.225     0.000     0.775         0.9100
# 247                   NaN     0.101     0.215     0.684        -0.6124
# 248                   NaN     0.309     0.000     0.691         0.9246
# 249                   NaN     0.273     0.000     0.727         0.7579
# 250          9.757427e+17     0.000     0.000     1.000         0.0000
# 251                   NaN     0.072     0.000     0.928         0.4939
# 252                   NaN     0.257     0.180     0.564         0.5372
# 253                   NaN     0.089     0.043     0.868         0.4767
# 254                   NaN     0.000     0.062     0.937        -0.2960
# 255          9.735708e+17     0.217     0.000     0.783         0.8814
# 256                   NaN     0.305     0.000     0.695         0.9144
# 257                   NaN     0.091     0.132     0.777        -0.2960
# 258                   NaN     0.000     0.164     0.836        -0.5707
# 259                   NaN     0.242     0.000     0.758         0.8364
# 260                   NaN     0.218     0.053     0.729         0.7619
# 261                   NaN     0.120     0.031     0.850         0.6239
# 262                   NaN     0.331     0.000     0.669         0.7118
# 263                   NaN     0.117     0.000     0.883         0.6249
# 264                   NaN     0.213     0.000     0.787         0.8070
#
#      twitter_account
# 0         RepAbraham
# 1         RepAbraham
# 2         RepAbraham
# 3         RepAbraham
# 4         RepAbraham
# 5         RepAbraham
# 6         RepAbraham
# 7         RepAbraham
# 8         RepAbraham
# 9         RepAbraham
# 10        RepAbraham
# 11        RepAbraham
# 12        RepAbraham
# 13        RepAbraham
# 14        RepAbraham
# 15        RepAbraham
# 16        RepAbraham
# 17        RepAbraham
# 18        RepAbraham
# 19        RepAbraham
# 20        RepAbraham
# 21        RepAbraham
# 22        RepAbraham
# 23        RepAbraham
# 24        RepAbraham
# 25        RepAbraham
# 26        RepAbraham
# 27        RepAbraham
# 28        RepAbraham
# 29        RepAbraham
# ..               ...
# 235       RepAbraham
# 236       RepAbraham
# 237       RepAbraham
# 238       RepAbraham
# 239       RepAbraham
# 240       RepAbraham
# 241       RepAbraham
# 242       RepAbraham
# 243       RepAbraham
# 244       RepAbraham
# 245       RepAbraham
# 246       RepAbraham
# 247       RepAbraham
# 248       RepAbraham
# 249       RepAbraham
# 250       RepAbraham
# 251       RepAbraham
# 252       RepAbraham
# 253       RepAbraham
# 254       RepAbraham
# 255       RepAbraham
# 256       RepAbraham
# 257       RepAbraham
# 258       RepAbraham
# 259       RepAbraham
# 260       RepAbraham
# 261       RepAbraham
# 262       RepAbraham
# 263       RepAbraham
# 264       RepAbraham
#
# [265 rows x 25 columns]

# %%
response = service.analyze(
    text=tweetsDF.loc[1, "full_text"],
    features=Features(#entities=EntitiesOptions(emotion=True, sentiment=True),
                      keywords=KeywordsOptions(emotion=True, sentiment=True))).get_result()

# %%
tweetsDF.loc[1, "full_text"]
# Out:
# 'Today is the day! #GeauxTigers https://t.co/B8ixSAMOUh'

# %%
response
# Out:
# {'usage': {'text_units': 1, 'text_characters': 54, 'features': 1},
#  'language': 'en',
#  'keywords': [{'text': 'Today',
#    'sentiment': {'score': 0.845689, 'label': 'positive'},
#    'relevance': 0.980057,
#    'emotion': {'sadness': 0.237793,
#     'joy': 0.577961,
#     'fear': 0.092637,
#     'disgust': 0.026219,
#     'anger': 0.054059},
#    'count': 1},
#   {'text': 'day',
#    'sentiment': {'score': 0.845689, 'label': 'positive'},
#    'relevance': 0.891414,
#    'emotion': {'sadness': 0.237793,
#     'joy': 0.577961,
#     'fear': 0.092637,
#     'disgust': 0.026219,
#     'anger': 0.054059},
#    'count': 1}]}

# %%
repAbrahamTweetsConcat = " -- ".join(tweetsDF.full_text)

# %%
repAbrahamTweetsConcat
# Out:
# 'Dianne and I were thrilled to join my granddaughter’s kindergarten class today. Dianne read “House Mouse, Senate Mouse” to introduce them to how our system of government works. #LA05 https://t.co/EZh8IcTJN3 -- Today is the day! #GeauxTigers https://t.co/B8ixSAMOUh -- RT @tmcclelland: Incredibly grateful to give the game ball this past Saturday to Colonel (Dr.) Chris Hudson, Commandor of the 2d Medical Gr… -- RT @nfib_la: Thank you to our Guardians of Small Business @BillCassidy @JohnKennedyLA @SteveScalise @RepGarretGraves @RepAbraham @RepMikeJo… -- RT @ScottFranklinJr: Incredible tour of the Iraq rice shipment out of Lake Charles.  @RepAbraham wanted to get a first hand look at his har… -- Great seeing my friends @RepMikeJohnson and his wife Kelly and Tech XXII at @LATech homecoming today. #HBTD #LA05 https://t.co/PgMCE1xruC -- Democrats want to abolish ICE, but I like that these agents are taking dangerous child predators off of Louisiana streets. #LA05 https://t.co/KIKSApGaC5 -- Thanks Gen. Frank for inviting me to participate in the 100th Anniversary Ceremony of the 115th Combat Support Hospital at Camp Beauregard. CSH is training to build tent hospitals during war. Thanks to these soldiers for all they do for our country &amp; their fellow troops. #LA05 https://t.co/g4q7JxM6bW -- #LA05 is the largest recipient ($1.12 million) of a wave of investments from the Delta Regional Authority to train new workers and make infrastructure enhancements in 8 projects in Ouachita, Rapides, Lincoln, La Salle, Concordia and East Carroll parishes.\nhttps://t.co/zHSQ4AVHnu -- .@4H Clubs help our kids grow as people and learn that it\'s never too soon to give back to your community. During #National4HWeek, we celebrate this great organization that has been shaping lives for 116 years, mine included. #LA05 https://t.co/J5esyDP4G6 -- Back on the ground after penetrating the eye of Hurricane Michael with the @NOAA_HurrHunter team. What a great group of pilots and professionals that help save thousands of lives. #LA05 https://t.co/srPfugr1Jj -- .@nikkihaley has been outstanding representing the US &amp; advancing President Trump\'s "America First" foreign policy. She will be greatly missed. As we consider her replacement, @RepRussell has served in uniform, knows the issues &amp; would be a strong voice for American interests. -- Huge congrats to @LaTech student Mason Andrews (@ATWin40days) for becoming the youngest person to ever fly solo around the world! Welcome home! You make #la05 proud. #HBTD #EverLoyalBe https://t.co/ULYXntUgKY -- RT @usaricenews: US rice sale of 90k MT to Iraq is a shot in the arm, thanks to @SecretarySonny @StateDept @RepAbraham @RepRickCrawford @Re… -- This weekend, we remember &amp; honor firefighters across the country who have fallen in the line of duty. These folks run toward the fire when the rest of us run the other way. I\'ll always support our first-responders and am thankful for the work they do everyday in our communities. -- Tomorrow is Bring Your Bible to School Day and I encourage every Christian student in Louisiana to participate. Religious freedom is never something to take for granted and tomorrow is a great opportunity to express your faith in the classroom. -- Throughout October, Americans will don the color pink to show support for breast cancer survivors. As a doctor, I\'ve seen the devastating effects cancer can have on women &amp; their families. I will be praying for breast cancer survivors, patients &amp; their families all month long. https://t.co/YktU9bdClr -- Today we honor Gold Star Mothers across the nation. I\'m thankful for their strength and the strength of every military family who sends children, brothers and sisters, to war for our country. https://t.co/WLTcTX988Y -- Senate Democrat - the only job in America where you can get mad and walk out of work without being fired. The nation deserves better than their temper tantrums and political grandstanding. #LA05 #ConfirmKavanaugh -- I m ...

# %%
len(repAbrahamTweetsConcat)
# Out:
# 59638

# %%
response = service.analyze(
    text=repAbrahamTweetsConcat[:30000],
    features=Features(entities=EntitiesOptions(emotion=True, sentiment=True),
                      keywords=KeywordsOptions(emotion=True, sentiment=True))).get_result()

# %% [markdown]
# finds maximum of 50 keywords!

# %%
len(response["keywords"])
# Out:
# 50

# %% [markdown]
# ## IBM slice:

# %%
tweetsDF = pd.read_csv(f"{dataDir}/tweets/raw/tweets100by100.csv")

# %%
tweetsDF
# Out:
#                           created_at  \
# 0     Mon Jan 07 23:20:11 +0000 2019
# 1     Mon Jan 07 20:30:29 +0000 2019
# 2     Mon Jan 07 14:21:29 +0000 2019
# 3     Sun Jan 06 22:28:05 +0000 2019
# 4     Sun Jan 06 16:39:38 +0000 2019
# 5     Sun Jan 06 14:49:09 +0000 2019
# 6     Sun Jan 06 14:29:51 +0000 2019
# 7     Sat Jan 05 22:04:51 +0000 2019
# 8     Sat Jan 05 21:05:37 +0000 2019
# 9     Sat Jan 05 19:45:59 +0000 2019
# 10    Fri Jan 04 23:11:38 +0000 2019
# 11    Fri Jan 04 18:18:06 +0000 2019
# 12    Fri Jan 04 02:36:24 +0000 2019
# 13    Thu Jan 03 16:56:04 +0000 2019
# 14    Thu Jan 03 14:41:57 +0000 2019
# 15    Sat Jan 05 00:00:00 +0000 2019
# 16    Thu Jan 03 23:00:00 +0000 2019
# 17    Thu Jan 03 21:17:34 +0000 2019
# 18    Wed Jan 02 22:00:00 +0000 2019
# 19    Tue Jan 01 04:59:00 +0000 2019
# 20    Sun Dec 30 21:00:00 +0000 2018
# 21    Sat Dec 29 20:00:00 +0000 2018
# 22    Fri Dec 28 19:00:00 +0000 2018
# 23    Thu Dec 27 18:30:00 +0000 2018
# 24    Wed Dec 26 17:00:00 +0000 2018
# 25    Tue Dec 25 16:00:00 +0000 2018
# 26    Sun Dec 23 23:00:00 +0000 2018
# 27    Sun Dec 23 20:00:01 +0000 2018
# 28    Sun Dec 23 03:01:00 +0000 2018
# 29    Sun Dec 23 01:01:00 +0000 2018
# ...                              ...
# 8179  Mon Nov 19 17:02:25 +0000 2018
# 8180  Mon Nov 19 16:01:00 +0000 2018
# 8181  Mon Nov 19 15:16:34 +0000 2018
# 8182  Sun Nov 18 22:03:14 +0000 2018
# 8183  Sun Nov 18 17:38:44 +0000 2018
# 8184  Sat Nov 17 20:23:05 +0000 2018
# 8185  Fri Nov 16 20:45:12 +0000 2018
# 8186  Fri Nov 16 19:03:02 +0000 2018
# 8187  Thu Nov 15 21:07:37 +0000 2018
# 8188  Thu Nov 15 16:11:23 +0000 2018
# 8189  Wed Nov 14 21:52:48 +0000 2018
# 8190  Wed Nov 14 16:51:49 +0000 2018
# 8191  Tue Nov 13 21:40:59 +0000 2018
# 8192  Mon Nov 12 21:41:46 +0000 2018
# 8193  Sun Nov 11 16:21:48 +0000 2018
# 8194  Sat Nov 10 17:00:00 +0000 2018
# 8195  Fri Nov 09 19:15:13 +0000 2018
# 8196  Mon Nov 05 23:19:31 +0000 2018
# 8197  Sun Nov 04 18:31:21 +0000 2018
# 8198  Sat Nov 03 15:30:00 +0000 2018
# 8199  Fri Nov 02 13:09:35 +0000 2018
# 8200  Fri Nov 02 13:04:36 +0000 2018
# 8201  Wed Oct 31 21:45:00 +0000 2018
# 8202  Wed Oct 31 15:09:26 +0000 2018
# 8203  Wed Oct 31 03:24:07 +0000 2018
# 8204  Tue Oct 30 21:00:00 +0000 2018
# 8205  Tue Oct 30 18:00:18 +0000 2018
# 8206  Mon Oct 29 19:29:29 +0000 2018
# 8207  Mon Oct 29 15:15:10 +0000 2018
# 8208  Sun Oct 28 00:15:08 +0000 2018
#
#                                               full_text        retweet_count  \
# 0                    Thank you! https://t.co/QHR3So39yV  1082416637033267203
# 1     #TrumpShutdown not just about federal workers,...  1082373932701941760
# 2     And bring the agents responsible for the two c...  1082281069204963329
# 3     For Texans, the president’s demand for a wall ...  1082041138163392513
# 4     RT @LeaderHoyer: Joined @MeetThePress to discu...  1081953447929364481
# 5     You won’t get a tax refund until the #TrumpShu...  1081925645616246784
# 6     RT @HouseDemocrats: House Democrats were busy ...  1081920789237194752
# 7     'Si, se puede': “Rep. Sylvia Garcia, D-Texas, ...  1081672904763473920
# 8     We must ensure the man who shot and killed Jaz...  1081657998005727235
# 9     #nobabyjails “Southwest Key Programs, faces mo...  1081637958422351873
# 10    RT @CNN: Rep. Sylvia Garcia is one of the firs...  1081327323612368896
# 11    We work #ForThePeople. That’s why I’m proud to...  1081253453601615873
# 12    Blessed to be surrounded by family today. We a...  1081016465598398465
# 13    Tune in to @cspan now to watch opening day pro...  1080870420717494272
# 14    Today is the big day! Thank you to the people ...  1080836667072749568
# 15    If people don’t have health insurance or can’t...  1081339496082288640
# 16    Denying #healthcare to those with pre-existing...  1080962007258550274
# 17    Honored to have been sworn into the 116th Cong...  1080936227778560000
# 18    Under the Affordable Care Act, you can't be de...  1080584519084851200
# 19    As we close the books on one year and begin an...  1079965188206415873
# 20    In the 3 years after the Affordable Care Act w...  1079482257004359680
# 21    Retweet if you agree: Americans should not be ...  1079104769627774978
# 22    The #healthcare of millions of Americans is at...  1078727281193902080
# 23    We want patients in Washington state to be pro...  1078357345137238018
# 24    The American people have spoken loud and clear...  1077972308009107457
# 25    Merry Christmas to everyone celebrating in Was...  1077594821492129792
# 26    The Affordable Care Act has expanded coverage ...  1076975740669706240
# 27    We must protect those with pre-existing condit...  1076930445361770496
# 28    Now that the final agreement for the 8.5 mile ...  1076674001844355073
# 29    Under the Affordable Care Act, you can't be de...  1076643802956193792
# ...                                                 ...                  ...
# 8179  For more on the Change of Command ceremony las...  1064564563876691974
# 8180  #OTD in 1863 Abraham Lincoln gave his famous #...  1064549108403310592
# 8181  I enjoyed the opportunity to sit down with may...  1064537925428408323
# 8182  Congrats Chris! A well deserved accolade for a...  1064277878421053440
# 8183  Within our military, the change of command cer...  1064211317693841408
# 8184  It was a pleasure to be in Arrowsmith this mor...  1063890286173188096
# 8185  The Gipper’s alma mater is headed to the playo...  1063533464845254657
# 8186  During #NationalApprenticeshipWeek we recogniz...  1063507757142343683
# 8187  Each year @SJRbreaking recognizes a leader in ...  1063176719098621958
# 8188  Yesterday, I sat down with @KHQA as part of th...  1063102170579562496
# 8189  Pleased to join Director Jeff Mays of the IDES...  1062825704147038209
# 8190  Proud to work in a bipartisan fashion to suppo...  1062749955612467202
# 8191  Economic optimism among Main Street businesses...  1062460339000930310
# 8192  Yesterday we recognized the 100th anniversary ...  1062098148888322048
# 8193  Today serves as yet another reminder that free...  1061655241148559361
# 8194  Happy Birthday to the @USMC! Thank you to the ...  1061302465457467392
# 8195  Congrats to @GROWMARK on receiving a HIRE Vets...  1060974107490181120
# 8196  Pro-growth policies enacted by Congress are pu...  1059586035716370440
# 8197  RT @SHAF55: Thank you to ⁦@RepLaHood⁩ for your...  1059151126765989890
# 8198  Honored to receive the Award for Manufacturing...  1058743101206999041
# 8199  RT @SpfldDaily: Davis, LaHood Announce Grant t...  1058345376913281028
# 8200  Another strong jobs report. Our economy is on ...  1058344123676192769
# 8201  Happy #Halloween to all of those celebrating t...  1057750309613813761
# 8202  Wages and salaries jump by 3.1%, highest level...  1057650760266190848
# 8203                     Go ☘️! https://t.co/RFEpff58c0  1057473263964774400
# 8204  Great to have Coach Dominguez swing by our off...  1057376596267388929
# 8205  Honored to be keynote speaker at the Law Enfor...  1057331373235679232
# 8206  #BreastCancerAwarenessMonth serves as an impor...  1056991430185496577
# 8207  #ICYMI @WGLTNews: Federal Mass Transit Chief S...  1056927429724389377
# 8208  My statement following the tragic shooting at ...  1056338541716869120
#
#       retweeted_status  id_str  twitter_account
# 0                  5.0   False  RepSylviaGarcia
# 1                 21.0   False  RepSylviaGarcia
# 2                 12.0   False  RepSylviaGarcia
# 3                 11.0   False  RepSylviaGarcia
# 4                 70.0    True  RepSylviaGarcia
# 5                 12.0   False  RepSylviaGarcia
# 6               2151.0    True  RepSylviaGarcia
# 7                  6.0   False  RepSylviaGarcia
# 8                 36.0   False  RepSylviaGarcia
# 9                 11.0   False  RepSylviaGarcia
# 10               156.0    True  RepSylviaGarcia
# 11                27.0   False  RepSylviaGarcia
# 12                13.0   False  RepSylviaGarcia
# 13                 2.0   False  RepSylviaGarcia
# 14                17.0   False  RepSylviaGarcia
# 15                66.0   False  SenatorCantwell
# 16                36.0   False  SenatorCantwell
# 17                78.0   False  SenatorCantwell
# 18                79.0   False  SenatorCantwell
# 19                11.0   False  SenatorCantwell
# 20               298.0   False  SenatorCantwell
# 21              1307.0   False  SenatorCantwell
# 22                48.0   False  SenatorCantwell
# 23                52.0   False  SenatorCantwell
# 24                64.0   False  SenatorCantwell
# 25                13.0   False  SenatorCantwell
# 26                77.0   False  SenatorCantwell
# 27                35.0   False  SenatorCantwell
# 28                13.0   False  SenatorCantwell
# 29                63.0   False  SenatorCantwell
# ...                ...     ...              ...
# 8179               NaN   False        RepLaHood
# 8180               7.0   False        RepLaHood
# 8181               NaN   False        RepLaHood
# 8182               NaN   False        RepLaHood
# 8183               3.0   False        RepLaHood
# 8184               NaN   False        RepLaHood
# 8185              10.0   False        RepLaHood
# 8186               1.0   False        RepLaHood
# 8187               2.0   False        RepLaHood
# 8188               2.0   False        RepLaHood
# 8189               1.0   False        RepLaHood
# 8190               NaN   False        RepLaHood
# 8191               4.0   False        RepLaHood
# 8192               2.0   False        RepLaHood
# 8193               3.0   False        RepLaHood
# 8194               2.0   False        RepLaHood
# 8195               1.0   False        RepLaHood
# 8196              10.0   False        RepLaHood
# 8197               9.0    True        RepLaHood
# 8198               2.0   False        RepLaHood
# 8199               2.0    True        RepLaHood
# 8200               6.0   False        RepLaHood
# 8201               NaN   False        RepLaHood
# 8202               7.0   False        RepLaHood
# 8203               2.0   False        RepLaHood
# 8204               2.0   False        RepLaHood
# 8205               2.0   False        RepLaHood
# 8206               1.0   False        RepLaHood
# 8207               3.0   False        RepLaHood
# 8208              11.0   False        RepLaHood
#
# [8209 rows x 6 columns]

# %%
metaDatMin = pd.read_csv("data/metaDatUSPols100.csv")

# %%
tweet1 = list(tweetsDF.loc[1:3,"full_text"])
tweet1
# Out:
# ['#TrumpShutdown not just about federal workers, it’s about all of us.  If we fly, safety &amp; delays at airports; if we file tax return, no one to process &amp; delays in refund check; if a Senior or veteran applying for assistance,  no one to process &amp; delay in checks.  #EndShutdown https://t.co/g16aYNihPU',
#  'And bring the agents responsible for the two children who died in your custody with you!  Still lots of questions. #JusticeforFelipe #JusticeForJakelin https://t.co/y6hGXAU1ZJ',
#  'For Texans, the president’s demand for a wall will trample private property rights and infringe on a church. How can conservatives defend this? #TrumpShutdown https://t.co/3M9gsQEQxE']

# %%
tweet11 = "\r\n\t".join(tweet1)

# %%
tweetsDF.groupby("twitter_account")

# %%
RepSylviaTweetsConcat = "--".join(tweetsDF.loc[tweetsDF.loc[:,"twitter_account"]=="RepSylviaGarcia","full_text"])

# %%
response = service.analyze(
    text=RepSylviaTweetsConcat,
    features=Features(entities=EntitiesOptions(emotion=True, sentiment=True),
                      keywords=KeywordsOptions(emotion=True, sentiment=True))).get_result()

# %%
response
# Out:
# {'usage': {'text_units': 1, 'text_characters': 2459, 'features': 2},
#  'language': 'en',
#  'keywords': [{'text': 'JusticeForJazmine https://t.co/T5CXIpmUVF--#nobabyjails',
#    'sentiment': {'score': -0.896636, 'label': 'negative'},
#    'relevance': 0.629309,
#    'emotion': {'sadness': 0.692436,
#     'joy': 0.034563,
#     'fear': 0.029867,
#     'disgust': 0.153688,
#     'anger': 0.280267},
#    'count': 1},
#   {'text': 'Sylvia Garcia',
#    'sentiment': {'score': -0.490122, 'label': 'negative'},
#    'relevance': 0.624276,
#    'emotion': {'sadness': 0.120218,
#     'joy': 0.507051,
#     'fear': 0.06623,
#     'disgust': 0.15095,
#     'anger': 0.108609},
#    'count': 2},
#   {'text': 'TrumpShutdown https://t.co/3M9gsQEQxE--RT',
#    'sentiment': {'score': -0.659505, 'label': 'negative'},
#    'relevance': 0.610097,
#    'emotion': {'sadness': 0.151475,
#     'joy': 0.251257,
#     'fear': 0.479617,
#     'disgust': 0.240376,
#     'anger': 0.01938},
#    'count': 1},
#   {'text': 'former state senator',
#    'sentiment': {'score': -0.589997, 'label': 'negative'},
#    'relevance': 0.609334,
#    'emotion': {'sadness': 0.283894,
#     'joy': 0.111606,
#     'fear': 0.028527,
#     'disgust': 0.046417,
#     'anger': 0.10657},
#    'count': 1},
#   {'text': '✊🏼✊🏽✊🏾',
#    'sentiment': {'score': -0.883811, 'label': 'negative'},
#    'relevance': 0.603367,
#    'emotion': {'sadness': 0.080244,
#     'joy': 0.132586,
#     'fear': 0.100346,
#     'disgust': 0.162589,
#     'anger': 0.056796},
#    'count': 1},
#   {'text': 'House Democrats',
#    'sentiment': {'score': -0.883811, 'label': 'negative'},
#    'relevance': 0.578778,
#    'emotion': {'sadness': 0.523648,
#     'joy': 0.057944,
#     'fear': 0.164406,
#     'disgust': 0.09352,
#     'anger': 0.266278},
#    'count': 1},
#   {'text': 'Southwest Key Programs',
#    'sentiment': {'score': -0.896636, 'label': 'negative'},
#    'relevance': 0.57315,
#    'emotion': {'sadness': 0.692436,
#     'joy': 0.034563,
#     'fear': 0.029867,
#     'disgust': 0.153688,
#     'anger': 0.280267},
#    'count': 1},
#   {'text': 'JusticeForJakelin https://t.co/y6hGXAU1ZJ--For Texans',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.567405,
#    'emotion': {'sadness': 0.101475,
#     'joy': 0.320909,
#     'fear': 0.069274,
#     'disgust': 0.193812,
#     'anger': 0.147337},
#    'count': 1},
#   {'text': 'compromise funding bills',
#    'sentiment': {'score': -0.958642, 'label': 'negative'},
#    'relevance': 0.566617,
#    'emotion': {'sadness': 0.078327,
#     'joy': 0.159963,
#     'fear': 0.017479,
#     'disgust': 0.175249,
#     'anger': 0.124291},
#    'count': 1},
#   {'text': 'refund check',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.558011,
#    'emotion': {'sadness': 0.366532,
#     'joy': 0.022868,
#     'fear': 0.051608,
#     'disgust': 0.143132,
#     'anger': 0.09215},
#    'count': 1},
#   {'text': 'D-Texas',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.54808,
#    'emotion': {'sadness': 0.126349,
#     'joy': 0.432608,
#     'fear': 0.084757,
#     'disgust': 0.077715,
#     'anger': 0.068603},
#    'count': 1},
#   {'text': 'tax return',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.547358,
#    'emotion': {'sadness': 0.366532,
#     'joy': 0.022868,
#     'fear': 0.051608,
#     'disgust': 0.143132,
#     'anger': 0.09215},
#    'count': 1},
#   {'text': 'private property rights',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.544877,
#    'emotion': {'sadness': 0.101475,
#     'joy': 0.320909,
#     'fear': 0.069274,
#     'disgust': 0.193812,
#     'anger': 0.147337},
#    'count': 1},
#   {'text': 'Congress https://t.co/htgkif7rXr https://t.co/nUQjs2Oq2t--We work',
#    'sentiment': {'score': 0.394652, 'mixed': '1', 'label': 'positive'},
#    'relevance': 0.544387,
#    'emotion': {'sadness': 0.17685,
#     'joy': 0.3513,
#     'fear': 0.074412,
#     'disgust': 0.211834,
#     'anger': 0.149748},
#    'count': 1},
#   {'text': 'EndShutdown https://t.co/g16aYNihPU--And',
#    'sentiment': {'score': -0.857147, 'label': 'negative'},
#    'relevance': 0.543596,
#    'emotion': {'sadness': 0.588905,
#     'joy': 0.107296,
#     'fear': 0.110761,
#     'disgust': 0.149053,
#     'anger': 0.119072},
#    'count': 1},
#   {'text': 'video of staff members',
#    'sentiment': {'score': -0.896636, 'label': 'negative'},
#    'relevance': 0.542545,
#    'emotion': {'sadness': 0.692436,
#     'joy': 0.034563,
#     'fear': 0.029867,
#     'disgust': 0.153688,
#     'anger': 0.280267},
#    'count': 1},
#   {'text': 'Nutrition assistance',
#    'sentiment': {'score': 0.537995, 'label': 'positive'},
#    'relevance': 0.533581,
#    'emotion': {'sadness': 0.427654,
#     'joy': 0.170992,
#     'fear': 0.012128,
#     'disgust': 0.098708,
#     'anger': 0.057446},
#    'count': 1},
#   {'text': 'people of the 29th District',
#    'sentiment': {'score': 0.510281, 'mixed': '1', 'label': 'positive'},
#    'relevance': 0.532932,
#    'emotion': {'sadness': 0.261496,
#     'joy': 0.526773,
#     'fear': 0.016343,
#     'disgust': 0.103815,
#     'anger': 0.070037},
#    'count': 2},
#   {'text': 'House',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.530617,
#    'emotion': {'sadness': 0.39969,
#     'joy': 0.0357,
#     'fear': 0.153985,
#     'disgust': 0.17878,
#     'anger': 0.310765},
#    'count': 1},
#   {'text': 'Justice Department',
#    'sentiment': {'score': -0.896636, 'label': 'negative'},
#    'relevance': 0.529138,
#    'emotion': {'sadness': 0.692436,
#     'joy': 0.034563,
#     'fear': 0.029867,
#     'disgust': 0.153688,
#     'anger': 0.280267},
#    'count': 1},
#   {'text': 'president’s demand',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.528813,
#    'emotion': {'sadness': 0.101475,
#     'joy': 0.320909,
#     'fear': 0.069274,
#     'disgust': 0.193812,
#     'anger': 0.147337},
#    'count': 1},
#   {'text': 'first female Speaker',
#    'sentiment': {'score': -0.883811, 'label': 'negative'},
#    'relevance': 0.527167,
#    'emotion': {'sadness': 0.16091,
#     'joy': 0.305478,
#     'fear': 0.050924,
#     'disgust': 0.115366,
#     'anger': 0.0407},
#    'count': 1},
#   {'text': 'se puede',
#    'sentiment': {'score': -0.883811, 'label': 'negative'},
#    'relevance': 0.526392,
#    'emotion': {'sadness': 0.039359,
#     'joy': 0.138136,
#     'fear': 0.104979,
#     'disgust': 0.141452,
#     'anger': 0.059018},
#    'count': 1},
#   {'text': '🏿Swearing',
#    'sentiment': {'score': -0.883811, 'label': 'negative'},
#    'relevance': 0.522305,
#    'emotion': {'sadness': 0.080244,
#     'joy': 0.132586,
#     'fear': 0.100346,
#     'disgust': 0.162589,
#     'anger': 0.056796},
#    'count': 1},
#   {'text': 'Dems’ commitment',
#    'sentiment': {'score': -0.659505, 'label': 'negative'},
#    'relevance': 0.520013,
#    'emotion': {'sadness': 0.151475,
#     'joy': 0.251257,
#     'fear': 0.479617,
#     'disgust': 0.240376,
#     'anger': 0.01938},
#    'count': 1},
#   {'text': 'amp',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.518922,
#    'emotion': {'sadness': 0.30111,
#     'joy': 0.045937,
#     'fear': 0.040452,
#     'disgust': 0.218121,
#     'anger': 0.123901},
#    'count': 3},
#   {'text': 'delays',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.518673,
#    'emotion': {'sadness': 0.366532,
#     'joy': 0.022868,
#     'fear': 0.051608,
#     'disgust': 0.143132,
#     'anger': 0.09215},
#    'count': 2},
#   {'text': 'tax refund',
#    'sentiment': {'score': -0.958642, 'label': 'negative'},
#    'relevance': 0.515072,
#    'emotion': {'sadness': 0.078327,
#     'joy': 0.159963,
#     'fear': 0.017479,
#     'disgust': 0.175249,
#     'anger': 0.124291},
#    'count': 1},
#   {'text': 'assistance',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.514985,
#    'emotion': {'sadness': 0.485067,
#     'joy': 0.030139,
#     'fear': 0.020424,
#     'disgust': 0.134093,
#     'anger': 0.070102},
#    'count': 1},
#   {'text': 'city controller',
#    'sentiment': {'score': -0.589997, 'label': 'negative'},
#    'relevance': 0.513995,
#    'emotion': {'sadness': 0.283894,
#     'joy': 0.111606,
#     'fear': 0.028527,
#     'disgust': 0.046417,
#     'anger': 0.10657},
#    'count': 1},
#   {'text': 'last month',
#    'sentiment': {'score': -0.896636, 'label': 'negative'},
#    'relevance': 0.5128,
#    'emotion': {'sadness': 0.692436,
#     'joy': 0.034563,
#     'fear': 0.029867,
#     'disgust': 0.153688,
#     'anger': 0.280267},
#    'count': 1},
#   {'text': 'Still lots of questions',
#    'sentiment': {'score': -0.437951, 'label': 'negative'},
#    'relevance': 0.51266,
#    'emotion': {'sadness': 0.455192,
#     'joy': 0.21361,
#     'fear': 0.187841,
#     'disgust': 0.049256,
#     'anger': 0.126114},
#    'count': 1},
#   {'text': 'Latina',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.511849,
#    'emotion': {'sadness': 0.120218,
#     'joy': 0.507051,
#     'fear': 0.06623,
#     'disgust': 0.15095,
#     'anger': 0.108609},
#    'count': 1},
#   {'text': 'children',
#    'sentiment': {'score': -0.87745, 'label': 'negative'},
#    'relevance': 0.511699,
#    'emotion': {'sadness': 0.792787,
#     'joy': 0.043765,
#     'fear': 0.012874,
#     'disgust': 0.131387,
#     'anger': 0.189679},
#    'count': 2},
#   {'text': 'veteran',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.510403,
#    'emotion': {'sadness': 0.366532,
#     'joy': 0.022868,
#     'fear': 0.051608,
#     'disgust': 0.143132,
#     'anger': 0.09215},
#    'count': 1},
#   {'text': 'pressure',
#    'sentiment': {'score': -0.896636, 'label': 'negative'},
#    'relevance': 0.510039,
#    'emotion': {'sadness': 0.692436,
#     'joy': 0.034563,
#     'fear': 0.029867,
#     'disgust': 0.153688,
#     'anger': 0.280267},
#    'count': 1},
#   {'text': 'safety',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.509849,
#    'emotion': {'sadness': 0.366532,
#     'joy': 0.022868,
#     'fear': 0.051608,
#     'disgust': 0.143132,
#     'anger': 0.09215},
#    'count': 1},
#   {'text': 'airports',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.509577,
#    'emotion': {'sadness': 0.366532,
#     'joy': 0.022868,
#     'fear': 0.051608,
#     'disgust': 0.143132,
#     'anger': 0.09215},
#    'count': 1},
#   {'text': 'TX29 children',
#    'sentiment': {'score': 0.537995, 'label': 'positive'},
#    'relevance': 0.509365,
#    'emotion': {'sadness': 0.427654,
#     'joy': 0.170992,
#     'fear': 0.012128,
#     'disgust': 0.098708,
#     'anger': 0.057446},
#    'count': 1},
#   {'text': 'man',
#    'sentiment': {'score': -0.589997, 'label': 'negative'},
#    'relevance': 0.508047,
#    'emotion': {'sadness': 0.325732,
#     'joy': 0.288605,
#     'fear': 0.020971,
#     'disgust': 0.289287,
#     'anger': 0.192301},
#    'count': 1},
#   {'text': 'wall',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.507572,
#    'emotion': {'sadness': 0.101475,
#     'joy': 0.320909,
#     'fear': 0.069274,
#     'disgust': 0.193812,
#     'anger': 0.147337},
#    'count': 1},
#   {'text': 'first Latinas',
#    'sentiment': {'score': -0.490122, 'label': 'negative'},
#    'relevance': 0.507458,
#    'emotion': {'sadness': 0.17685,
#     'joy': 0.3513,
#     'fear': 0.074412,
#     'disgust': 0.211834,
#     'anger': 0.149748},
#    'count': 1},
#   {'text': 'Houston',
#    'sentiment': {'score': -0.589997, 'label': 'negative'},
#    'relevance': 0.506725,
#    'emotion': {'sadness': 0.283894,
#     'joy': 0.111606,
#     'fear': 0.028527,
#     'disgust': 0.046417,
#     'anger': 0.10657},
#    'count': 1},
#   {'text': 'delay',
#    'sentiment': {'score': -0.966104, 'label': 'negative'},
#    'relevance': 0.506227,
#    'emotion': {'sadness': 0.366532,
#     'joy': 0.022868,
#     'fear': 0.051608,
#     'disgust': 0.143132,
#     'anger': 0.09215},
#    'count': 1},
#   {'text': 'agents',
#    'sentiment': {'score': -0.857147, 'label': 'negative'},
#    'relevance': 0.506075,
#    'emotion': {'sadness': 0.588905,
#     'joy': 0.107296,
#     'fear': 0.110761,
#     'disgust': 0.149053,
#     'anger': 0.119072},
#    'count': 1},
#   {'text': 'justice',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.506049,
#    'emotion': {'sadness': 0.479543,
#     'joy': 0.068209,
#     'fear': 0.12358,
#     'disgust': 0.303669,
#     'anger': 0.27402},
#    'count': 1},
#   {'text': 'checks',
#    'sentiment': {'score': -0.917987, 'label': 'negative'},
#    'relevance': 0.506047,
#    'emotion': {'sadness': 0.366532,
#     'joy': 0.022868,
#     'fear': 0.051608,
#     'disgust': 0.143132,
#     'anger': 0.09215},
#    'count': 1},
#   {'text': 'bills',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.505594,
#    'emotion': {'sadness': 0.100485,
#     'joy': 0.113399,
#     'fear': 0.036444,
#     'disgust': 0.23887,
#     'anger': 0.199037},
#    'count': 1},
#   {'text': 'days',
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'relevance': 0.505309,
#    'emotion': {'sadness': 0.427654,
#     'joy': 0.170992,
#     'fear': 0.012128,
#     'disgust': 0.098708,
#     'anger': 0.057446},
#    'count': 1},
#   {'text': 'Texas congresswoman',
#    'sentiment': {'score': -0.589997, 'label': 'negative'},
#    'relevance': 0.505291,
#    'emotion': {'sadness': 0.126349,
#     'joy': 0.432608,
#     'fear': 0.084757,
#     'disgust': 0.077715,
#     'anger': 0.068603},
#    'count': 1}],
#  'entities': [{'type': 'Person',
#    'text': 'Rep. Sylvia Garcia',
#    'sentiment': {'score': -0.344554, 'label': 'negative'},
#    'relevance': 0.919331,
#    'emotion': {'sadness': 0.190585,
#     'joy': 0.49718,
#     'fear': 0.04806,
#     'disgust': 0.143892,
#     'anger': 0.104968},
#    'count': 3},
#   {'type': 'Location',
#    'text': 'Texas',
#    'sentiment': {'score': -0.344554, 'label': 'negative'},
#    'relevance': 0.619586,
#    'emotion': {'sadness': 0.211876,
#     'joy': 0.49448,
#     'fear': 0.050545,
#     'disgust': 0.149645,
#     'anger': 0.098908},
#    'disambiguation': {'subtype': ['StateOrCounty']},
#    'count': 2},
#   {'type': 'Location',
#    'text': 'Houston',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.519946,
#    'emotion': {'sadness': 0.2892,
#     'joy': 0.108073,
#     'fear': 0.029225,
#     'disgust': 0.048226,
#     'anger': 0.121098},
#    'disambiguation': {'subtype': ['City']},
#    'count': 2},
#   {'type': 'JobTitle',
#    'text': 'president',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.484691,
#    'emotion': {'sadness': 0.0,
#     'joy': 0.0,
#     'fear': 0.0,
#     'disgust': 0.0,
#     'anger': 0.0},
#    'count': 1},
#   {'type': 'Person',
#    'text': 'Jazmine Barnes',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.483942,
#    'emotion': {'sadness': 0.430613,
#     'joy': 0.05948,
#     'fear': 0.083467,
#     'disgust': 0.248608,
#     'anger': 0.384917},
#    'count': 1},
#   {'type': 'Organization',
#    'text': 'Senate',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.480634,
#    'emotion': {'sadness': 0.0,
#     'joy': 0.0,
#     'fear': 0.0,
#     'disgust': 0.0,
#     'anger': 0.0},
#    'count': 1},
#   {'type': 'Organization',
#    'text': 'Justice Department',
#    'sentiment': {'score': -0.312161, 'label': 'negative'},
#    'relevance': 0.466975,
#    'emotion': {'sadness': 0.597218,
#     'joy': 0.024851,
#     'fear': 0.035922,
#     'disgust': 0.338822,
#     'anger': 0.234266},
#    'count': 1},
#   {'type': 'JobTitle',
#    'text': 'senator',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.447015,
#    'emotion': {'sadness': 0.367024,
#     'joy': 0.108124,
#     'fear': 0.043298,
#     'disgust': 0.053035,
#     'anger': 0.133671},
#    'count': 1},
#   {'type': 'Company',
#    'text': 'CNN',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.425753,
#    'emotion': {'sadness': 0.0,
#     'joy': 0.0,
#     'fear': 0.0,
#     'disgust': 0.0,
#     'anger': 0.0},
#    'disambiguation': {'subtype': ['Broadcast',
#      'AwardWinner',
#      'RadioNetwork',
#      'TVNetwork'],
#     'name': 'CNN',
#     'dbpedia_resource': 'http://dbpedia.org/resource/CNN'},
#    'count': 1},
#   {'type': 'Organization',
#    'text': 'Congress',
#    'sentiment': {'score': -0.365127, 'label': 'negative'},
#    'relevance': 0.402815,
#    'emotion': {'sadness': 0.287345,
#     'joy': 0.342823,
#     'fear': 0.044925,
#     'disgust': 0.185187,
#     'anger': 0.145039},
#    'count': 1},
#   {'type': 'Location',
#    'text': 'Pasadena.',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'emotion': {'sadness': 0.0,
#     'joy': 0.0,
#     'fear': 0.0,
#     'disgust': 0.0,
#     'anger': 0.0},
#    'disambiguation': {'subtype': ['City']},
#    'count': 1},
#   {'type': 'Hashtag',
#    'text': '#TrumpShutdown',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 3},
#   {'type': 'Hashtag',
#    'text': '#JusticeForJakelin',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'Hashtag',
#    'text': '#JusticeForJazmine',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'Hashtag',
#    'text': '#JusticeforFelipe',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'TwitterHandle',
#    'text': '@HouseDemocrats',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'Hashtag',
#    'text': '#ForThePeople',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'TwitterHandle',
#    'text': '@MeetThePress',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'Hashtag',
#    'text': '#EndShutdown',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'TwitterHandle',
#    'text': '@LeaderHoyer',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'TwitterHandle',
#    'text': '@NancyPelosi',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'TwitterHandle',
#    'text': '@NBCNews',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'TwitterHandle',
#    'text': '@cspan',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'Hashtag',
#    'text': '#TX29',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'Hashtag',
#    'text': '#HR1',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1},
#   {'type': 'TwitterHandle',
#    'text': '@CNN',
#    'sentiment': {'score': 0.0, 'label': 'neutral'},
#    'relevance': 0.348764,
#    'count': 1}]}

# %%
len(response["keywords"])
# Out:
# 50

# %%
for i in range(50):
    print(response["keywords"][i]["text"])
# Out:
# JusticeForJazmine https://t.co/T5CXIpmUVF--#nobabyjails
# Sylvia Garcia
# TrumpShutdown https://t.co/3M9gsQEQxE--RT
# former state senator
# ✊🏼✊🏽✊🏾
# House Democrats
# Southwest Key Programs
# JusticeForJakelin https://t.co/y6hGXAU1ZJ--For Texans
# compromise funding bills
# refund check
# D-Texas
# tax return
# private property rights
# Congress https://t.co/htgkif7rXr https://t.co/nUQjs2Oq2t--We work
# EndShutdown https://t.co/g16aYNihPU--And
# video of staff members
# Nutrition assistance
# people of the 29th District
# House
# Justice Department
# president’s demand
# first female Speaker
# se puede
# 🏿Swearing
# Dems’ commitment
# amp
# delays
# tax refund
# assistance
# city controller
# last month
# Still lots of questions
# Latina
# children
# veteran
# pressure
# safety
# airports
# TX29 children
# man
# wall
# first Latinas
# Houston
# delay
# agents
# justice
# checks
# bills
# days
# Texas congresswoman

# %%
sum(keyword["emotion"]["sadness"] for keyword in response["keywords"])
# Out:
# 16.597171000000003

# %%
groupedTweets = tweetsDF.groupby('twitter_account')['full_text'].apply(lambda x: "%s" % ' --\n '.join(x)).reset_index()

# %%
groupedTweets
# Out:
#     twitter_account                                          full_text
# 0   BettyMcCollum04  There’s still time to #GetCovered! @MNsure’s l...
# 1       BradSherman  Proud to be sworn in by @SpeakerPelosi to begi...
# 2     Call_Me_Dutch  RT @RepAnthonyBrown: I represent over 50,000 f...
# 3     CathyMcMorris  HAPPENING SOON: I’ll speak with @mschlapp on @...
# 4     ChrisMurphyCT  Cassie Bernall was 17. Her parents used to cal...
# 5    DesJarlaisTN04  Economy in last two years has rebounded from O...
# 6     EleanorNorton  Thank you to the following Members for introdu...
# 7   GraceNapolitano  RT @RepThompson: The American people have been...
# 8        GrahamBlog  .@tim_cook Our nation is at war &amp; this Iph...
# 9     JanSchakowsky  RT @CNN: JUST IN: House Speaker Nancy Pelosi a...
# 10      JohnBoozman  RT @BarryMoehring: Honored to have had Senator...
# 11    LisaMurkowski  Spraznikom to all those across Alaska celebrat...
# 12      MazieHirono  Someone who is amoral makes no distinction bet...
# 13        NitaLowey  There's no reason for the entire federal govt ...
# 14         RepAmata  Had a great time with the troops at Camp Arifj...
# 15   RepAndreCarson  With the partial government shutdown entering ...
# 16     RepAndyLevin  To mark Day 17 of the senseless #TrumpShutdown...
# 17    RepAngieCraig  I won't accept a paycheck during this or any s...
# 18      RepBenCline  NEWS: Ben Cline made it to Congress, here's ho...
# 19    RepBrianBabin  RT @TXRandy14: Do you remember... Under Presid...
# 20    RepBryanSteil  Joining @WTMJSteve on @620wtmj at 9:07CST. Tun...
# 21   RepBuddyCarter  Tune in! https://t.co/HyRiQMMlwk --\n From Amy...
# 22         RepCheri  I made some new friends today at Shaheen’s Vil...
# 23         RepChuck  I believe that hardworking members of our fede...
# 24     RepCindyAxne  Due to the shutdown, @USDA will now delay cruc...
# 25   RepClayHiggins  RT @LaRadioNetwork: Speaker Pelosi won't rule ...
# 26       RepCleaver  The White House has stated over and over again...
# 27      RepComstock  RT @CongressionalAC: Navigator app for the vis...
# 28         RepDavid  A beautiful #InaugurationDay with Olivia in Ar...
# 29    RepDebDingell  Devastated by the tragic loss of the Abbas fam...
# ..              ...                                                ...
# 56  RepSylviaGarcia  Thank you! https://t.co/QHR3So39yV --\n #Trump...
# 57       RepTedYoho  Will be joining @HARRISFAULKNER at 1:30pm toda...
# 58       RepTimWalz  This is my last tweet from this account. It wa...
# 59     RepUnderwood  So help me God 🇺🇸 https://t.co/MWwEHjOuGb --\n...
# 60    RepValDemings  This Friday, America's @TSA officers will miss...
# 61        RepVeasey  When Chris Wallace calls you out for lying on ...
# 62      RepWalorski  The 116th Congress is in session! I was honore...
# 63        RepWilson  We stand united in our opposition to Boko Hara...
# 64         RonWyden  I agree with @ChrisVanHollen.\n   \nThe #Trump...
# 65      RosLehtinen  RT @elnuevoherald: Ileana Ros-Lehtinen se estr...
# 66     SenAngusKing  I got to work early this morning and spent a q...
# 67    SenBlumenthal  Background checks are a crucial step in the ri...
# 68        SenCapito  Two seniors from Hurricane High School came to...
# 69     SenFeinstein  I’m glad to see a bill providing $12 billion i...
# 70    SenGaryPeters  The Chippewa tribe in the UP relies on federal...
# 71     SenJoniErnst  Both men exemplified bravery and dedication to...
# 72    SenRonJohnson  Congratulations @GovEvers, would like to work ...
# 73    SenRubioPress  Great work by the service men and women aboard...
# 74   SenatorBaldwin  Thank you to @Rooseveltinst for this important...
# 75  SenatorCantwell  If people don’t have health insurance or can’t...
# 76   SenatorIsakson  This is great news for Moultrie and Colquitt C...
# 77   SenatorShaheen  Fran was a true American hero. Rest in Peace. ...
# 78    Senatorhassan  Hard-working Americans are suffering because o...
# 79       TulsiPress  Our veterans deserve better than added stress ...
# 80     VernBuchanan  RT @FL_Daily: @VernBuchanan Calls on DOJ to St...
# 81     VirginiaFoxx  What did you miss last year? Check out my news...
# 82      repdonbeyer  So many people across the country have worked ...
# 83       repmialove  I am grateful to @SpeakerRyan for his leadersh...
# 84   sencortezmasto  .@USGAO found the VA’s efforts to reduce suici...
# 85   staceyplaskett  After Republicans shut down the government in ...
#
# [86 rows x 2 columns]

# %% [markdown]
# ## Merge with metadata

# %%
metaDatMin.sort_values(by="twitter_account")
# Out:
#     Unnamed: 0                                            api_uri at_large  \
# 36         817  https://api.propublica.org/congress/v1/members...    False
# 90         379  https://api.propublica.org/congress/v1/members...    False
# 81         355  https://api.propublica.org/congress/v1/members...    False
# 40         822  https://api.propublica.org/congress/v1/members...    False
# 76        1059  https://api.propublica.org/congress/v1/members...      NaN
# 97         658  https://api.propublica.org/congress/v1/members...    False
# 39         299  https://api.propublica.org/congress/v1/members...     True
# 31         839  https://api.propublica.org/congress/v1/members...    False
# 78         486  https://api.propublica.org/congress/v1/members...      NaN
# 47         905  https://api.propublica.org/congress/v1/members...    False
# 50        1004  https://api.propublica.org/congress/v1/members...      NaN
# 42        1058  https://api.propublica.org/congress/v1/members...      NaN
# 3          494  https://api.propublica.org/congress/v1/members...      NaN
# 32         859  https://api.propublica.org/congress/v1/members...    False
# 16         312  https://api.propublica.org/congress/v1/members...    False
# 37         797  https://api.propublica.org/congress/v1/members...    False
# 25         329  https://api.propublica.org/congress/v1/members...     True
# 71          55  https://api.propublica.org/congress/v1/members...    False
# 88         787  https://api.propublica.org/congress/v1/members...    False
# 11         636  https://api.propublica.org/congress/v1/members...    False
# 82         620  https://api.propublica.org/congress/v1/members...    False
# 69          36  https://api.propublica.org/congress/v1/members...    False
# 83         564  https://api.propublica.org/congress/v1/members...    False
# 93         936  https://api.propublica.org/congress/v1/members...    False
# 80         605  https://api.propublica.org/congress/v1/members...    False
# 14          48  https://api.propublica.org/congress/v1/members...    False
# 73         677  https://api.propublica.org/congress/v1/members...    False
# 18         563  https://api.propublica.org/congress/v1/members...    False
# 55         179  https://api.propublica.org/congress/v1/members...    False
# 67          69  https://api.propublica.org/congress/v1/members...    False
# ..         ...                                                ...      ...
# 17         972  https://api.propublica.org/congress/v1/members...    False
# 19         986  https://api.propublica.org/congress/v1/members...    False
# 63         551  https://api.propublica.org/congress/v1/members...      NaN
# 8          346  https://api.propublica.org/congress/v1/members...    False
# 53        1046  https://api.propublica.org/congress/v1/members...      NaN
# 95         503  https://api.propublica.org/congress/v1/members...      NaN
# 62        1001  https://api.propublica.org/congress/v1/members...      NaN
# 33        1009  https://api.propublica.org/congress/v1/members...      NaN
# 46         480  https://api.propublica.org/congress/v1/members...      NaN
# 84        1063  https://api.propublica.org/congress/v1/members...      NaN
# 12         479  https://api.propublica.org/congress/v1/members...      NaN
# 87        1042  https://api.propublica.org/congress/v1/members...      NaN
# 77        1071  https://api.propublica.org/congress/v1/members...      NaN
# 30         997  https://api.propublica.org/congress/v1/members...      NaN
# 2         1008  https://api.propublica.org/congress/v1/members...      NaN
# 75        1041  https://api.propublica.org/congress/v1/members...      NaN
# 41         535  https://api.propublica.org/congress/v1/members...      NaN
# 15        1034  https://api.propublica.org/congress/v1/members...      NaN
# 13         142  https://api.propublica.org/congress/v1/members...    False
# 7          686  https://api.propublica.org/congress/v1/members...    False
# 92         591  https://api.propublica.org/congress/v1/members...    False
# 24         682  https://api.propublica.org/congress/v1/members...    False
# 79          20  https://api.propublica.org/congress/v1/members...    False
# 5          249  https://api.propublica.org/congress/v1/members...    False
# 43         470  https://api.propublica.org/congress/v1/members...      NaN
# 49         319  https://api.propublica.org/congress/v1/members...     True
# 45         650  https://api.propublica.org/congress/v1/members...    False
# 48         813  https://api.propublica.org/congress/v1/members...    False
# 57         627  https://api.propublica.org/congress/v1/members...    False
# 65         864  https://api.propublica.org/congress/v1/members...    False
#
#                                          contact_form     crp_id   cspan_id  \
# 36                                                NaN  N00012942    86670.0
# 90                                                NaN  N00006897    45124.0
# 81                                                NaN  N00025482    49155.0
# 40                                                NaN  N00026314  1013063.0
# 76                                                NaN  N00027566  1021270.0
# 97                                                NaN  N00030957   623517.0
# 39             https://norton.house.gov/contact/email  N00001692      882.0
# 31                                                NaN  N00006789    57873.0
# 78  https://www.lgraham.senate.gov/public/index.cf...  N00009975    36782.0
# 47                                                NaN  N00004724    57874.0
# 50  https://www.boozman.senate.gov/public/index.cf...  N00013873    92069.0
# 42  https://www.murkowski.senate.gov/public/index....  N00026050  1004138.0
# 3               https://www.hirono.senate.gov/contact  N00028139    91216.0
# 32                                                NaN  N00007360     6153.0
# 16                                                NaN  N00007360     6153.0
# 37                                                NaN  N00001024     6110.0
# 25                https://radewagen.house.gov/contact  N00007635     5188.0
# 71                                                NaN  N00029513  1027364.0
# 88                                                NaN        NaN        NaN
# 11                                                NaN        NaN        NaN
# 82                                                NaN        NaN        NaN
# 69                                                NaN  N00001619    55227.0
# 83                                                NaN  N00005736    44883.0
# 93                                                NaN        NaN        NaN
# 80                                                NaN  N00035346    76158.0
# 14                                                NaN  N00033390    63949.0
# 73                                                NaN  N00030815    95146.0
# 18                                                NaN        NaN        NaN
# 55                                                NaN  N00039953   106094.0
# 67                                                NaN  N00026790    10933.0
# ..                                                ...        ...        ...
# 17                                                NaN  N00031226    95005.0
# 19                                                NaN  N00030650    87016.0
# 63              https://www.wyden.senate.gov/contact/  N00007724     1962.0
# 8                                                 NaN  N00002858     3206.0
# 53                                                NaN  N00034580    37413.0
# 95                                                NaN  N00034580    37413.0
# 62         https://www.blumenthal.senate.gov/contact/  N00031685    21799.0
# 33  https://www.capito.senate.gov/contact/contact-...  N00009771    83737.0
# 46  https://www.feinstein.senate.gov/public/index....  N00007364    13061.0
# 84   https://www.peters.senate.gov/contact/email-gary  N00029277    50199.0
# 12  https://www.ernst.senate.gov/public/index.cfm/...  N00035483    75342.0
# 87  https://www.ronjohnson.senate.gov/public/index...  N00032546    62835.0
# 77  http://www.rubio.senate.gov/public/index.cfm/c...  N00030612    87599.0
# 30                                                NaN  N00004367    57884.0
# 2                                                 NaN  N00007836    26137.0
# 75  https://www.isakson.senate.gov/public/index.cf...  N00002593    59135.0
# 41  https://www.shaheen.senate.gov/contact/contact...  N00024790    22850.0
# 15  https://www.hassan.senate.gov/content/contact-...  N00038397    67481.0
# 13                                                NaN  N00033281  1025291.0
# 7                                                 NaN  N00033281  1025291.0
# 92                                                NaN  N00027626  1021626.0
# 24                                                NaN  N00026166  1013052.0
# 79                                                NaN  N00036018    21141.0
# 5                                                 NaN  N00033842    67205.0
# 43  https://www.cortezmasto.senate.gov/content/con...  N00037161   105698.0
# 49                https://plaskett.house.gov/contact/  N00035000    79090.0
# 45                                                NaN        NaN        NaN
# 48                                                NaN        NaN        NaN
# 57                                                NaN  N00038260    76619.0
# 65                                                NaN  N00004558    23978.0
#
#           date_of_birth  district  dw_nominate         facebook_account  ...  \
# 36  1954-07-12 00:00:00         4          NaN         repbettymccollum  ...
# 90  1954-10-24 00:00:00        30       -0.343              63158229861  ...
# 81  1946-01-31 00:00:00         2       -0.298              1.84757E+14  ...
# 40  1969-05-22 00:00:00         5          NaN          mcmorrisrodgers  ...
# 76  1973-08-03 00:00:00       NaN          NaN            chrismurphyct  ...
# 97  1964-02-21 00:00:00         4          NaN      ScottDesJarlaisTN04  ...
# 39  1937-06-13 00:00:00  At-Large          NaN      CongresswomanNorton  ...
# 31  1936-12-04 00:00:00        32          NaN       RepGraceNapolitano  ...
# 78  1955-07-09 00:00:00       NaN        0.409   USSenatorLindseyGraham  ...
# 47  1944-05-26 00:00:00         9          NaN            janschakowsky  ...
# 50  1950-12-10 00:00:00       NaN          NaN              JohnBoozman  ...
# 42  1957-05-22 00:00:00       NaN          NaN         SenLisaMurkowski  ...
# 3   1947-11-03 00:00:00       NaN       -0.490            senatorhirono  ...
# 32  1940-03-26 00:00:00        12          NaN              NancyPelosi  ...
# 16  1940-03-26 00:00:00        12       -0.492              NancyPelosi  ...
# 37  1937-07-05 00:00:00        17          NaN                 RepLowey  ...
# 25  1947-12-29 00:00:00  At-Large          NaN  congresswomanaumuaamata  ...
# 71  1974-10-16 00:00:00         7       -0.431   CongressmanAndreCarson  ...
# 88  1960-08-01 00:00:00         9          NaN                      NaN  ...
# 11  1972-02-14 00:00:00         2          NaN                      NaN  ...
# 82  1972-02-29 00:00:00         6          NaN                      NaN  ...
# 69  1945-04-07 00:00:00         1       -0.482           RepRobertBrady  ...
# 83  1948-03-23 00:00:00        36          NaN            RepBrianBabin  ...
# 93  1981-03-30 00:00:00         1          NaN                      NaN  ...
# 80  1957-09-06 00:00:00         1          NaN   congressmanbuddycarter  ...
# 14  1961-10-17 00:00:00        17       -0.238                 RepCheri  ...
# 73  1962-10-11 00:00:00         3          NaN                 repchuck  ...
# 18  1965-04-20 00:00:00         3          NaN                      NaN  ...
# 55  1961-08-24 00:00:00         3        0.524                      NaN  ...
# 67  1944-10-26 00:00:00         5       -0.451         emanuelcleaverii  ...
# ..                  ...       ...          ...                      ...  ...
# 17  1963-08-17 00:00:00         2          NaN        RepJackieWalorski  ...
# 19  1942-11-05 00:00:00        24          NaN                RepWilson  ...
# 63  1949-05-03 00:00:00       NaN       -0.316                      NaN  ...
# 8   1952-07-15 00:00:00        27        0.245             iroslehtinen  ...
# 53  1944-03-31 00:00:00       NaN          NaN      SenatorAngusSKingJr  ...
# 95  1944-03-31 00:00:00       NaN       -0.152      SenatorAngusSKingJr  ...
# 62  1946-02-13 00:00:00       NaN          NaN            SenBlumenthal  ...
# 33  1953-11-26 00:00:00       NaN          NaN               senshelley  ...
# 46  1933-06-22 00:00:00       NaN       -0.264         senatorfeinstein  ...
# 84  1958-12-01 00:00:00       NaN          NaN            SenGaryPeters  ...
# 12  1970-07-01 00:00:00       NaN        0.515             senjoniernst  ...
# 87  1955-04-08 00:00:00       NaN          NaN            senronjohnson  ...
# 77  1971-05-28 00:00:00       NaN          NaN        SenatorMarcoRubio  ...
# 30  1962-02-11 00:00:00       NaN          NaN             TammyBaldwin  ...
# 2   1958-10-13 00:00:00       NaN          NaN          senatorcantwell  ...
# 75  1944-12-28 00:00:00       NaN          NaN                      NaN  ...
# 41  1947-01-28 00:00:00       NaN       -0.269           SenatorShaheen  ...
# 15  1958-02-27 00:00:00       NaN          NaN            SenatorHassan  ...
# 13  1981-04-12 00:00:00         2       -0.281          RepTulsiGabbard  ...
# 7   1981-04-12 00:00:00         2          NaN          RepTulsiGabbard  ...
# 92  1951-05-08 00:00:00        16          NaN      CongressmanBuchanan  ...
# 24  1943-06-29 00:00:00         5          NaN          RepVirginiaFoxx  ...
# 79  1950-06-20 00:00:00         8       -0.395              repdonbeyer  ...
# 5   1975-12-06 00:00:00         4        0.569               repmialove  ...
# 43  1964-03-29 00:00:00       NaN       -0.342       SenatorCortezMasto  ...
# 49  1964-05-13 00:00:00  At-Large          NaN        repstaceyplaskett  ...
# 45  1959-06-06 00:00:00         4          NaN                      NaN  ...
# 48  1960-06-01 00:00:00         6          NaN                      NaN  ...
# 57  1972-08-19 00:00:00         1          NaN         congressmancomer  ...
# 65  1944-06-29 00:00:00         7          NaN                      NaN  ...
#
#    state_rank suffix               title total_present total_votes  \
# 36        NaN    NaN      Representative           0.0        12.0
# 90        NaN    NaN      Representative           0.0       976.0
# 81        NaN    NaN      Representative           0.0       976.0
# 40        NaN    NaN      Representative           0.0        12.0
# 76     junior    NaN  Senator, 1st Class           NaN         NaN
# 97        NaN    NaN      Representative           0.0        12.0
# 39        NaN    NaN            Delegate           NaN         0.0
# 31        NaN    NaN      Representative           0.0        12.0
# 78     senior    NaN  Senator, 2nd Class           0.0       444.0
# 47        NaN    NaN      Representative           0.0        12.0
# 50     senior    NaN  Senator, 3rd Class           NaN         NaN
# 42     senior    NaN  Senator, 3rd Class           NaN         NaN
# 3      junior    NaN  Senator, 1st Class           1.0       444.0
# 32        NaN    NaN      Representative           0.0        12.0
# 16        NaN    NaN      Representative           0.0       976.0
# 37        NaN    NaN      Representative           0.0        12.0
# 25        NaN    NaN            Delegate           NaN         0.0
# 71        NaN    NaN      Representative           0.0       976.0
# 88        NaN    NaN      Representative           0.0        12.0
# 11        NaN    NaN      Representative           0.0        12.0
# 82        NaN    NaN      Representative           0.0        12.0
# 69        NaN    NaN      Representative           0.0       976.0
# 83        NaN    NaN      Representative           0.0        12.0
# 93        NaN    NaN      Representative           0.0        12.0
# 80        NaN    NaN      Representative           0.0        12.0
# 14        NaN    NaN      Representative           0.0       976.0
# 73        NaN    NaN      Representative           0.0        12.0
# 18        NaN    NaN      Representative           0.0        12.0
# 55        NaN    NaN      Representative           0.0       976.0
# 67        NaN     II      Representative           4.0       976.0
# ..        ...    ...                 ...           ...         ...
# 17        NaN    NaN      Representative           0.0        12.0
# 19        NaN    NaN      Representative           0.0        12.0
# 63     senior    NaN  Senator, 3rd Class           2.0       444.0
# 8         NaN    NaN      Representative           0.0       976.0
# 53     junior    NaN  Senator, 1st Class           NaN         NaN
# 95     junior    NaN  Senator, 1st Class           0.0       444.0
# 62     senior    NaN  Senator, 3rd Class           NaN         NaN
# 33     junior    NaN  Senator, 2nd Class           NaN         NaN
# 46     senior    NaN  Senator, 1st Class           1.0       444.0
# 84     junior    NaN  Senator, 2nd Class           NaN         NaN
# 12     junior    NaN  Senator, 2nd Class           0.0       444.0
# 87     senior    NaN  Senator, 3rd Class           NaN         NaN
# 77     senior    NaN  Senator, 3rd Class           NaN         NaN
# 30     junior    NaN  Senator, 1st Class           NaN         NaN
# 2      junior    NaN  Senator, 1st Class           NaN         NaN
# 75     senior    NaN  Senator, 3rd Class           NaN         NaN
# 41     senior    NaN  Senator, 2nd Class           1.0       444.0
# 15     junior    NaN  Senator, 3rd Class           NaN         NaN
# 13        NaN    NaN      Representative           0.0       976.0
# 7         NaN    NaN      Representative           0.0        12.0
# 92        NaN    NaN      Representative           0.0        12.0
# 24        NaN    NaN      Representative           0.0        12.0
# 79        NaN    NaN      Representative           0.0       976.0
# 5         NaN    NaN      Representative           0.0       976.0
# 43     junior    NaN  Senator, 3rd Class           1.0       444.0
# 49        NaN    NaN            Delegate           NaN         0.0
# 45        NaN    NaN      Representative           0.0        12.0
# 48        NaN    NaN      Representative           0.0        12.0
# 57        NaN    NaN      Representative           0.0        12.0
# 65        NaN    NaN      Representative           0.0        12.0
#
#     twitter_account                                    url  \
# 36  BettyMcCollum04             https://mccollum.house.gov
# 90      BradSherman              https://sherman.house.gov
# 81    Call_Me_Dutch        https://ruppersberger.house.gov
# 40    CathyMcMorris             https://mcmorris.house.gov
# 76    ChrisMurphyCT          https://www.murphy.senate.gov
# 97   DesJarlaisTN04           https://desjarlais.house.gov
# 39    EleanorNorton               https://norton.house.gov
# 31  GraceNapolitano           https://napolitano.house.gov
# 78       GrahamBlog  https://www.lgraham.senate.gov/public
# 47    JanSchakowsky           https://schakowsky.house.gov
# 50      JohnBoozman  https://www.boozman.senate.gov/public
# 42    LisaMurkowski       https://www.murkowski.senate.gov
# 3       MazieHirono          https://www.hirono.senate.gov
# 32      NancyPelosi               https://pelosi.house.gov
# 16      NancyPelosi               https://pelosi.house.gov
# 37        NitaLowey                https://lowey.house.gov
# 25         RepAmata            https://radewagen.house.gov
# 71   RepAndreCarson               https://carson.house.gov
# 88     RepAndyLevin           https://andylevin.house.gov/
# 11    RepAngieCraig               https://craig.house.gov/
# 82      RepBenCline               https://cline.house.gov/
# 69         RepBrady                https://brady.house.gov
# 83    RepBrianBabin                https://babin.house.gov
# 93    RepBryanSteil               https://steil.house.gov/
# 80   RepBuddyCarter          https://buddycarter.house.gov
# 14         RepCheri               https://bustos.house.gov
# 73         RepChuck          https://fleischmann.house.gov
# 18     RepCindyAxne                https://axne.house.gov/
# 55   RepClayHiggins          https://clayhiggins.house.gov
# 67       RepCleaver              https://cleaver.house.gov
# ..              ...                                    ...
# 17      RepWalorski             https://walorski.house.gov
# 19        RepWilson               https://wilson.house.gov
# 63         RonWyden           https://www.wyden.senate.gov
# 8       RosLehtinen         https://ros-lehtinen.house.gov
# 53     SenAngusKing            https://www.king.senate.gov
# 95     SenAngusKing            https://www.king.senate.gov
# 62    SenBlumenthal      https://www.blumenthal.senate.gov
# 33        SenCapito          https://www.capito.senate.gov
# 46     SenFeinstein       https://www.feinstein.senate.gov
# 84    SenGaryPeters          https://www.peters.senate.gov
# 12     SenJoniErnst    https://www.ernst.senate.gov/public
# 87    SenRonJohnson      https://www.ronjohnson.senate.gov
# 77    SenRubioPress           https://www.rubio.senate.gov
# 30   SenatorBaldwin         https://www.baldwin.senate.gov
# 2   SenatorCantwell        https://www.cantwell.senate.gov
# 75   SenatorIsakson         https://www.isakson.senate.gov
# 41   SenatorShaheen         https://www.shaheen.senate.gov
# 15    Senatorhassan          https://www.hassan.senate.gov
# 13       TulsiPress              https://gabbard.house.gov
# 7        TulsiPress              https://gabbard.house.gov
# 92     VernBuchanan             https://buchanan.house.gov
# 24     VirginiaFoxx                 https://foxx.house.gov
# 79      repdonbeyer                https://beyer.house.gov
# 5        repmialove                 https://love.house.gov
# 43   sencortezmasto     https://www.cortezmasto.senate.gov
# 49   staceyplaskett             https://plaskett.house.gov
# 45              NaN                https://dean.house.gov/
# 48              NaN              https://mcbath.house.gov/
# 57              NaN                https://comer.house.gov
# 65              NaN       https://collinpeterson.house.gov
#
#    votes_with_party_pct  votesmart_id           youtube_account
# 36                83.33        3812.0                       NaN
# 90                92.00         142.0               shermanca27
# 81                91.35       36130.0             ruppersberger
# 40                83.33        3217.0           mcmorrisrodgers
# 76                  NaN       17189.0            senchrismurphy
# 97                83.33      123473.0       ScottDesJarlaisTN04
# 39                  NaN         775.0            EleanorHNorton
# 31                83.33        8393.0        RepGraceNapolitano
# 78                97.15       21992.0        USSenLindseyGraham
# 47                83.33        6387.0             repschakowsky
# 50                  NaN       27958.0        BoozmanPressOffice
# 42                  NaN       15841.0          senatormurkowski
# 3                 88.33        1677.0       CongresswomanHirono
# 32                33.33       26732.0               nancypelosi
# 16                94.17       26732.0               nancypelosi
# 37                83.33       26982.0                 nitalowey
# 25                  NaN           NaN                       NaN
# 71                93.33       84917.0            repandrecarson
# 88                83.33           NaN                       NaN
# 11                83.33           NaN                       NaN
# 82                83.33           NaN                       NaN
# 69                94.52        2519.0                 BradyPA01
# 83                75.00         360.0                       NaN
# 93                83.33           NaN                       NaN
# 80                83.33       32085.0                       NaN
# 14                91.31      134964.0                  RepCheri
# 73                83.33      123456.0                  repchuck
# 18                83.33           NaN                       NaN
# 55                98.19      174484.0                       NaN
# 67                94.29       39507.0                repcleaver
# ..                  ...           ...                       ...
# 17                83.33       34205.0               repwalorski
# 19                90.00       17319.0        repfredericawilson
# 63                88.49       27036.0               senronwyden
# 8                 84.79       26815.0         IleanaRosLehtinen
# 53                  NaN       22381.0          SenatorAngusKing
# 95                84.23       22381.0          SenatorAngusKing
# 62                  NaN        1568.0         SenatorBlumenthal
# 33                  NaN       11701.0  UCbiXdR4XQ3vD9Xp5lfR9QXw
# 46                92.09       53273.0          SenatorFeinstein
# 84                  NaN        8749.0             RepGaryPeters
# 12                97.52      128583.0                       NaN
# 87                  NaN      126217.0         SenatorRonJohnson
# 77                  NaN        1601.0         SenatorMarcoRubio
# 30                  NaN        3470.0            witammybaldwin
# 2                   NaN       27122.0           SenatorCantwell
# 75                  NaN        1721.0            SenatorIsakson
# 41                92.52        1663.0            senatorshaheen
# 15                  NaN       42552.0                       NaN
# 13                91.47      129306.0                tulsipress
# 7                 75.00      129306.0                tulsipress
# 92                83.33       66247.0              vernbuchanan
# 24                83.33        6051.0           repvirginiafoxx
# 79                93.97        1707.0                       NaN
# 5                 95.67      135957.0                       NaN
# 43                89.68       69579.0                       NaN
# 49                  NaN           NaN                       NaN
# 45                83.33           NaN                       NaN
# 48                83.33           NaN                       NaN
# 57                83.33       35169.0                       NaN
# 65                75.00       26926.0                       NaN
#
# [100 rows x 51 columns]

# %%
metaDatMin.loc[:5, "twitter_account"]
# Out:
# 0    RepSylviaGarcia
# 1          RepSinema
# 2    SenatorCantwell
# 3        MazieHirono
# 4          RepSinema
# 5         repmialove
# Name: twitter_account, dtype: object

# %%
"""SELECT t1.*, t2.full_text from metadat as t1 join groupedTweets as t2 on t1.twitter_account == t2.twitter_account"""
# Out:
# 'SELECT t1.*, t2.full_text from metadat as t1 join groupedTweets as t2 on t1.twitter_account == t2.twitter_account'

# %%
metaDatMin.join(groupedTweets, on="twitter_account", how="inner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-27f03134a270> in <module>
# ----> 1 metaDatMin.join(groupedTweets, on="twitter_account", how="inner")
#
# ~/.virtualenvs/PolySpeech/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6813         # For SparseDataFrame's benefit
#    6814         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6815                                  rsuffix=rsuffix, sort=sort)
#    6816
#    6817     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/.virtualenvs/PolySpeech/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6828             return merge(self, other, left_on=on, how=how,
#    6829                          left_index=on is None, right_index=True,
# -> 6830                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6831         else:
#    6832             if on is not None:
#
# ~/.virtualenvs/PolySpeech/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~/.virtualenvs/PolySpeech/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     531         # validate the merge keys dtypes. We may need to coerce
#     532         # to avoid incompat dtypes
# --> 533         self._maybe_coerce_merge_keys()
#     534
#     535         # If argument passed to validate,
#
# ~/.virtualenvs/PolySpeech/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#     978                       (inferred_right in string_types and
#     979                        inferred_left not in string_types)):
# --> 980                     raise ValueError(msg)
#     981
#     982             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
metaDatMin.dtypes["twitter_account"]
# Out:
# dtype('O')

# %%
groupedTweets.dtypes["twitter_account"]
# Out:
# dtype('O')

# %% [markdown]
# ## Not helpful

# %%
# groupedTweets.twitter_account = groupedTweets.twitter_account.str.encode('utf-8')

# %%
# metaDatMin.twitter_account = metaDatMin.twitter_account.str.encode('utf-8')

# %%
tracker = ProgressTracker(len(groupedTweets))

# %%
responses = []
for i, tweetSet in enumerate(groupedTweets.loc[:,"full_text"]):
    response = service.analyze(
        text=tweetSet,
        features=Features(entities=EntitiesOptions(emotion=True, sentiment=True),
                          keywords=KeywordsOptions(emotion=True, sentiment=True))).get_result()
    responses.append(response)
    tracker.update(i)
# Out:
# 5 percent done
# 10 percent done
# 15 percent done
# 20 percent done
# 25 percent done
# 30 percent done
# 35 percent done
# 40 percent done
# 45 percent done
# 50 percent done
# 55 percent done
# 60 percent done
# 65 percent done
# 70 percent done
# 75 percent done
# 80 percent done
# 85 percent done
# 90 percent done
# 95 percent done

# %%
len(responses)
# Out:
# 86

# %%
import pickle

# %%
pickle.dump(responses, open('data/IBMResponses.pkl', 'wb'))

# %%
responses1 = pickle.load(open('data/IBMResponses.pkl', 'rb'))

# %%
responses = responses1

# %%
groupedTweets.loc[0,"full_text"]
# Out:
# 'There’s still time to #GetCovered! @MNsure’s last day of #OpenEnrollment is just 5 days away (1/13). Meet with an assister today &amp; get free help: https://t.co/Ja2wX1J3tq https://t.co/TDExOMi34v --\n I am saddened by the passing of my friend and former MN House colleague Tom Rukavina. While we didn’t always agree, it was an honor to fight alongside him on behalf of hardworking Minnesotans. His passion for the people he represented and sense of humor will be missed. --\n Need help with a federal agency? My staff will be in Stillwater tomorrow -- Tuesday, Jan. 8 -- to assist. Learn more &amp; make an appointment → https://t.co/DlyyZnGneQ https://t.co/C7Gy7l5pX8 --\n Minnesota is in good hands with @julieblaha as State Auditor. Congratulations on your inauguration! --\n Looking forward to continued progress for Minnesota voters under Steve Simon’s leadership as he’s sworn in for a second term as MN’s Secretary of State. Congratulations, @MNSteveSimon! --\n I know from our many years of working together in the U.S. House that @keithellison will serve Minnesota well as its next Attorney General. Congratulations, Keith! --\n Congratulations to @GovTimWalz and @LtGovFlanagan on your inauguration as Minnesota’s next governor and lieutenant governor! I’m looking forward to working with your administration as you build #OneMinnesota. --\n Thank you to @GovMarkDayton for your years of dedicated public service as the Governor of Minnesota. Governor Dayton truly left Minnesota better off for our children and grandchildren. Thank you, Mark! --\n Today is day 17 of the #TrumpShutdown. Federal employees like TSA agents &amp; air traffic controllers are working without pay to keep our nation safe. @realDonaldTrump needs to take responsibility for the impact of his shutdown and end it immediately. --\n .@HouseDemocrats are working hard to bring the #TrumpShutdown to an end and get our country moving again. I’m proud to co-sponsor the #ForThePeople Act – a set of reforms to strengthen our democracy and return political power to the people. https://t.co/akmypi3FWA --\n RT @esmemurphy: .@wcco 10:30am as the Government shutdown drags on two influential members of Congress @BettyMcCollum04 @RepTomEmmer will b… --\n Miss the December 15th deadline to enroll in @MNsure? No problem! MNsure open enrollment is still in full swing. The final deadline to enroll in a plan for 2019 is JANUARY 13th. Visit https://t.co/Rvk2QGH5qv to compare plans and #GetCovered today. --\n Thousands of federal employees are going w/o pay during the #TrumpShutdown, and the president is doling out pay raises to his senior political appointees. This is outrageous. I stand w/ @RepMikeQuigley in calling on the White House to rescind this action. https://t.co/Gc8XK68iHA --\n This was a truly historic week in U.S. history – the House of Representatives ushered in its most diverse freshman class, including 36 new women. It is with great pride that I serve alongside these dedicated public servants. Now, let’s get to work! https://t.co/i4n2jzOGku --\n Proud to cosponsor H.R. 1. @HouseDemocrats will end the #CultureOfCorruption and build a democracy that works for every American. https://t.co/nbjhTDTMLh --\n Despite last night’s House vote to reopen the gov\'t, the #TrumpShutdown is now two weeks old. Smithsonian museums are closed. EPA inspections of many polluted sites have ceased. And federal workers still don’t know when their next paycheck might arrive. This is unacceptable. https://t.co/6hVMXJ8hES --\n RT @esmemurphy: .@wcco Sun10:30am as Gov shutdown continues 2 powerful members of Congress are live in studio:Democrat @BettyMcCollum04  a… --\n Congress has a responsibility to fund the gov\'t and end the #TrumpShutdown. We’re about to vote on funding legislation that has already received overwhelming Republican support in the Senate. Any Republican opposition to this is a vote against their own legislation. --\n Congratulations to Congressman Jim Langevin on being the first Sp ...

# %%
pp.pprint(responses[0]["keywords"])
# Out:
# [{'count': 1,
#   'emotion': {'anger': 0.069223,
#               'disgust': 0.086477,
#               'fear': 0.011827,
#               'joy': 0.613442,
#               'sadness': 0.085489},
#   'relevance': 0.555145,
#   'sentiment': {'label': 'positive', 'score': 0.94042},
#   'text': 'years of dedicated public service'},
#  {'count': 7,
#   'emotion': {'anger': 0.153825,
#               'disgust': 0.440669,
#               'fear': 0.038792,
#               'joy': 0.30408,
#               'sadness': 0.192395},
#   'relevance': 0.554577,
#   'sentiment': {'label': 'negative', 'mixed': '1', 'score': -0.778695},
#   'text': 'American people'},
#  {'count': 2,
#   'emotion': {'anger': 0.085175,
#               'disgust': 0.023002,
#               'fear': 0.126905,
#               'joy': 0.036896,
#               'sadness': 0.220109},
#   'relevance': 0.552202,
#   'sentiment': {'label': 'negative', 'score': -0.626272},
#   'text': 'federal agency'},
#  {'count': 1,
#   'emotion': {'anger': 0.046492,
#               'disgust': 0.061873,
#               'fear': 0.098019,
#               'joy': 0.623777,
#               'sadness': 0.166293},
#   'relevance': 0.548751,
#   'sentiment': {'label': 'negative', 'score': -0.678951},
#   'text': 'assister today'},
#  {'count': 1,
#   'emotion': {'anger': 0.157872,
#               'disgust': 0.5296,
#               'fear': 0.153132,
#               'joy': 0.02777,
#               'sadness': 0.39889},
#   'relevance': 0.543534,
#   'sentiment': {'label': 'negative', 'score': -0.840814},
#   'text': 'influential members of Congress'},
#  {'count': 1,
#   'emotion': {'anger': 0.033664,
#               'disgust': 0.034796,
#               'fear': 0.190504,
#               'joy': 0.047859,
#               'sadness': 0.796041},
#   'relevance': 0.540356,
#   'sentiment': {'label': 'negative', 'score': -0.74737},
#   'text': 'MNsure’s last day'},
#  {'count': 1,
#   'emotion': {'anger': 0.074935,
#               'disgust': 0.104388,
#               'fear': 0.038407,
#               'joy': 0.663631,
#               'sadness': 0.131434},
#   'relevance': 0.535866,
#   'sentiment': {'label': 'negative', 'score': -0.303409},
#   'text': 'Steve Simon’s leadership'},
#  {'count': 2,
#   'emotion': {'anger': 0.21867,
#               'disgust': 0.685053,
#               'fear': 0.078687,
#               'joy': 0.023912,
#               'sadness': 0.301663},
#   'relevance': 0.533714,
#   'sentiment': {'label': 'negative', 'score': -0.964528},
#   'text': 'Native Americans'},
#  {'count': 1,
#   'emotion': {'anger': 0.098386,
#               'disgust': 0.601181,
#               'fear': 0.099481,
#               'joy': 0.172128,
#               'sadness': 0.242754},
#   'relevance': 0.533012,
#   'sentiment': {'label': 'negative', 'score': -0.929589},
#   'text': 'strong opposition'},
#  {'count': 1,
#   'emotion': {'anger': 0.083436,
#               'disgust': 0.086988,
#               'fear': 0.047003,
#               'joy': 0.691844,
#               'sadness': 0.137493},
#   'relevance': 0.530055,
#   'sentiment': {'label': 'positive', 'score': 0.952717},
#   'text': 'ForThePeople Act'},
#  {'count': 3,
#   'emotion': {'anger': 0.132193,
#               'disgust': 0.042026,
#               'fear': 0.029541,
#               'joy': 0.092096,
#               'sadness': 0.457637},
#   'relevance': 0.529451,
#   'sentiment': {'label': 'negative', 'score': -0.377188},
#   'text': 'Federal employees'},
#  {'count': 1,
#   'emotion': {'anger': 0.390025,
#               'disgust': 0.42882,
#               'fear': 0.024669,
#               'joy': 0.045814,
#               'sadness': 0.435051},
#   'relevance': 0.52726,
#   'sentiment': {'label': 'negative', 'score': -0.95705},
#   'text': 'President Trump'},
#  {'count': 1,
#   'emotion': {'anger': 0.17592,
#               'disgust': 0.709293,
#               'fear': 0.007841,
#               'joy': 0.050996,
#               'sadness': 0.20981},
#   'relevance': 0.526077,
#   'sentiment': {'label': 'positive', 'score': 0.84012},
#   'text': 'Republican support'},
#  {'count': 1,
#   'emotion': {'anger': 0.157872,
#               'disgust': 0.5296,
#               'fear': 0.153132,
#               'joy': 0.02777,
#               'sadness': 0.39889},
#   'relevance': 0.524292,
#   'sentiment': {'label': 'negative', 'score': -0.840814},
#   'text': 'Government shutdown drags'},
#  {'count': 4,
#   'emotion': {'anger': 0.053748,
#               'disgust': 0.371149,
#               'fear': 0.315,
#               'joy': 0.217415,
#               'sadness': 0.272591},
#   'relevance': 0.52421,
#   'sentiment': {'label': 'negative', 'mixed': '1', 'score': -0.571592},
#   'text': 'climate change'},
#  {'count': 1,
#   'emotion': {'anger': 0.02652,
#               'disgust': 0.067409,
#               'fear': 0.145605,
#               'joy': 0.735952,
#               'sadness': 0.054846},
#   'relevance': 0.523439,
#   'sentiment': {'label': 'positive', 'score': 0.900845},
#   'text': 'good hands'},
#  {'count': 42,
#   'emotion': {'anger': 0.165962,
#               'disgust': 0.605426,
#               'fear': 0.177292,
#               'joy': 0.123168,
#               'sadness': 0.51852},
#   'relevance': 0.523083,
#   'sentiment': {'label': 'negative', 'mixed': '1', 'score': -0.722207},
#   'text': 'amp'},
#  {'count': 1,
#   'emotion': {'anger': 0.437855,
#               'disgust': 0.296818,
#               'fear': 0.192177,
#               'joy': 0.092505,
#               'sadness': 0.081172},
#   'relevance': 0.521791,
#   'sentiment': {'label': 'negative', 'mixed': '1', 'score': -0.317828},
#   'text': 'billionaire NFL team owner'},
#  {'count': 1,
#   'emotion': {'anger': 0.09645,
#               'disgust': 0.086951,
#               'fear': 0.108007,
#               'joy': 0.487561,
#               'sadness': 0.250688},
#   'relevance': 0.521594,
#   'sentiment': {'label': 'neutral', 'score': 0},
#   'text': 'U.S. House'},
#  {'count': 1,
#   'emotion': {'anger': 0.12362,
#               'disgust': 0.282504,
#               'fear': 0.05906,
#               'joy': 0.191822,
#               'sadness': 0.529628},
#   'relevance': 0.521217,
#   'sentiment': {'label': 'negative', 'score': -0.686587},
#   'text': 'last night’s House vote'},
#  {'count': 2,
#   'emotion': {'anger': 0.062384,
#               'disgust': 0.006934,
#               'fear': 0.011841,
#               'joy': 0.810409,
#               'sadness': 0.072566},
#   'relevance': 0.521139,
#   'sentiment': {'label': 'negative', 'mixed': '1', 'score': -0.472021},
#   'text': 'new year'},
#  {'count': 1,
#   'emotion': {'anger': 0.055764,
#               'disgust': 0.148206,
#               'fear': 0.014915,
#               'joy': 0.662106,
#               'sadness': 0.08813},
#   'relevance': 0.521082,
#   'sentiment': {'label': 'positive', 'score': 0.726778},
#   'text': 'first day of the new Democratic majority'},
#  {'count': 1,
#   'emotion': {'anger': 0.08348,
#               'disgust': 0.382948,
#               'fear': 0.140297,
#               'joy': 0.391557,
#               'sadness': 0.087559},
#   'relevance': 0.521027,
#   'sentiment': {'label': 'positive', 'score': 0.616507},
#   'text': 'human health'},
#  {'count': 1,
#   'emotion': {'anger': 0.052606,
#               'disgust': 0.073077,
#               'fear': 0.018631,
#               'joy': 0.634443,
#               'sadness': 0.172791},
#   'relevance': 0.520865,
#   'sentiment': {'label': 'positive', 'score': 0.84012},
#   'text': 'first Speaker'},
#  {'count': 1,
#   'emotion': {'anger': 0.012719,
#               'disgust': 0.039224,
#               'fear': 0.001702,
#               'joy': 0.877117,
#               'sadness': 0.054327},
#   'relevance': 0.520166,
#   'sentiment': {'label': 'positive', 'score': 0.973626},
#   'text': 'strong supporter of net neutrality'},
#  {'count': 3,
#   'emotion': {'anger': 0.426507,
#               'disgust': 0.59908,
#               'fear': 0.068195,
#               'joy': 0.03441,
#               'sadness': 0.19389},
#   'relevance': 0.520121,
#   'sentiment': {'label': 'negative', 'mixed': '1', 'score': -0.316775},
#   'text': 'public lands'},
#  {'count': 2,
#   'emotion': {'anger': 0.345312,
#               'disgust': 0.628968,
#               'fear': 0.046959,
#               'joy': 0.061425,
#               'sadness': 0.153396},
#   'relevance': 0.519193,
#   'sentiment': {'label': 'positive', 'score': 0.804016},
#   'text': 'White House'},
#  {'count': 1,
#   'emotion': {'anger': 0.035474,
#               'disgust': 0.064155,
#               'fear': 0.013754,
#               'joy': 0.70264,
#               'sadness': 0.190322},
#   'relevance': 0.519071,
#   'sentiment': {'label': 'positive', 'score': 0.524035},
#   'text': 'powerful members of Congress'},
#  {'count': 1,
#   'emotion': {'anger': 0.041866,
#               'disgust': 0.127507,
#               'fear': 0.105842,
#               'joy': 0.417387,
#               'sadness': 0.246942},
#   'relevance': 0.518931,
#   'sentiment': {'label': 'positive', 'score': 0.57191},
#   'text': 'historic week'},
#  {'count': 1,
#   'emotion': {'anger': 0.049807,
#               'disgust': 0.100895,
#               'fear': 0.413205,
#               'joy': 0.328146,
#               'sadness': 0.224508},
#   'relevance': 0.51893,
#   'sentiment': {'label': 'negative', 'score': -0.672286},
#   'text': 'hard work'},
#  {'count': 1,
#   'emotion': {'anger': 0.291649,
#               'disgust': 0.093283,
#               'fear': 0.639909,
#               'joy': 0.033489,
#               'sadness': 0.227625},
#   'relevance': 0.518749,
#   'sentiment': {'label': 'negative', 'score': -0.986398},
#   'text': 'realDonaldTrump’s latest tantrum'},
#  {'count': 2,
#   'emotion': {'anger': 0.031155,
#               'disgust': 0.015315,
#               'fear': 0.089018,
#               'joy': 0.044066,
#               'sadness': 0.182293},
#   'relevance': 0.518637,
#   'sentiment': {'label': 'negative', 'score': -0.532176},
#   'text': 'Attention Minnesotans'},
#  {'count': 1,
#   'emotion': {'anger': 0.376054,
#               'disgust': 0.225362,
#               'fear': 0.056515,
#               'joy': 0.11727,
#               'sadness': 0.158426},
#   'relevance': 0.518626,
#   'sentiment': {'label': 'negative', 'score': -0.966889},
#   'text': 'human rights violations'},
#  {'count': 1,
#   'emotion': {'anger': 0.041866,
#               'disgust': 0.127507,
#               'fear': 0.105842,
#               'joy': 0.417387,
#               'sadness': 0.246942},
#   'relevance': 0.518418,
#   'sentiment': {'label': 'positive', 'score': 0.889162},
#   'text': 'new women'},
#  {'count': 1,
#   'emotion': {'anger': 0.02652,
#               'disgust': 0.067409,
#               'fear': 0.145605,
#               'joy': 0.735952,
#               'sadness': 0.054846},
#   'relevance': 0.51782,
#   'sentiment': {'label': 'positive', 'score': 0.886424},
#   'text': 'State Auditor'},
#  {'count': 1,
#   'emotion': {'anger': 0.176535,
#               'disgust': 0.211597,
#               'fear': 0.081619,
#               'joy': 0.046844,
#               'sadness': 0.315675},
#   'relevance': 0.517116,
#   'sentiment': {'label': 'positive', 'score': 0.949254},
#   'text': 'responsible spending bill'},
#  {'count': 1,
#   'emotion': {'anger': 0.108859,
#               'disgust': 0.196038,
#               'fear': 0.038791,
#               'joy': 0.095981,
#               'sadness': 0.299848},
#   'relevance': 0.517051,
#   'sentiment': {'label': 'positive', 'score': 0.775785},
#   'text': 'government services'},
#  {'count': 1,
#   'emotion': {'anger': 0.166802,
#               'disgust': 0.754592,
#               'fear': 0.026356,
#               'joy': 0.072606,
#               'sadness': 0.153699},
#   'relevance': 0.51652,
#   'sentiment': {'label': 'positive', 'score': 0.84012},
#   'text': 'Republican opposition'},
#  {'count': 1,
#   'emotion': {'anger': 0.114235,
#               'disgust': 0.068738,
#               'fear': 0.021433,
#               'joy': 0.584834,
#               'sadness': 0.065758},
#   'relevance': 0.516206,
#   'sentiment': {'label': 'positive', 'mixed': '1', 'score': 0.462371},
#   'text': 'sincerest congratulations'},
#  {'count': 1,
#   'emotion': {'anger': 0.063872,
#               'disgust': 0.290497,
#               'fear': 0.079919,
#               'joy': 0.381747,
#               'sadness': 0.21588},
#   'relevance': 0.516093,
#   'sentiment': {'label': 'negative', 'score': -0.939504},
#   'text': 'National Parks'},
#  {'count': 1,
#   'emotion': {'anger': 0.132193,
#               'disgust': 0.042026,
#               'fear': 0.029541,
#               'joy': 0.092096,
#               'sadness': 0.457637},
#   'relevance': 0.515854,
#   'sentiment': {'label': 'negative', 'score': -0.377188},
#   'text': 'air traffic controllers'},
#  {'count': 1,
#   'emotion': {'anger': 0.119383,
#               'disgust': 0.129185,
#               'fear': 0.042459,
#               'joy': 0.610074,
#               'sadness': 0.132312},
#   'relevance': 0.515816,
#   'sentiment': {'label': 'positive', 'score': 0.439679},
#   'text': 'reopening of the Smith Avenue High Bridge'},
#  {'count': 1,
#   'emotion': {'anger': 0.049502,
#               'disgust': 0.011954,
#               'fear': 0.005568,
#               'joy': 0.896531,
#               'sadness': 0.044401},
#   'relevance': 0.515078,
#   'sentiment': {'label': 'negative', 'score': -0.910486},
#   'text': 'delicious winter treats'},
#  {'count': 1,
#   'emotion': {'anger': 0.325913,
#               'disgust': 0.64515,
#               'fear': 0.020798,
#               'joy': 0.0389,
#               'sadness': 0.232161},
#   'relevance': 0.514066,
#   'sentiment': {'label': 'negative', 'score': -0.904337},
#   'text': 'Israel Anti-Boycott Act'},
#  {'count': 1,
#   'emotion': {'anger': 0.323962,
#               'disgust': 0.442317,
#               'fear': 0.062027,
#               'joy': 0.04439,
#               'sadness': 0.420047},
#   'relevance': 0.513714,
#   'sentiment': {'label': 'negative', 'score': -0.912122},
#   'text': 'Arctic National Wildlife Refuge'},
#  {'count': 2,
#   'emotion': {'anger': 0.589469,
#               'disgust': 0.096774,
#               'fear': 0.18617,
#               'joy': 0.047594,
#               'sadness': 0.30646},
#   'relevance': 0.513478,
#   'sentiment': {'label': 'positive', 'mixed': '1', 'score': 0.310068},
#   'text': 'House Floor'},
#  {'count': 3,
#   'emotion': {'anger': 0.435957,
#               'disgust': 0.331911,
#               'fear': 0.022756,
#               'joy': 0.032658,
#               'sadness': 0.222282},
#   'relevance': 0.513,
#   'sentiment': {'label': 'positive', 'score': 0.288905},
#   'text': 'federal government'},
#  {'count': 1,
#   'emotion': {'anger': 0.039946,
#               'disgust': 0.072351,
#               'fear': 0.012887,
#               'joy': 0.757242,
#               'sadness': 0.10996},
#   'relevance': 0.512912,
#   'sentiment': {'label': 'negative', 'score': -0.852843},
#   'text': 'Ryan Zinke'},
#  {'count': 2,
#   'emotion': {'anger': 0.023797,
#               'disgust': 0.028565,
#               'fear': 0.061413,
#               'joy': 0.122585,
#               'sadness': 0.105044},
#   'relevance': 0.512743,
#   'sentiment': {'label': 'neutral', 'score': 0},
#   'text': 'Stillwater tomorrow'},
#  {'count': 1,
#   'emotion': {'anger': 0.095912,
#               'disgust': 0.085304,
#               'fear': 0.121792,
#               'joy': 0.114626,
#               'sadness': 0.230093},
#   'relevance': 0.512538,
#   'sentiment': {'label': 'neutral', 'score': 0},
#   'text': 'EPA inspections'}]

# %%
def getEmotion(keyword, emotion):
    try:
        return keyword["emotion"][emotion]
    except KeyError:
        return 0

# %%
emotionTallys = {}
emotions = ("anger", "disgust", "fear", "joy", "sadness")
for emotion in emotions:
    emotionTallys[emotion] = [sum(getEmotion(keyword, emotion) for keyword in response["keywords"]) for response in responses]

# %%
emotionTallys["disgust"][:5]
# Out:
# [12.180891999999995,
#  7.840825000000002,
#  8.941889,
#  5.460022999999999,
#  10.769493999999998]

# %%
emotionTallys
# Out:
# {'anger': [7.481342999999999,
#   7.076859000000001,
#   6.359759000000001,
#   3.143239,
#   10.001310999999998,
#   6.962200000000001,
#   9.820251,
#   5.900742000000001,
#   10.431705000000003,
#   8.619988999999997,
#   3.3756369999999998,
#   3.783326,
#   10.764426,
#   8.702764000000004,
#   3.737167,
#   3.8055659999999993,
#   5.401173,
#   6.950645,
#   3.5849910000000014,
#   4.963512,
#   6.124818000000001,
#   4.808764999999999,
#   3.8403420000000006,
#   5.425565999999999,
#   5.894471000000001,
#   6.862951999999998,
#   7.906724000000001,
#   6.474148999999998,
#   3.8005250000000004,
#   6.690532999999999,
#   4.749309,
#   8.098965000000002,
#   3.907908,
#   6.521464,
#   8.265009,
#   6.743813999999999,
#   6.187695000000002,
#   6.275063999999999,
#   6.5739740000000015,
#   4.9134899999999995,
#   7.023959000000002,
#   7.161707000000001,
#   6.820056999999999,
#   5.367714,
#   3.9017590000000006,
#   5.474398000000001,
#   5.7823990000000025,
#   6.728176000000001,
#   7.370973,
#   6.746156000000001,
#   4.290567999999999,
#   2.6289379999999998,
#   3.4859250000000004,
#   4.964938,
#   4.0422910000000005,
#   5.955963999999999,
#   6.173655999999999,
#   4.287932,
#   7.407002,
#   4.591015000000002,
#   8.962800999999999,
#   5.350816000000001,
#   3.0295129999999997,
#   6.5609399999999996,
#   6.799079999999999,
#   0,
#   4.795228,
#   5.956085999999998,
#   3.2060950000000004,
#   8.927107999999999,
#   3.936442,
#   4.566925,
#   4.5376140000000005,
#   5.836383000000002,
#   5.260294000000003,
#   5.781573000000002,
#   3.489137,
#   4.772704999999999,
#   7.975291999999999,
#   9.119546,
#   7.844921999999998,
#   3.111753,
#   10.754112000000001,
#   4.202659,
#   5.862182000000001,
#   4.949183000000001],
#  'disgust': [12.180891999999995,
#   7.840825000000002,
#   8.941889,
#   5.460022999999999,
#   10.769493999999998,
#   10.891909999999998,
#   7.497926999999999,
#   8.136046,
#   10.514688999999999,
#   11.480549999999997,
#   4.9190770000000015,
#   5.377248000000002,
#   11.444838999999998,
#   16.824817000000003,
#   7.600911999999999,
#   6.168023999999998,
#   11.444127999999997,
#   5.553588999999999,
#   8.30818,
#   9.992711,
#   7.314216,
#   6.8876029999999995,
#   6.482382999999997,
#   9.483290000000002,
#   4.367680000000001,
#   9.252559999999999,
#   10.469604,
#   7.921634,
#   3.8787249999999993,
#   7.832959000000001,
#   5.304306,
#   8.840555999999998,
#   4.77174,
#   10.183506,
#   9.094557000000002,
#   8.088175999999999,
#   9.552008,
#   8.369589,
#   7.625221999999999,
#   6.1863790000000005,
#   9.517586999999999,
#   8.424759000000002,
#   8.634010000000002,
#   6.914563000000001,
#   4.587111,
#   9.958602000000003,
#   7.606571000000001,
#   7.159561999999998,
#   10.210522999999998,
#   10.670952999999999,
#   8.413437000000002,
#   3.995745,
#   6.068446,
#   10.061677,
#   3.7915910000000017,
#   7.518576000000004,
#   7.396019000000001,
#   8.873229,
#   8.210537,
#   9.149476,
#   11.496786999999998,
#   8.566902,
#   5.570761000000001,
#   8.962917999999998,
#   7.418593,
#   0,
#   4.6687150000000015,
#   9.818306000000002,
#   6.186958000000001,
#   12.789041999999998,
#   6.276667999999997,
#   5.643069,
#   4.909122000000001,
#   8.680162000000001,
#   5.237712999999998,
#   5.937212000000001,
#   5.350154,
#   6.629284,
#   8.977621999999998,
#   8.938942999999998,
#   12.696602,
#   6.062609999999999,
#   11.966864000000005,
#   6.138374999999997,
#   6.142398000000002,
#   8.507513999999999],
#  'fear': [4.78084,
#   5.106363,
#   3.3481950000000005,
#   4.641078,
#   5.147196000000001,
#   7.197007000000001,
#   3.5875200000000005,
#   6.161445,
#   11.20029,
#   4.482566,
#   4.233507000000001,
#   3.022941999999999,
#   5.206212000000001,
#   4.457180000000001,
#   2.9639669999999994,
#   4.898801,
#   3.748018000000001,
#   4.8817509999999995,
#   3.035853999999999,
#   5.142500000000001,
#   4.831967999999999,
#   3.369932,
#   3.6196540000000006,
#   4.30299,
#   3.1409059999999993,
#   4.5703130000000005,
#   4.638839999999999,
#   3.4925240000000004,
#   5.1217310000000005,
#   4.840702,
#   5.4749909999999975,
#   6.049275000000001,
#   4.338445000000001,
#   6.660366,
#   6.690174,
#   4.7471770000000015,
#   5.605845000000002,
#   7.322376000000001,
#   5.785198000000002,
#   3.838024999999999,
#   5.6876479999999985,
#   5.621941,
#   4.107533999999999,
#   4.214677000000002,
#   3.9879300000000004,
#   4.734261,
#   4.943427000000002,
#   9.695708000000002,
#   5.258826999999999,
#   3.6334710000000014,
#   3.4884500000000003,
#   3.9056800000000003,
#   2.9243879999999995,
#   3.9340149999999996,
#   3.878787,
#   3.790225,
#   3.3583219999999994,
#   5.355943000000001,
#   3.8653229999999996,
#   2.8731829999999996,
#   6.887677999999999,
#   6.159045999999999,
#   3.981238000000001,
#   5.094036000000002,
#   4.132061000000001,
#   0,
#   3.256537,
#   6.110173000000002,
#   4.536317,
#   6.8220730000000005,
#   4.174308000000001,
#   4.716260000000001,
#   6.338217,
#   5.803587999999999,
#   4.374010999999999,
#   4.881491999999999,
#   1.9111670000000003,
#   5.970523000000001,
#   5.615794999999998,
#   5.623478,
#   5.060249,
#   3.131624999999999,
#   5.883585000000001,
#   3.5001049999999996,
#   5.263594000000001,
#   3.914247],
#  'joy': [15.476949999999999,
#   13.308786999999997,
#   18.177092000000005,
#   24.160086000000003,
#   10.932396000000002,
#   14.038458000000004,
#   16.637090999999998,
#   18.672098,
#   8.528349999999998,
#   13.015393999999999,
#   24.508032999999998,
#   22.059872000000002,
#   10.093288999999999,
#   13.0603,
#   26.828417999999992,
#   20.745004,
#   14.350017000000001,
#   17.457434000000003,
#   8.718465999999998,
#   18.550219000000002,
#   12.06223,
#   22.854312000000004,
#   23.985982,
#   23.068884000000004,
#   13.103977,
#   17.630283,
#   12.119165000000002,
#   17.971419,
#   22.916182000000006,
#   17.618488000000003,
#   19.664496999999997,
#   15.316302000000004,
#   26.98117999999999,
#   14.870646000000008,
#   17.817839,
#   15.212144999999998,
#   17.763961000000002,
#   15.268170000000005,
#   17.059606999999996,
#   20.068418000000012,
#   16.983134000000003,
#   18.443590999999998,
#   19.395758999999998,
#   20.099449000000003,
#   23.519419999999997,
#   19.310108000000003,
#   16.727863999999997,
#   14.90848,
#   16.238892000000003,
#   19.778596000000004,
#   24.052534,
#   27.889904,
#   24.85811899999999,
#   26.259760999999997,
#   25.810430999999998,
#   17.791473999999997,
#   10.136660000000003,
#   17.247021999999998,
#   17.028207,
#   21.905171,
#   12.927421000000002,
#   15.315085,
#   26.694660000000002,
#   17.646736000000004,
#   20.285818999999996,
#   0,
#   24.295872999999993,
#   13.696222000000002,
#   26.770207999999993,
#   9.660952000000004,
#   22.08165899999999,
#   20.693768000000002,
#   24.254848999999997,
#   17.015176,
#   21.846273000000007,
#   15.226591,
#   28.79976699999999,
#   23.871153000000007,
#   17.671999,
#   16.669458,
#   14.212301,
#   25.738663,
#   7.849886999999998,
#   20.421322999999994,
#   19.214108000000007,
#   21.518531999999993],
#  'sadness': [11.547214,
#   12.367954999999998,
#   9.000912,
#   12.697617999999995,
#   14.585865999999998,
#   15.626288999999998,
#   10.993626000000003,
#   13.573010000000002,
#   10.665003,
#   14.592579,
#   8.928343,
#   9.760451,
#   16.448949999999996,
#   14.542784999999999,
#   6.911652999999999,
#   12.337002999999997,
#   13.227842999999996,
#   9.74277,
#   7.038092999999999,
#   11.370277000000003,
#   12.739795,
#   11.697527,
#   11.055553000000002,
#   8.768113,
#   15.633762999999995,
#   13.090434999999996,
#   13.543455999999997,
#   10.408589,
#   10.464742999999999,
#   10.634343,
#   13.424019000000003,
#   12.795539999999995,
#   10.121445,
#   11.816613000000002,
#   13.449093000000005,
#   16.070808000000003,
#   12.581134999999998,
#   15.976312,
#   11.770210000000002,
#   11.455053999999999,
#   12.829327000000001,
#   14.382478,
#   11.195765999999999,
#   9.828799999999998,
#   10.649545000000002,
#   12.436440000000005,
#   14.432572999999998,
#   14.427684000000001,
#   13.515318999999996,
#   8.806595,
#   11.127590000000001,
#   8.071343000000002,
#   9.310994000000003,
#   7.631244,
#   7.982783999999999,
#   10.352967999999997,
#   16.610935,
#   10.431113999999999,
#   16.800106999999993,
#   7.318405999999999,
#   15.748040999999999,
#   15.845436999999999,
#   11.569886,
#   12.868362000000001,
#   10.984318999999998,
#   0,
#   11.730873,
#   12.935829000000004,
#   7.399625,
#   16.068471999999996,
#   10.668491000000001,
#   10.089623999999995,
#   9.794391000000001,
#   11.403573000000005,
#   10.583187000000002,
#   12.781617999999996,
#   7.346385000000001,
#   9.185128,
#   11.062556000000004,
#   12.082444000000002,
#   10.971428,
#   10.816328000000002,
#   20.493323999999998,
#   11.488828,
#   10.029901,
#   9.004155000000003]}

# %%
emotionsDF = pd.DataFrame(emotionTallys)

# %%
len(emotionsDF)
# Out:
# 86

# %%
len(groupedTweets)
# Out:
# 86

# %%
len(tweetsDF)
# Out:
# 8209

# %%
len(metaDatMin)
# Out:
# 100

# %%
groupedTweetsWithAnalysisMin = groupedTweets.join(emotionsDF)

# %%
groupedTweetsWithAnalysisMin.to_csv("data/groupedTweetsWithEmotions.csv", index=False)

# %%
pd.read_csv("data/groupedTweetsWithEmotions.csv")
# Out:
#     twitter_account                                          full_text  \
# 0   BettyMcCollum04  There’s still time to #GetCovered! @MNsure’s l...
# 1       BradSherman  Proud to be sworn in by @SpeakerPelosi to begi...
# 2     Call_Me_Dutch  RT @RepAnthonyBrown: I represent over 50,000 f...
# 3     CathyMcMorris  HAPPENING SOON: I’ll speak with @mschlapp on @...
# 4     ChrisMurphyCT  Cassie Bernall was 17. Her parents used to cal...
# 5    DesJarlaisTN04  Economy in last two years has rebounded from O...
# 6     EleanorNorton  Thank you to the following Members for introdu...
# 7   GraceNapolitano  RT @RepThompson: The American people have been...
# 8        GrahamBlog  .@tim_cook Our nation is at war &amp; this Iph...
# 9     JanSchakowsky  RT @CNN: JUST IN: House Speaker Nancy Pelosi a...
# 10      JohnBoozman  RT @BarryMoehring: Honored to have had Senator...
# 11    LisaMurkowski  Spraznikom to all those across Alaska celebrat...
# 12      MazieHirono  Someone who is amoral makes no distinction bet...
# 13        NitaLowey  There's no reason for the entire federal govt ...
# 14         RepAmata  Had a great time with the troops at Camp Arifj...
# 15   RepAndreCarson  With the partial government shutdown entering ...
# 16     RepAndyLevin  To mark Day 17 of the senseless #TrumpShutdown...
# 17    RepAngieCraig  I won't accept a paycheck during this or any s...
# 18      RepBenCline  NEWS: Ben Cline made it to Congress, here's ho...
# 19    RepBrianBabin  RT @TXRandy14: Do you remember... Under Presid...
# 20    RepBryanSteil  Joining @WTMJSteve on @620wtmj at 9:07CST. Tun...
# 21   RepBuddyCarter  Tune in! https://t.co/HyRiQMMlwk --\n From Amy...
# 22         RepCheri  I made some new friends today at Shaheen’s Vil...
# 23         RepChuck  I believe that hardworking members of our fede...
# 24     RepCindyAxne  Due to the shutdown, @USDA will now delay cruc...
# 25   RepClayHiggins  RT @LaRadioNetwork: Speaker Pelosi won't rule ...
# 26       RepCleaver  The White House has stated over and over again...
# 27      RepComstock  RT @CongressionalAC: Navigator app for the vis...
# 28         RepDavid  A beautiful #InaugurationDay with Olivia in Ar...
# 29    RepDebDingell  Devastated by the tragic loss of the Abbas fam...
# ..              ...                                                ...
# 56  RepSylviaGarcia  Thank you! https://t.co/QHR3So39yV --\n #Trump...
# 57       RepTedYoho  Will be joining @HARRISFAULKNER at 1:30pm toda...
# 58       RepTimWalz  This is my last tweet from this account. It wa...
# 59     RepUnderwood  So help me God 🇺🇸 https://t.co/MWwEHjOuGb --\n...
# 60    RepValDemings  This Friday, America's @TSA officers will miss...
# 61        RepVeasey  When Chris Wallace calls you out for lying on ...
# 62      RepWalorski  The 116th Congress is in session! I was honore...
# 63        RepWilson  We stand united in our opposition to Boko Hara...
# 64         RonWyden  I agree with @ChrisVanHollen.\n   \nThe #Trump...
# 65      RosLehtinen  RT @elnuevoherald: Ileana Ros-Lehtinen se estr...
# 66     SenAngusKing  I got to work early this morning and spent a q...
# 67    SenBlumenthal  Background checks are a crucial step in the ri...
# 68        SenCapito  Two seniors from Hurricane High School came to...
# 69     SenFeinstein  I’m glad to see a bill providing $12 billion i...
# 70    SenGaryPeters  The Chippewa tribe in the UP relies on federal...
# 71     SenJoniErnst  Both men exemplified bravery and dedication to...
# 72    SenRonJohnson  Congratulations @GovEvers, would like to work ...
# 73    SenRubioPress  Great work by the service men and women aboard...
# 74   SenatorBaldwin  Thank you to @Rooseveltinst for this important...
# 75  SenatorCantwell  If people don’t have health insurance or can’t...
# 76   SenatorIsakson  This is great news for Moultrie and Colquitt C...
# 77   SenatorShaheen  Fran was a true American hero. Rest in Peace. ...
# 78    Senatorhassan  Hard-working Americans are suffering because o...
# 79       TulsiPress  Our veterans deserve better than added stress ...
# 80     VernBuchanan  RT @FL_Daily: @VernBuchanan Calls on DOJ to St...
# 81     VirginiaFoxx  What did you miss last year? Check out my news...
# 82      repdonbeyer  So many people across the country have worked ...
# 83       repmialove  I am grateful to @SpeakerRyan for his leadersh...
# 84   sencortezmasto  .@USGAO found the VA’s efforts to reduce suici...
# 85   staceyplaskett  After Republicans shut down the government in ...
#
#         anger    disgust       fear        joy    sadness
# 0    7.481343  12.180892   4.780840  15.476950  11.547214
# 1    7.076859   7.840825   5.106363  13.308787  12.367955
# 2    6.359759   8.941889   3.348195  18.177092   9.000912
# 3    3.143239   5.460023   4.641078  24.160086  12.697618
# 4   10.001311  10.769494   5.147196  10.932396  14.585866
# 5    6.962200  10.891910   7.197007  14.038458  15.626289
# 6    9.820251   7.497927   3.587520  16.637091  10.993626
# 7    5.900742   8.136046   6.161445  18.672098  13.573010
# 8   10.431705  10.514689  11.200290   8.528350  10.665003
# 9    8.619989  11.480550   4.482566  13.015394  14.592579
# 10   3.375637   4.919077   4.233507  24.508033   8.928343
# 11   3.783326   5.377248   3.022942  22.059872   9.760451
# 12  10.764426  11.444839   5.206212  10.093289  16.448950
# 13   8.702764  16.824817   4.457180  13.060300  14.542785
# 14   3.737167   7.600912   2.963967  26.828418   6.911653
# 15   3.805566   6.168024   4.898801  20.745004  12.337003
# 16   5.401173  11.444128   3.748018  14.350017  13.227843
# 17   6.950645   5.553589   4.881751  17.457434   9.742770
# 18   3.584991   8.308180   3.035854   8.718466   7.038093
# 19   4.963512   9.992711   5.142500  18.550219  11.370277
# 20   6.124818   7.314216   4.831968  12.062230  12.739795
# 21   4.808765   6.887603   3.369932  22.854312  11.697527
# 22   3.840342   6.482383   3.619654  23.985982  11.055553
# 23   5.425566   9.483290   4.302990  23.068884   8.768113
# 24   5.894471   4.367680   3.140906  13.103977  15.633763
# 25   6.862952   9.252560   4.570313  17.630283  13.090435
# 26   7.906724  10.469604   4.638840  12.119165  13.543456
# 27   6.474149   7.921634   3.492524  17.971419  10.408589
# 28   3.800525   3.878725   5.121731  22.916182  10.464743
# 29   6.690533   7.832959   4.840702  17.618488  10.634343
# ..        ...        ...        ...        ...        ...
# 56   6.173656   7.396019   3.358322  10.136660  16.610935
# 57   4.287932   8.873229   5.355943  17.247022  10.431114
# 58   7.407002   8.210537   3.865323  17.028207  16.800107
# 59   4.591015   9.149476   2.873183  21.905171   7.318406
# 60   8.962801  11.496787   6.887678  12.927421  15.748041
# 61   5.350816   8.566902   6.159046  15.315085  15.845437
# 62   3.029513   5.570761   3.981238  26.694660  11.569886
# 63   6.560940   8.962918   5.094036  17.646736  12.868362
# 64   6.799080   7.418593   4.132061  20.285819  10.984319
# 65   0.000000   0.000000   0.000000   0.000000   0.000000
# 66   4.795228   4.668715   3.256537  24.295873  11.730873
# 67   5.956086   9.818306   6.110173  13.696222  12.935829
# 68   3.206095   6.186958   4.536317  26.770208   7.399625
# 69   8.927108  12.789042   6.822073   9.660952  16.068472
# 70   3.936442   6.276668   4.174308  22.081659  10.668491
# 71   4.566925   5.643069   4.716260  20.693768  10.089624
# 72   4.537614   4.909122   6.338217  24.254849   9.794391
# 73   5.836383   8.680162   5.803588  17.015176  11.403573
# 74   5.260294   5.237713   4.374011  21.846273  10.583187
# 75   5.781573   5.937212   4.881492  15.226591  12.781618
# 76   3.489137   5.350154   1.911167  28.799767   7.346385
# 77   4.772705   6.629284   5.970523  23.871153   9.185128
# 78   7.975292   8.977622   5.615795  17.671999  11.062556
# 79   9.119546   8.938943   5.623478  16.669458  12.082444
# 80   7.844922  12.696602   5.060249  14.212301  10.971428
# 81   3.111753   6.062610   3.131625  25.738663  10.816328
# 82  10.754112  11.966864   5.883585   7.849887  20.493324
# 83   4.202659   6.138375   3.500105  20.421323  11.488828
# 84   5.862182   6.142398   5.263594  19.214108  10.029901
# 85   4.949183   8.507514   3.914247  21.518532   9.004155
#
# [86 rows x 7 columns]

# %% [markdown]
# ## Scrap

# %%
with open("dataDir.txt", 'r') as f:
    dir = f.read().strip()
dir
# Out:
# '/Volumes/GoogleDrive/My Drive/Yale/4/spring/Research/PolySpeech'

# %%
suffix = ".json"
# prefix = dir + "/WIL Twitter Data With Vader/"
prefix = dir + "/WIL Twitter Data/"

# %%
getName = slice(*(len(prefix),-len(suffix)))

# %%
json_paths = glob.glob(prefix + "*" + suffix)
print(len(json_paths))
json_paths[0]
with codecs.open(json_paths[0], 'r', encoding='utf8') as rf: 
    read_tweets = json.load(rf)
    print(len(read_tweets))
# Out:
# 2065
# 3156

# %%
def tagIBM(analyzer, start=0, limit=None):
    if limit == None:
        limit = itertools.count()
    else:
        limit = range(start, limit)
    for (i,json_path),_ in zip(enumerate(glob.glob(prefix + "*" + suffix)), limit):
        name = json_path[getName]
        with codecs.open(json_path, 'r', encoding='utf8') as rf: 
            read_tweets = json.load(rf)
            read_tweets = [json.loads(t) for t in read_tweets]
            tweets = [read_tweets[i]['full_text'] for i,_ in enumerate(read_tweets)]
            print(tweets[0])
            print(i,name, "Tweet count:", len(tweets))
            for (j, tweet),_ in zip(enumerate(tweets), limit):
                print(tweet)
                response = service.analyze(text=tweet,
                                           features=Features(emotion=natural_language_understanding_v1.EmotionOptions(),
                                                              keywords=KeywordsOptions())).get_result()
                read_tweets[j]['IBM'] = response
#         with open(outPrefix + name + suffix, 'w') as outfile:
#             json.dump(read_tweets, outfile)
#         print([read_tweets[i]['IBM'] for i,_ in enumerate(read_tweets)])
    return read_tweets
tweets = tagIBM(service, limit=1)
# Out:
# RT @briankoppelman: 1)Some thoughts on the value of reading fiction: When I was in my 20s/early 30s, I read 3 or 4 books a week. Mostly fic…
# 0 heykerikae Tweet count: 3156
# RT @briankoppelman: 1)Some thoughts on the value of reading fiction: When I was in my 20s/early 30s, I read 3 or 4 books a week. Mostly fic…

# %%
tweets[0]
# Out:
# {'created_at': 'Wed Dec 26 00:10:32 +0000 2018',
#  'full_text': 'RT @briankoppelman: 1)Some thoughts on the value of reading fiction: When I was in my 20s/early 30s, I read 3 or 4 books a week. Mostly fic…',
#  'hashtags': [],
#  'id': 1077718265567371264,
#  'id_str': '1077718265567371264',
#  'lang': 'en',
#  'retweet_count': 3107,
#  'retweeted_status': {'created_at': 'Mon Dec 24 22:24:40 +0000 2018',
#   'favorite_count': 11094,
#   'full_text': '1)Some thoughts on the value of reading fiction: When I was in my 20s/early 30s, I read 3 or 4 books a week. Mostly fiction. This sounds like a lot to non-writers. But it’s not. It never felt like work. Or if it did, I was on to the next book.',
#   'hashtags': [],
#   'id': 1077329236149571584,
#   'id_str': '1077329236149571584',
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-80.147162, 25.7613083],
#       [-80.1187628, 25.7613083],
#       [-80.1187628, 25.872623],
#       [-80.147162, 25.872623]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Miami Beach, FL',
#    'id': '0121b92345f0e2b4',
#    'name': 'Miami Beach',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/0121b92345f0e2b4.json'},
#   'retweet_count': 3107,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'urls': [],
#   'user': {'id': 16737406, 'id_str': '16737406'},
#   'user_mentions': []},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'urls': [],
#  'user': {'id': 17083778, 'id_str': '17083778'},
#  'user_mentions': [{'id': 16737406,
#    'id_str': '16737406',
#    'name': 'Brian Koppelman',
#    'screen_name': 'briankoppelman'}],
#  'IBM': {'usage': {'text_units': 1, 'text_characters': 140, 'features': 2},
#   'language': 'en',
#   'keywords': [{'text': 'value of reading fiction',
#     'relevance': 0.948469,
#     'count': 1},
#    {'text': '20s', 'relevance': 0.82297, 'count': 1},
#    {'text': 'RT', 'relevance': 0.817649, 'count': 1},
#    {'text': 'thoughts', 'relevance': 0.657903, 'count': 1},
#    {'text': 'books', 'relevance': 0.565563, 'count': 1},
#    {'text': 'week', 'relevance': 0.554172, 'count': 1},
#    {'text': '30s', 'relevance': 0.493918, 'count': 1},
#    {'text': 'briankoppelman', 'relevance': 0.327459, 'count': 1}],
#   'emotion': {'document': {'emotion': {'sadness': 0.41707,
#      'joy': 0.415651,
#      'fear': 0.131175,
#      'disgust': 0.073958,
#      'anger': 0.019712}}}}}

# %%
natural_language_understanding_v1.EmotionOptions
# Out:
# watson_developer_cloud.natural_language_understanding_v1.EmotionOptions

# %%
response = service.analyze(
    text=tweets,
    features=Features(emotion=natural_language_understanding_v1.EmotionOptions(),
                      keywords=KeywordsOptions())).get_result()

# %%
response
# Out:
# {'usage': {'text_units': 1, 'text_characters': 140, 'features': 2},
#  'language': 'en',
#  'keywords': [{'text': 'value of reading fiction',
#    'relevance': 0.948469,
#    'count': 1},
#   {'text': '20s', 'relevance': 0.82297, 'count': 1},
#   {'text': 'RT', 'relevance': 0.817649, 'count': 1},
#   {'text': 'thoughts', 'relevance': 0.657903, 'count': 1},
#   {'text': 'books', 'relevance': 0.565563, 'count': 1},
#   {'text': 'week', 'relevance': 0.554172, 'count': 1},
#   {'text': '30s', 'relevance': 0.493918, 'count': 1},
#   {'text': 'briankoppelman', 'relevance': 0.327459, 'count': 1}],
#  'emotion': {'document': {'emotion': {'sadness': 0.41707,
#     'joy': 0.415651,
#     'fear': 0.131175,
#     'disgust': 0.073958,
#     'anger': 0.019712}}}}

# %% [markdown]
# ## OG analysis

# %%
from __future__ import print_function
import json
from os.path import join, dirname
from watson_developer_cloud import ToneAnalyzerV3

tone_analyzer = ToneAnalyzerV3(
    username='e382ff56-867f-4857-a0be-5d3da0968b61',
    password='yfRH7C1jLu4A',
    version='2017-09-26')

# %%
from collections import Counter
import pandas as pd
import numpy as np

# %%
print(json.dumps(tone_analyzer.tone(tone_input='I am very happy. It is a good day.',
                                    content_type="text/plain", sentences=False), indent=2))
# Out:
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.961678,
#         "tone_id": "joy",
#         "tone_name": "Joy"
#       },
#       {
#         "score": 0.983213,
#         "tone_id": "confident",
#         "tone_name": "Confident"
#       }
#     ]
#   }
# }

# %%
# df = pd.read_csv('data/week1-mar25-min.csv')

# %%
df = pd.read_csv('pol_tweets_50.csv')
#df = pd.read_csv('men200.csv')

# %%
#df

# %%
len(df) / 50
# Out:
# 216.0

# %%
111 * 2
# Out:
# 222

# %%
step = 10
it = len(df) / step
pref_len = 20
l=0
fails = 1
for i in range(int(it)):
    idx = i*step
    if i % 10 == 0:
        print("progress: i:", i, idx*100/len(df), "%")
    tweet_batch = df.loc[idx:idx+step, 'tweet_text']
    #tweet_batch = [tweet.replace('.', '--').replace('!', '--') for tweet in tweet_batch]
    raw = tone_analyzer.tone(tone_input='. '.join(tweet_batch), content_type='text/plain', sentences=True)
    for j, sent_dict in enumerate(raw['sentences_tone']):
        # find the csv sentence starting with this, if any.
        # first 20 letters serve as key
        key = sent_dict['text'][:pref_len]
        # Linear search from index to idx + step for where to put the results
        for k in range(step):
            if df.loc[idx + k, 'tweet_text'][:pref_len] == key:
                if idx + k <= l:
                    print('Rewriting previous')
                l = idx+k
                df.loc[l, 'IBM_text'] = sent_dict['text']
                for tone in sent_dict['tones']:
                    df.loc[l, tone['tone_name']] = tone['score']
                break
            if k == step - 1:
                # Failure
                if fails % 10 == 0:
                    fails += 1
                    print('Failed 10 matches')
print(fails)
# Out:
# progress: i: 0 0.0 %
# Rewriting previous
# Rewriting previous
# Rewriting previous
# Rewriting previous
# progress: i: 10 0.9259259259259259 %
# progress: i: 20 1.8518518518518519 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-dcc891f94bbb> in <module>()
#      10     tweet_batch = df.loc[idx:idx+step, 'tweet_text']
#      11     #tweet_batch = [tweet.replace('.', '--').replace('!', '--') for tweet in tweet_batch]
# ---> 12     raw = tone_analyzer.tone(tone_input='. '.join(tweet_batch), content_type='text/plain', sentences=True)
#      13     for j, sent_dict in enumerate(raw['sentences_tone']):
#      14         # find the csv sentence starting with this, if any.
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/watson_developer_cloud/tone_analyzer_v3.py in tone(self, tone_input, content_type, sentences, tones, content_language, accept_language)
#     128             params=params,
#     129             data=data,
# --> 130             accept_json=True)
#     131         return response
#     132
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/watson_developer_cloud/watson_service.py in request(self, method, url, accept_json, headers, params, json, data, files, **kwargs)
#     356                                     headers=headers,
#     357                                     params=params, data=data, files=files,
# --> 358                                     **kwargs)
#     359
#     360         if 200 <= response.status_code <= 299:
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     327         context.load_cert_chain(certfile, keyfile)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#     331     warnings.warn(
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     439         while True:
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#     443                 rd = util.wait_for_read(sock, sock.gettimeout())
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1803         :return: None.
#    1804         """
# -> 1805         result = _lib.SSL_do_handshake(self._ssl)
#    1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# KeyboardInterrupt:

# %%
df[-10:]
# Out:
#       first_name last_name gender  age type  senate_class     party  \
# 10790       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10791       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10792       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10793       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10794       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10795       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10796       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10797       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10798       Kurt  Schrader      M   66  rep           NaN  Democrat
# 10799       Kurt  Schrader      M   66  rep           NaN  Democrat
#
#            twitter            tweet_id  \
# 10790  RepSchrader  955165484068036608
# 10791  RepSchrader  954464269805989888
# 10792  RepSchrader  954170091993788416
# 10793  RepSchrader  952307923731935232
# 10794  RepSchrader  952266732898418688
# 10795  RepSchrader  951935153919717376
# 10796  RepSchrader  951931235131101184
# 10797  RepSchrader  951912635112525824
# 10798  RepSchrader  941714486792142848
# 10799  RepSchrader  941359634971062275
#
#                                               tweet_text  tweet_retweet_count  \
# 10790  My town hall in Polk County originally schedul...                    8
# 10791  My town halls in Tillamook and Lincoln Countie...                    4
# 10792  I wouldn't expect a student government to oper...                    9
# 10793  Four years ago I met three Marine Corps combat...                   13
# 10794  Thanks to all who came out to see Senator Merk...                    4
# 10795  Tune in to News @1190KEX at 1:50 while I speak...                    2
# 10796  Thanks to the Canby Rotary for having me today...                    2
# 10797  Happy to see the great work being done by @Car...                    5
# 10798  Open enrollment ends at MIDNIGHT tonight! Make...                    4
# 10799  Open enrollment ends TOMORROW! Visit https://t...                    5
#
#        tweet_favorite_count  \
# 10790                     5
# 10791                     8
# 10792                    25
# 10793                    36
# 10794                    17
# 10795                     5
# 10796                     4
# 10797                     6
# 10798                     2
# 10799                     4
#
#                                                 IBM_text  Sadness       Joy  \
# 10790  My town hall in Polk County originally schedul...      NaN       NaN
# 10791  My town halls in Tillamook and Lincoln Countie...      NaN  0.507633
# 10792  I wouldn't expect a student government to oper...      NaN       NaN
# 10793  Four years ago I met three Marine Corps combat...      NaN  0.515799
# 10794  Thanks to all who came out to see Senator Merk...      NaN  0.554443
# 10795  Tune in to News @1190KEX at 1:50 while I speak...      NaN       NaN
# 10796                                                NaN      NaN       NaN
# 10797  Happy to see the great work being done by @Car...      NaN  0.886998
# 10798                     Open enrollment ends TOMORROW!      NaN       NaN
# 10799                                                NaN      NaN       NaN
#
#        Tentative  Analytical  Confident  Fear  Anger
# 10790        NaN         NaN        NaN   NaN    NaN
# 10791        NaN         NaN        NaN   NaN    NaN
# 10792        NaN    0.703409        NaN   NaN    NaN
# 10793        NaN         NaN        NaN   NaN    NaN
# 10794        NaN    0.579367        NaN   NaN    NaN
# 10795        NaN         NaN        NaN   NaN    NaN
# 10796        NaN         NaN        NaN   NaN    NaN
# 10797        NaN         NaN        NaN   NaN    NaN
# 10798        NaN         NaN        NaN   NaN    NaN
# 10799        NaN         NaN        NaN   NaN    NaN

# %%
df.to_csv('more-data/all_w_IBM_50.csv')

# %%
#pd.read_csv('more-data/all_w_IBM_50.csv')

# %%
for i, tweet in enumerate(df.loc[:1000, 'tweet_text']):
    
    raw = tone_analyzer.tone(tone_input=tweet, content_type='text/plain', sentences=False)
    print(raw)
    for tone in raw['document_tone']['tones']:
        print(tone['tone_name'], tone['score'])
        df.loc[i, tone['tone_name']] = tone['score']
# Out:
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': [{'score': 0.915262, 'tone_id': 'joy', 'tone_name': 'Joy'}]}}
# Joy 0.915262
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': [{'score': 0.783873, 'tone_id': 'joy', 'tone_name': 'Joy'}]}}
# Joy 0.783873
# {'document_tone': {'tones': [{'score': 0.828183, 'tone_id': 'joy', 'tone_name': 'Joy'}]}}
# Joy 0.828183
# {'document_tone': {'tones': [{'score': 0.632709, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.596122, 'tone_id': 'analytical', 'tone_name': 'Analytical'}, {'score': 0.932568, 'tone_id': 'confident', 'tone_name': 'Confident'}]}}
# Sadness 0.632709
# Analytical 0.596122
# Confident 0.932568
# {'document_tone': {'tones': [{'score': 0.536692, 'tone_id': 'fear', 'tone_name': 'Fear'}]}}
# Fear 0.536692
# {'document_tone': {'tones': [{'score': 0.828638, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}}
# Analytical 0.828638
# {'document_tone': {'tones': [{'score': 0.903342, 'tone_id': 'joy', 'tone_name': 'Joy'}]}}
# Joy 0.903342
# {'document_tone': {'tones': [{'score': 0.506763, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}}
# Analytical 0.506763
# {'document_tone': {'tones': [{'score': 0.509668, 'tone_id': 'joy', 'tone_name': 'Joy'}]}}
# Joy 0.509668
# {'document_tone': {'tones': [{'score': 0.559375, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.597565, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}}
# Joy 0.559375
# Analytical 0.597565
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': [{'score': 0.641927, 'tone_id': 'joy', 'tone_name': 'Joy'}]}}
# Joy 0.641927
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': []}}
# {'document_tone': {'tones': []}}

# %%
#df

# %%
genders = ['F', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'F', 'M', 'F', 'F', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M']
names = ["lisamurkowski",        
"SenJohnMcCain",
"JeffFlake",
"JohnBoozman",
"SenFeinstein",
"SenatorBoxer",
"MarkUdall",
"SenBennetCO",
"ChrisMurphyCT",
"SenBlumenthal",
"SenatorCarper",
"ChrisCoons",
"marcorubio",
"SaxbyChambliss",
"brianschatz",
"maziehirono",
"MikeCrapo",
"SenatorRisch",
"SenatorDurbin",
"SenDonnelly",
"SenDanCoats",
"ChuckGrassley",
"SenatorHarkin",
"SenPatRoberts",
"JerryMoran",
"SenRandPaul",
"SenLandrieu",
"DavidVitter",
"SenatorBarb",
"MarkeyMemo",
"stabenow",
"amyklobuchar",
"SenatorWicker",
"clairecmc",
"RoyBlunt",
"jontester",
"SenatorFischer",
"SenatorReid",
"SenDeanHeller",
"SenatorShaheen",
"kellyayotte",
"CoryBooker",
"SenatorMenendez",
"MartinHeinrich",
"SenatorTomUdall",
"SenSchumer",
"SenGillibrand",
"SenatorBurr",
"SenatorHagan",
"SenatorHeitkamp",
"SenJohnHoeven",
"SenSherrodBrown",
"robportman",
"jiminhofe",
"RonWyden",
"SenToomey",
"SenJackReed",
"SenWhitehouse",
"GrahamBlog",
"SenatorTimScott",
"SenJohnThune",
"SenMikeLee",
"SenatorLeahy",
"timkaine",
"SenRockefeller",
"Sen_JoeManchin",
"SenRonJohnson",
"SenatorEnzi",
"SenJohnBarrasso"]

# %%
len(names)
# Out:
# 69

# %%
len(genders)
# Out:
# 69

# %%
d = {}
for i, name in enumerate(names):
    d[name] = genders[i]

# %%
d['KellyAyotte'] = 'F'

# %%
# for i, name in enumerate(df.loc[:, 'politician_username']):
#     try:
#         df.loc[i, 'gender'] = d[name]
#     except KeyError as e:
#         df.loc[i, 'gender'] = 'M'
#         print(e, i, name)

# %%
for i, name in enumerate(df.loc[37700:38775, 'politician_username']):
    if name == 'KellyAyotte':
        df.loc[i, 'gender'] = 'F'

# %%
df.loc[37800]
# Out:
# politician_name                                              Kelly Ayotte
# politician_username                                           KellyAyotte
# tweet_text              Getting ready to rappell off Brady Sullivan wi...
# tweet_retweet_count                                                     5
# tweet_favorite_count                                                   68
# Joy                                                                   NaN
# Sadness                                                               NaN
# Analytical                                                            NaN
# Confident                                                             NaN
# Fear                                                                  NaN
# gender                                                                  M
# Name: 37800, dtype: object

# %%
d
# Out:
# {'ChrisCoons': 'M',
#  'ChrisMurphyCT': 'M',
#  'ChuckGrassley': 'M',
#  'CoryBooker': 'M',
#  'DavidVitter': 'M',
#  'GrahamBlog': 'M',
#  'JeffFlake': 'M',
#  'JerryMoran': 'M',
#  'JohnBoozman': 'M',
#  'MarkUdall': 'M',
#  'MarkeyMemo': 'M',
#  'MartinHeinrich': 'M',
#  'MikeCrapo': 'M',
#  'RonWyden': 'M',
#  'RoyBlunt': 'M',
#  'SaxbyChambliss': 'M',
#  'SenBennetCO': 'M',
#  'SenBlumenthal': 'M',
#  'SenDanCoats': 'M',
#  'SenDeanHeller': 'M',
#  'SenDonnelly': 'M',
#  'SenFeinstein': 'F',
#  'SenGillibrand': 'F',
#  'SenJackReed': 'M',
#  'SenJohnBarrasso': 'M',
#  'SenJohnHoeven': 'M',
#  'SenJohnMcCain': 'M',
#  'SenJohnThune': 'M',
#  'SenLandrieu': 'F',
#  'SenMikeLee': 'M',
#  'SenPatRoberts': 'M',
#  'SenRandPaul': 'M',
#  'SenRockefeller': 'M',
#  'SenRonJohnson': 'M',
#  'SenSchumer': 'M',
#  'SenSherrodBrown': 'M',
#  'SenToomey': 'M',
#  'SenWhitehouse': 'M',
#  'Sen_JoeManchin': 'M',
#  'SenatorBarb': 'F',
#  'SenatorBoxer': 'F',
#  'SenatorBurr': 'M',
#  'SenatorCarper': 'M',
#  'SenatorDurbin': 'M',
#  'SenatorEnzi': 'M',
#  'SenatorFischer': 'F',
#  'SenatorHagan': 'F',
#  'SenatorHarkin': 'M',
#  'SenatorHeitkamp': 'F',
#  'SenatorLeahy': 'M',
#  'SenatorMenendez': 'M',
#  'SenatorReid': 'M',
#  'SenatorRisch': 'M',
#  'SenatorShaheen': 'F',
#  'SenatorTimScott': 'M',
#  'SenatorTomUdall': 'M',
#  'SenatorWicker': 'M',
#  'amyklobuchar': 'F',
#  'brianschatz': 'M',
#  'clairecmc': 'F',
#  'jiminhofe': 'M',
#  'jontester': 'M',
#  'kellyayotte': 'F',
#  'lisamurkowski': 'F',
#  'marcorubio': 'M',
#  'maziehirono': 'F',
#  'robportman': 'M',
#  'stabenow': 'F',
#  'timkaine': 'M'}

# %%
tweet_batch = df.loc[:500, 'tweet_text']

# %%
tweet_batch = [tweet.replace('.', '--').replace('!', '--') for tweet in tweet_batch]

# %%
raw = tone_analyzer.tone(tone_input='. '.join(tweet_batch), content_type='text/plain', sentences=True)

# %%
tweet_batch[5]
# Out:
# 'The FY18 government funding before the Senate has big wins for Alaska-- As chairman of the Interior Appropriations S------ https://t--co/1eFjj2wdNx'

# %%
#raw

# %%
tweet_batch[100]
# Out:
# 'Speaking now to the Alaska State Legislature-- Watch live here: https://t--co/I17YMhkXGV'

# %%
tweet_batch[7]
# Out:
# 'Today kids in AK joined thousands of young people across the U.S. for "Kick Butts Day." Proud to see so many youth... https://t.co/XfnQ33Mg36'

# %%
tweet_batch[8]
# Out:
# 'We must protect our most vulnerable victims &amp; bring justice to all who are impacted by these crimes. This evening,... https://t.co/W4tqiuA8FL'

# %%
with open('data/min2.txt') as f:
    content = f.readlines()

# %%
#print(json.dumps(tone_analyzer.tone(tone_input=''.join(content[:100]), content_type='text/plain'), indent=2))

# %%
raw = tone_analyzer.tone(tone_input=''.join(content[:100]), content_type='text/plain')

# %%
#raw['sentences_tone']

# %%
c = Counter()
for sent_dict in raw['sentences_tone']:
    for tone in sent_dict['tones']:
        c[tone['tone_name']] += 1
#    if sent_dict['tones'] != []:
#        print(sent_dict['tones']
print(c)
# Out:
# Counter({'Joy': 27, 'Analytical': 15, 'Confident': 6, 'Sadness': 5, 'Tentative': 3, 'Fear': 1, 'Anger': 1})

# %%
utterances = [{'text': 'I am very happy.', 'user': 'glenn'},
              {'text': 'It is a good day.', 'user': 'glenn'}]
print(json.dumps(tone_analyzer.tone_chat(utterances), indent=2))
# Out:
# {
#   "utterances_tone": [
#     {
#       "utterance_id": 0,
#       "utterance_text": "I am very happy.",
#       "tones": [
#         {
#           "score": 0.912181,
#           "tone_id": "excited",
#           "tone_name": "Excited"
#         }
#       ]
#     },
#     {
#       "utterance_id": 1,
#       "utterance_text": "It is a good day.",
#       "tones": [
#         {
#           "score": 0.67376,
#           "tone_id": "excited",
#           "tone_name": "Excited"
#         },
#         {
#           "score": 0.722718,
#           "tone_id": "satisfied",
#           "tone_name": "Satisfied"
#         }
#       ]
#     }
#   ]
# }

# %%
arr = tone_analyzer.tone_chat(utterances)

# %%
arr
# Out:
# {'utterances_tone': [{'tones': [{'score': 0.912181,
#      'tone_id': 'excited',
#      'tone_name': 'Excited'}],
#    'utterance_id': 0,
#    'utterance_text': 'I am very happy.'},
#   {'tones': [{'score': 0.67376, 'tone_id': 'excited', 'tone_name': 'Excited'},
#     {'score': 0.722718, 'tone_id': 'satisfied', 'tone_name': 'Satisfied'}],
#    'utterance_id': 1,
#    'utterance_text': 'It is a good day.'}]}

# %%
print(json.dumps(tone_analyzer.tone(tone_input='I am very happy. It is a good day.',
                                    content_type="text/plain", sentences=False), indent=2))
# Out:
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.961678,
#         "tone_id": "joy",
#         "tone_name": "Joy"
#       },
#       {
#         "score": 0.983213,
#         "tone_id": "confident",
#         "tone_name": "Confident"
#       }
#     ]
#   }
# }

# %%
utterances
# Out:
# [{'text': 'I am very happy.', 'user': 'glenn'},
#  {'text': 'It is a good day.', 'user': 'glenn'}]

# %%
print(json.dumps(tone_analyzer.tone(tone_input=utterances,
                                    content_type="text/plain"), indent=2))
# Out:
# {
#   "document_tone": {
#     "tones": []
#   }
# }

# %%
tone_analyzer.tone?

# %%
arr = []
for line in content:
    arr.append(tone_analyzer.tone(tone_input=line, content_type='text/plain', sentences=False))

# %%
arr
# Out:
# [{'document_tone': {'tones': []}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': [{'score': 0.915262,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'}]}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': [{'score': 0.783873,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'}]}},
#  {'document_tone': {'tones': [{'score': 0.828183,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'}]}},
#  {'document_tone': {'tones': [{'score': 0.632709,
#      'tone_id': 'sadness',
#      'tone_name': 'Sadness'},
#     {'score': 0.932568, 'tone_id': 'confident', 'tone_name': 'Confident'},
#     {'score': 0.596122, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}},
#  {'document_tone': {'tones': [{'score': 0.536692,
#      'tone_id': 'fear',
#      'tone_name': 'Fear'}]}},
#  {'document_tone': {'tones': [{'score': 0.828638,
#      'tone_id': 'analytical',
#      'tone_name': 'Analytical'}]}},
#  {'document_tone': {'tones': [{'score': 0.903342,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'}]}},
#  {'document_tone': {'tones': [{'score': 0.506763,
#      'tone_id': 'analytical',
#      'tone_name': 'Analytical'}]}},
#  {'document_tone': {'tones': [{'score': 0.509668,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'}]}},
#  {'document_tone': {'tones': [{'score': 0.559375,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'},
#     {'score': 0.597565, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': [{'score': 0.641927,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'}]}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': [{'score': 0.58752,
#      'tone_id': 'sadness',
#      'tone_name': 'Sadness'},
#     {'score': 0.862626, 'tone_id': 'confident', 'tone_name': 'Confident'}]}},
#  {'document_tone': {'tones': [{'score': 0.821152,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'},
#     {'score': 0.927401, 'tone_id': 'confident', 'tone_name': 'Confident'}]}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': [{'score': 0.762356,
#      'tone_id': 'analytical',
#      'tone_name': 'Analytical'}]}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': [{'score': 0.894423,
#      'tone_id': 'joy',
#      'tone_name': 'Joy'}]}},
#  {'document_tone': {'tones': []}},
#  {'document_tone': {'tones': []}}]

# %%
arr = []
for i in range(100):
    arr.append(tone_analyzer.tone(tone_input=content[i], content_type='text/plain'))
arr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-3d31c3ccd643> in <module>()
#       1 arr = []
#       2 for i in range(100):
# ----> 3     arr.append(tone_analyzer.tone(tone_input=content[i], content_type='text/plain'))
#       4 arr
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/watson_developer_cloud/tone_analyzer_v3.py in tone(self, tone_input, content_type, sentences, tones, content_language, accept_language)
#     128             params=params,
#     129             data=data,
# --> 130             accept_json=True)
#     131         return response
#     132
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/watson_developer_cloud/watson_service.py in request(self, method, url, accept_json, headers, params, json, data, files, **kwargs)
#     356                                     headers=headers,
#     357                                     params=params, data=data, files=files,
# --> 358                                     **kwargs)
#     359
#     360         if 200 <= response.status_code <= 299:
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/.virtualenvs/finance/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %%
with open('IBM-resources/tone-example.json') as tone_json:
    # print(tone_json.readlines())
    tone = tone_analyzer.tone(tone_input=json.load(tone_json)['text'],
                              content_type='text/plain')
tone
# Out:
# {'document_tone': {'tones': [{'score': 1.0,
#     'tone_id': 'joy',
#     'tone_name': 'Joy'}]}}

# %%
utterances = [{'text': 'I am very happy.', 'user': 'glenn'},
              {'text': 'It is a good day.', 'user': 'glenn'}]
print(json.dumps(tone_analyzer.tone(tone_input=utterances), indent=2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-52df5c7e10f0> in <module>()
#       1 utterances = [{'text': 'I am very happy.', 'user': 'glenn'},
#       2               {'text': 'It is a good day.', 'user': 'glenn'}]
# ----> 3 print(json.dumps(tone_analyzer.tone(tone_input=utterances), indent=2))
#
# TypeError: tone() missing 1 required positional argument: 'content_type'

# %%
tone_analyzer.tone_chat?

# %%
tone_analyzer.tone?

# %%
tone_analyzer.ToneInput
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-16b63183f392> in <module>()
# ----> 1 tone_analyzer.ToneInput
#
# AttributeError: 'ToneAnalyzerV3' object has no attribute 'ToneInput'

# %%
ToneAnalyzerV3.ToneInput
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-4e2aa92794ba> in <module>()
# ----> 1 ToneAnalyzerV3.ToneInput
#
# AttributeError: type object 'ToneAnalyzerV3' has no attribute 'ToneInput'

# %%
with open('IBM-resources/tone-example.json') as tone_json:
    tone = tone_analyzer.tone(json.load(tone_json)['text'], "text/plain", sentences=True)

# %%
tone
# Out:
# {'document_tone': {'tones': [{'score': 1.0,
#     'tone_id': 'joy',
#     'tone_name': 'Joy'}]}}
